# %%
import numpy as np 
import pandas as pd

# %%
summary = pd.read_csv(r"/kaggle/input/news-summary/news_summary_HT.csv",encoding='iso-8859-1')
summary.head()
# Out:
#                author                  date  \
# 0        Chhavi Tyagi  03 Aug 2017,Thursday
# 1         Daisy Mowke  03 Aug 2017,Thursday
# 2      Arshiya Chopra  03 Aug 2017,Thursday
# 3       Sumedha Sehra  03 Aug 2017,Thursday
# 4  Aarushi Maheshwari  03 Aug 2017,Thursday
#
#                                            headlines  \
# 0  Daman & Diu revokes mandatory Rakshabandhan in...
# 1  Malaika slams user who trolled her for 'divorc...
# 2  'Virgin' now corrected to 'Unmarried' in IGIMS...
# 3  Aaj aapne pakad liya: LeT man Dujana before be...
# 4  Hotel staff to get training to spot signs of s...
#
#                                            read_more  \
# 0  http://www.hindustantimes.com/india-news/raksh...
# 1  http://www.hindustantimes.com/bollywood/malaik...
# 2  http://www.hindustantimes.com/patna/bihar-igim...
# 3  http://indiatoday.intoday.in/story/abu-dujana-...
# 4  http://indiatoday.intoday.in/story/sex-traffic...
#
#                                                 text  \
# 0  The Administration of Union Territory Daman an...
# 1  Malaika Arora slammed an Instagram user who tr...
# 2  The Indira Gandhi Institute of Medical Science...
# 3  Lashkar-e-Taiba's Kashmir commander Abu Dujana...
# 4  Hotels in Maharashtra will train their staff t...
#
#                                                ctext
# 0  The Daman and Diu administration on Wednesday ...
# 1  From her special numbers to TV?appearances, Bo...
# 2  The Indira Gandhi Institute of Medical Science...
# 3  Lashkar-e-Taiba's Kashmir commander Abu Dujana...
# 4  Hotels in Mumbai and other Indian cities are t...

# %%
summary['headlines'][1]
# Out:
# "Malaika slams user who trolled her for 'divorcing rich man' "

# %%
summary['text'][1]
# Out:
# 'Malaika Arora slammed an Instagram user who trolled her for "divorcing a rich man" and "having fun with the alimony". "Her life now is all about wearing short clothes, going to gym or salon, enjoying vacation[s]," the user commented. Malaika responded, "You certainly got to get your damn facts right before spewing sh*t on me...when you know nothing about me."'

# %%
summary['ctext'][1]
# Out:
# 'From her special numbers to TV?appearances, Bollywood actor Malaika Arora Khan has managed to carve her own identity. The actor, who made her debut in the Hindi film industry with the blockbuster debut opposite Shah Rukh Khan in Chaiyya Chaiyya from Dil Se (1998), is still remembered for the song. However, for trolls, she is a woman first and what matters right now is that she divorced a ?rich man?.  On Wednesday, Malaika Arora shared a gorgeous picture of herself on Instagram and a follower decided to troll her for using her ?alumni? (read alimony) money to wear ?short clothes and going to gym or salon?. Little did he/she know that the Munni Badnam star would reply with the perfect comeback. Take a look at the interaction:     Super excited to be affiliated with Khanna Jewellers @khannajewellerskj as their brand ambassador. Crafted to perfection, their stunning statement jewellery is a must have for every jewellery lover. #khannajewellers...#maksquad?? #hair @hairbypriyanka #stylist @manekaharisinghani #manager @ektakauroberoi #mua? @subbu28 #photographer @prasdnaik A post shared by Malaika Arora Khan (@malaikaarorakhanofficial) on Aug 2, 2017 at 6:20am PDT Then, Malaika decided to reply: The entire conversation only proves that no matter if a woman is successful, she will be attacked the moment she decides to step out of bounds the society decided for her. Apart from being a successful woman who lives life on her own terms, Malaika has literally played all the roles traditionally prescribed for a woman - she married quite early, had a son and raised him and was always around with the ?khandan?. But then, she got divorced and alimony is the taunt being thrown at her. The details of the alimony are only known to Malaika, her husband Arbaaz Khan and perhaps the family. The couple has handled the divorce with the utmost dignity. But we can vouch for the fact that she did not  need an alimony to buy clothes (short or not, her choice), go on vacations and enjoy her life. If anything, she is as successful, if not more, than her ex-husband.What happened between Arbaaz and Malaika is their personal concern. But to claim that Malaika married and then divorced Arbaaz for money doesn?t hold water. For those who do not agree, please get a course in feminism and for others, here?s a playlist of some of her most popular songs. Follow @htshowbiz for more'

# %%
raw = pd.read_csv('/kaggle/input/news-summary-dataset/news_summary_more.csv', encoding='iso-8859-1')
raw.head()
# Out:
#                                            headlines  \
# 0  upGrad learner switches to career in ML & Al w...
# 1  Delhi techie wins free food from Swiggy for on...
# 2  New Zealand end Rohit Sharma-led India's 12-ma...
# 3  Aegon life iTerm insurance plan helps customer...
# 4  Have known Hirani for yrs, what if MeToo claim...
#
#                                                 text
# 0  Saurav Kant, an alumnus of upGrad and IIIT-B's...
# 1  Kunal Shah's credit card bill payment platform...
# 2  New Zealand defeated India by 8 wickets in the...
# 3  With Aegon Life iTerm Insurance plan, customer...
# 4  Speaking about the sexual harassment allegatio...

# %%
raw['headlines'][1]
# Out:
# 'Delhi techie wins free food from Swiggy for one year on CRED'

# %%
raw['text'][1]
# Out:
# "Kunal Shah's credit card bill payment platform, CRED, gave users a chance to win free food from Swiggy for one year. Pranav Kaushik, a Delhi techie, bagged this reward after spending 2000 CRED coins. Users get one CRED coin per rupee of bill paid, which can be used to avail rewards from brands like Ixigo, BookMyShow, UberEats, Cult.Fit and more."

# %%
pre1 =  raw.iloc[:,0:2].copy()
pre1['head + text'] = pre1['headlines'].str.cat(pre1['text'], sep =" ")

# %%
pre1.head()
# Out:
#                                            headlines  \
# 0  upGrad learner switches to career in ML & Al w...
# 1  Delhi techie wins free food from Swiggy for on...
# 2  New Zealand end Rohit Sharma-led India's 12-ma...
# 3  Aegon life iTerm insurance plan helps customer...
# 4  Have known Hirani for yrs, what if MeToo claim...
#
#                                                 text  \
# 0  Saurav Kant, an alumnus of upGrad and IIIT-B's...
# 1  Kunal Shah's credit card bill payment platform...
# 2  New Zealand defeated India by 8 wickets in the...
# 3  With Aegon Life iTerm Insurance plan, customer...
# 4  Speaking about the sexual harassment allegatio...
#
#                                          head + text
# 0  upGrad learner switches to career in ML & Al w...
# 1  Delhi techie wins free food from Swiggy for on...
# 2  New Zealand end Rohit Sharma-led India's 12-ma...
# 3  Aegon life iTerm insurance plan helps customer...
# 4  Have known Hirani for yrs, what if MeToo claim...

# %%
pre2 = summary.iloc[:,0:6].copy()
pre2['head + text'] = pre2['author'].str.cat(pre2['date'].str.cat(pre2['headlines'].str.cat(pre2['read_more'].str.cat(pre2['text'].str.cat(pre2['ctext'], sep = " "), sep =" "),sep= " "), sep = " "),sep= " ")

# %%
pre2.head()
# Out:
#                author                  date  \
# 0        Chhavi Tyagi  03 Aug 2017,Thursday
# 1         Daisy Mowke  03 Aug 2017,Thursday
# 2      Arshiya Chopra  03 Aug 2017,Thursday
# 3       Sumedha Sehra  03 Aug 2017,Thursday
# 4  Aarushi Maheshwari  03 Aug 2017,Thursday
#
#                                            headlines  \
# 0  Daman & Diu revokes mandatory Rakshabandhan in...
# 1  Malaika slams user who trolled her for 'divorc...
# 2  'Virgin' now corrected to 'Unmarried' in IGIMS...
# 3  Aaj aapne pakad liya: LeT man Dujana before be...
# 4  Hotel staff to get training to spot signs of s...
#
#                                            read_more  \
# 0  http://www.hindustantimes.com/india-news/raksh...
# 1  http://www.hindustantimes.com/bollywood/malaik...
# 2  http://www.hindustantimes.com/patna/bihar-igim...
# 3  http://indiatoday.intoday.in/story/abu-dujana-...
# 4  http://indiatoday.intoday.in/story/sex-traffic...
#
#                                                 text  \
# 0  The Administration of Union Territory Daman an...
# 1  Malaika Arora slammed an Instagram user who tr...
# 2  The Indira Gandhi Institute of Medical Science...
# 3  Lashkar-e-Taiba's Kashmir commander Abu Dujana...
# 4  Hotels in Maharashtra will train their staff t...
#
#                                                ctext  \
# 0  The Daman and Diu administration on Wednesday ...
# 1  From her special numbers to TV?appearances, Bo...
# 2  The Indira Gandhi Institute of Medical Science...
# 3  Lashkar-e-Taiba's Kashmir commander Abu Dujana...
# 4  Hotels in Mumbai and other Indian cities are t...
#
#                                          head + text
# 0  Chhavi Tyagi 03 Aug 2017,Thursday Daman & Diu ...
# 1  Daisy Mowke 03 Aug 2017,Thursday Malaika slams...
# 2  Arshiya Chopra 03 Aug 2017,Thursday 'Virgin' n...
# 3  Sumedha Sehra 03 Aug 2017,Thursday Aaj aapne p...
# 4  Aarushi Maheshwari 03 Aug 2017,Thursday Hotel ...

# %%
pre2['head + text'][500]
# Out:
# 'Chhavi Tyagi 26 Jul 2017,Wednesday Nitish Kumar did not ask for Tejashwi\'s resignation: Lalu http://indiatoday.intoday.in/story/tejashwi-nitish-kumar-lalu-yadav-mahagathbandhan-jdu-rjd/1/1011250.html?utm_source=inshorts&utm_medium=referral&utm_campaign=fullarticle  RJD Chief Lalu Prasad Yadav on Wednesday said that Bihar Chief Minister Nitish Kumar has not asked for his son Tejashwi Yadav\'s resignation after the CBI raided him over corruption allegations. "We will not tolerate any disrespect towards him (Nitish Kumar). We have formed the grand alliance, made Nitish CM. Why will we break the alliance," Lalu said. As Nitish Kumar meets his party - Janata Dal United - MLAs later in the evening today in Patna, senior alliance partner Lalu Prasad today reiterated that his son Tejashwi Yadav won\'t resign. Deputy CM Tejashwi is facing corruption allegations after the CBI filed a case against him."Tejashwi will not resign. Nitish Kumar is leader of the alliance but he has not asked for his resignation," Lalu told reporters after a separate meeting of RJD MLAs.\xa0 "Nitish Kumar is leader of grand alliance. We will not tolerate any disrespect towards him. We have formed the grand alliance, made Nitish CM. Why will we break the alliance," Lalu said. "We have spoken to Nitish Kumar and he said he is not asking for Tejaswi\'s resignation. BJP is trying to frame us but are we are not afraid of their tactic," former CM Rabri Devi added.\xa0 The fate of Bihar\'s Mahagathbandhan or grand alliance (RJD, JD-U and Congress) is likely to be decided today or by tomorrow as the JD-U is firm on Tejashwi\'s resignation.Nitish Kumar is expected to make some tough decision before the start of Bihar Asssembly\'s Monsoon Session (July 28) which the BJP has threatened to disrupt demanding the CM to take a call on his deputy.Tejashwi and his party RJD, which has most number of MLAs\xa0 of the three alliance partners, have repeatedly described the corruption charges as a conspiracy by Opposition BJP. Earlier this month, Tejashwi and Nitish had a closed door meeting during which the deputy CM tabled his stance and claimed that he was being framed. Insiders said Nitish was not convinced with Tejashwi\'s explanation.It is believed that Nitish is miffed with Tejashwi as he has failed to present solid evidence in support of his \'not guilty\' claim despite being given ample time.Congress President Sonia Gandhi and son Rahul Gandhi have also tried to bridge the ever-widening gap between the JD-U and RJD but in vain.The JD-U has made abundantly clear that Nitish Kumar\'s taintless image is more important to the party than sticking with power. "Nitish is the leader of Mahagathbandhan, no one else. Those who are threatening of having 80 MLAs with them should not be in any kind of confusion. It will not take us even 5 minutes to quit government, power," JD-U spokesperson Ajay Alok had told India Today.The Janata Dal (United) has 71 MLAs, while Lalu\'s RJD has 80 seats\xa0 in the 243-seat Bihar Assembly.\xa0 ALSO READ:Nitish Kumar calls meeting of JD-U MLAs, pressure mounts further on Tejashwi YadavRevealed: What Tejashwi Yadav told Nitish Kumar in their 45-minute meeting behind closed doors'

# %%
pre = pd.DataFrame()
pre['text'] = pd.concat([pre1['text'], pre2['text']], ignore_index=True)
pre['summary'] = pd.concat([pre1['headlines'],pre2['headlines']],ignore_index = True)

# %%
pre.head()
# Out:
#                                                 text  \
# 0  Saurav Kant, an alumnus of upGrad and IIIT-B's...
# 1  Kunal Shah's credit card bill payment platform...
# 2  New Zealand defeated India by 8 wickets in the...
# 3  With Aegon Life iTerm Insurance plan, customer...
# 4  Speaking about the sexual harassment allegatio...
#
#                                              summary
# 0  upGrad learner switches to career in ML & Al w...
# 1  Delhi techie wins free food from Swiggy for on...
# 2  New Zealand end Rohit Sharma-led India's 12-ma...
# 3  Aegon life iTerm insurance plan helps customer...
# 4  Have known Hirani for yrs, what if MeToo claim...

# %%
pre['text'][:10]
# Out:
# 0    Saurav Kant, an alumnus of upGrad and IIIT-B's...
# 1    Kunal Shah's credit card bill payment platform...
# 2    New Zealand defeated India by 8 wickets in the...
# 3    With Aegon Life iTerm Insurance plan, customer...
# 4    Speaking about the sexual harassment allegatio...
# 5    Pakistani singer Rahat Fateh Ali Khan has deni...
# 6    India recorded their lowest ODI total in New Z...
# 7    Weeks after ex-CBI Director Alok Verma told th...
# 8    Andhra Pradesh CM N Chandrababu Naidu has said...
# 9    Congress candidate Shafia Zubair won the Ramga...
# Name: text, dtype: object

# %%
# Cleaning Operations:

'''1.Remove Special Characters: Handles unwanted symbols like tabs (\t), carriage returns (\r), and newlines (\n).
2.Normalize Case: Converts text to lowercase.
3.Handle Redundant Patterns: Replaces multiple underscores, dashes, tildes, and other repeated symbols with spaces.
4.Sanitize URLs: Extracts and retains the domain name, removing the rest of the URL.
5.Replace Identifiable Patterns:
6.Replaces sequences like "INC1234" or "CM1234" with placeholders (INC_NUM, CM_NUM).
7.Remove Extraneous Characters: Removes brackets, quotes, and non-alphanumeric symbols.
8.Reduce Redundant Spaces: Consolidates multiple spaces into a single space.'''
# Out:
# '1.Remove Special Characters: Handles unwanted symbols like tabs (\t), carriage returns (\r), and newlines (\n).\n2.Normalize Case: Converts text to lowercase.\n3.Handle Redundant Patterns: Replaces multiple underscores, dashes, tildes, and other repeated symbols with spaces.\n4.Sanitize URLs: Extracts and retains the domain name, removing the rest of the URL.\n5.Replace Identifiable Patterns:\n6.Replaces sequences like "INC1234" or "CM1234" with placeholders (INC_NUM, CM_NUM).\n7.Remove Extraneous Characters: Removes brackets, quotes, and non-alphanumeric symbols.\n8.Reduce Redundant Spaces: Consolidates multiple spaces into a single space.'

# %%
'''import re 
def text_strip(column):

  for row in column:    
    row=re.sub("(\\t)", ' ', str(row)).lower() 
    row=re.sub("(\\r)", ' ', str(row)).lower() 
    row=re.sub("(\\n)", ' ', str(row)).lower()
    
    row=re.sub("(__+)", ' ', str(row)).lower()   
    row=re.sub("(--+)", ' ', str(row)).lower()   
    row=re.sub("(~~+)", ' ', str(row)).lower()   
    row=re.sub("(\+\++)", ' ', str(row)).lower()   
    row=re.sub("(\.\.+)", ' ', str(row)).lower()  
    
    row=re.sub(r"[<>()|&©ø\[\]\'\",;?~*!]", ' ', str(row)).lower() 
    
    row=re.sub("(mailto:)", ' ', str(row)).lower() 
    row=re.sub(r"(\\x9\d)", ' ', str(row)).lower() 
    row=re.sub("([iI][nN][cC]\d+)", 'INC_NUM', str(row)).lower() 
    row=re.sub("([cC][mM]\d+)|([cC][hH][gG]\d+)", 'CM_NUM', str(row)).lower() 
    
    
    row=re.sub("(\.\s+)", ' ', str(row)).lower() 
    row=re.sub("(\-\s+)", ' ', str(row)).lower() 
    row=re.sub("(\:\s+)", ' ', str(row)).lower() 
    
    row=re.sub("(\s+.\s+)", ' ', str(row)).lower() 

    # to replace an url
    try:
        url = re.search(r'((https*:\/*)([^\/\s]+))(.[^\s]+)', str(row))
        repl_url = url.group(3)
        row = re.sub(r'((https*:\/*)([^\/\s]+))(.[^\s]+)',repl_url, str(row))
    except:
        pass
    

    
    row = re.sub("(\s+)",' ',str(row)).lower() #remove multiple spaces
    
    row=re.sub("(\s+.\s+)", ' ', str(row)).lower()

    
    
    yield row

      '''
# Out:
# 'import re \ndef text_strip(column):\n\n  for row in column:    \n    row=re.sub("(\\t)", \' \', str(row)).lower() \n    row=re.sub("(\\r)", \' \', str(row)).lower() \n    row=re.sub("(\\n)", \' \', str(row)).lower()\n    \n    row=re.sub("(__+)", \' \', str(row)).lower()   \n    row=re.sub("(--+)", \' \', str(row)).lower()   \n    row=re.sub("(~~+)", \' \', str(row)).lower()   \n    row=re.sub("(\\+\\++)", \' \', str(row)).lower()   \n    row=re.sub("(\\.\\.+)", \' \', str(row)).lower()  \n    \n    row=re.sub(r"[<>()|&©ø\\[\\]\'",;?~*!]", \' \', str(row)).lower() \n    \n    row=re.sub("(mailto:)", \' \', str(row)).lower() \n    row=re.sub(r"(\\x9\\d)", \' \', str(row)).lower() \n    row=re.sub("([iI][nN][cC]\\d+)", \'INC_NUM\', str(row)).lower() \n    row=re.sub("([cC][mM]\\d+)|([cC][hH][gG]\\d+)", \'CM_NUM\', str(row)).lower() \n    \n    \n    row=re.sub("(\\.\\s+)", \' \', str(row)).lower() \n    row=re.sub("(\\-\\s+)", \' \', str(row)).lower() \n    row=re.sub("(\\:\\s+)", \' \', str(row)).lower() \n    \n    row=re.sub("(\\s+.\\s+)", \' \', str(row)).lower() \n\n    # to replace an url\n    try:\n        url = re.search(r\'((https*:\\/*)([^\\/\\s]+))(.[^\\s]+)\', str(row))\n        repl_url = url.group(3)\n        row = re.sub(r\'((https*:\\/*)([^\\/\\s]+))(.[^\\s]+)\',repl_url, str(row))\n    except:\n        pass\n    \n\n    \n    row = re.sub("(\\s+)",\' \',str(row)).lower() #remove multiple spaces\n    \n    row=re.sub("(\\s+.\\s+)", \' \', str(row)).lower()\n\n    \n    \n    yield row\n\n      '

# %%
import re
import nltk
from nltk.corpus import stopwords

# Download the NLTK stopwords (you only need to do this once)
nltk.download('stopwords')

# Get the list of English stopwords
stop_words = set(stopwords.words('english'))

def text_strip(column):
    for row in column:
        # Basic cleaning
        row = re.sub("(\\t)", ' ', str(row)).lower()
        row = re.sub("(\\r)", ' ', str(row)).lower()
        row = re.sub("(\\n)", ' ', str(row)).lower()

        # More cleaning rules
        row = re.sub("(__+)", ' ', str(row)).lower()
        row = re.sub("(--+)", ' ', str(row)).lower()
        row = re.sub("(~~+)", ' ', str(row)).lower()
        row = re.sub("(\+\++)", ' ', str(row)).lower()
        row = re.sub("(\.\.+)", ' ', str(row)).lower()

        row = re.sub(r"[<>()|&©ø\[\]\'\",;?~*!]", ' ', str(row)).lower()

        row = re.sub("(mailto:)", ' ', str(row)).lower()
        row = re.sub(r"(\\x9\d)", ' ', str(row)).lower()
        row = re.sub("([iI][nN][cC]\d+)", 'INC_NUM', str(row)).lower()
        row = re.sub("([cC][mM]\d+)|([cC][hH][gG]\d+)", 'CM_NUM', str(row)).lower()

        row = re.sub("(\.\s+)", ' ', str(row)).lower()
        row = re.sub("(\-\s+)", ' ', str(row)).lower()
        row = re.sub("(\:\s+)", ' ', str(row)).lower()

        row = re.sub("(\s+.\s+)", ' ', str(row)).lower()

        # Replace URLs
        try:
            url = re.search(r'((https*:\/*)([^\/\s]+))(.[^\s]+)', str(row))
            repl_url = url.group(3)
            row = re.sub(r'((https*:\/*)([^\/\s]+))(.[^\s]+)', repl_url, str(row))
        except:
            pass

        row = re.sub("(\s+)", ' ', str(row)).lower()  # Remove multiple spaces
        row = re.sub("(\s+.\s+)", ' ', str(row)).lower()

        # Remove stopwords
        row = ' '.join([word for word in row.split() if word not in stop_words])

        # Yield the cleaned text row
        yield row
# Out:
# [nltk_data] Downloading package stopwords to /usr/share/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
# Count the number of words in the 'text' and 'summary' columns before preprocessing
pre['text_word_count_before'] = pre['text'].apply(lambda x: len(str(x).split()))
pre['summary_word_count_before'] = pre['summary'].apply(lambda x: len(str(x).split()))

# Calculate total word count before preprocessing
total_text_words_before = pre['text_word_count_before'].sum()
total_summary_words_before = pre['summary_word_count_before'].sum()

print(f'Total words in text before preprocessing: {total_text_words_before}')
print(f'Total words in summary before preprocessing: {total_summary_words_before}')
# Out:
# Total words in text before preprocessing: 5993839
# Total words in summary before preprocessing: 982067

# %%
# Apply the preprocessing function to 'text' and 'summary' columns
pre['text_preprocessed'] = list(text_strip(pre['text']))
pre['summary_preprocessed'] = list(text_strip(pre['summary']))

# Count the number of words in the preprocessed columns
pre['text_word_count_after'] = pre['text_preprocessed'].apply(lambda x: len(str(x).split()))
pre['summary_word_count_after'] = pre['summary_preprocessed'].apply(lambda x: len(str(x).split()))

# Calculate total word count after preprocessing
total_text_words_after = pre['text_word_count_after'].sum()
total_summary_words_after = pre['summary_word_count_after'].sum()

print(f'Total words in text after preprocessing: {total_text_words_after}')
print(f'Total words in summary after preprocessing: {total_summary_words_after}')
# Out:
# Total words in text after preprocessing: 3698105
# Total words in summary after preprocessing: 751246

# %%
pre
# Out:
#                                                      text  \
# 0       Saurav Kant, an alumnus of upGrad and IIIT-B's...
# 1       Kunal Shah's credit card bill payment platform...
# 2       New Zealand defeated India by 8 wickets in the...
# 3       With Aegon Life iTerm Insurance plan, customer...
# 4       Speaking about the sexual harassment allegatio...
# ...                                                   ...
# 102910  Fruit juice concentrate maker Rasna is eyeing ...
# 102911  Former Indian cricketer Sachin Tendulkar atten...
# 102912  Aamir Khan, while talking about reality shows ...
# 102913  The Maharashtra government has initiated an in...
# 102914  At least 400 languages or more than half langu...
#
#                                                   summary  \
# 0       upGrad learner switches to career in ML & Al w...
# 1       Delhi techie wins free food from Swiggy for on...
# 2       New Zealand end Rohit Sharma-led India's 12-ma...
# 3       Aegon life iTerm insurance plan helps customer...
# 4       Have known Hirani for yrs, what if MeToo claim...
# ...                                                   ...
# 102910  Rasna seeking ?250 cr revenue from snack categ...
# 102911  Sachin attends Rajya Sabha after questions on ...
# 102912  Shouldn't rob their childhood: Aamir on kids r...
# 102913  Asha Bhosle gets ?53,000 power bill for unused...
# 102914  More than half of India's languages may die in...
#
#         text_word_count_before  summary_word_count_before  \
# 0                           60                         13
# 1                           60                         12
# 2                           60                          9
# 3                           60                          9
# 4                           60                         13
# ...                        ...                        ...
# 102910                      60                          9
# 102911                      60                          8
# 102912                      59                          9
# 102913                      59                          9
# 102914                      60                         11
#
#                                         text_preprocessed  \
# 0       saurav kant alumnus upgrad iiit-b pg program m...
# 1       kunal shah credit card bill payment platform c...
# 2       new zealand defeated india wickets fourth odi ...
# 3       aegon life iterm insurance plan customers enjo...
# 4       speaking sexual harassment allegations rajkuma...
# ...                                                   ...
# 102910  fruit juice concentrate maker rasna eyeing rev...
# 102911  former indian cricketer sachin tendulkar atten...
# 102912  aamir khan talking reality shows television fe...
# 102913  maharashtra government initiated inquiry 83-ye...
# 102914  least 400 languages half languages spoken indi...
#
#                                      summary_preprocessed  \
# 0       upgrad learner switches career ml al 90% salar...
# 1        delhi techie wins free food swiggy one year cred
# 2       new zealand end rohit sharma-led india 12-matc...
# 3       aegon life iterm insurance plan helps customer...
# 4                known hirani yrs metoo claims true sonam
# ...                                                   ...
# 102910  rasna seeking 250 cr revenue snack category ch...
# 102911    sachin attends rajya sabha questions attendance
# 102912             rob childhood aamir kids reality shows
# 102913  asha bhosle gets 53 000 power bill unused bung...
# 102914          half india languages may die 50yrs survey
#
#         text_word_count_after  summary_word_count_after
# 0                          40                         9
# 1                          46                         9
# 2                          40                         9
# 3                          38                         9
# 4                          34                         7
# ...                       ...                       ...
# 102910                     41                         8
# 102911                     39                         6
# 102912                     28                         6
# 102913                     35                         9
# 102914                     39                         7
#
# [102915 rows x 8 columns]

# %%
pre['text_preprocessed'][0]
# Out:
# 'saurav kant alumnus upgrad iiit-b pg program machine learning artificial intelligence sr systems engineer infosys almost years work experience program upgrad 360-degree career support helped transition data scientist tech mahindra 90% salary hike upgrad online power learning powered lakh+ careers.'

# %%
pre['summary_preprocessed'][0]
# Out:
# 'upgrad learner switches career ml al 90% salary hike'

# %%
brief_cleaning1 = text_strip(pre['text'])
brief_cleaning2 = text_strip(pre['summary'])

# %%
print(brief_cleaning1)
# Out:
# <generator object text_strip at 0x7cf407a1f6f0>

# %%
# 1. Maximum Sentence Length Before and After Preprocessing
# Maximum sentence length before preprocessing
pre['sentence_length_before'] = pre['text'].apply(lambda x: len(str(x).split()))
max_sentence_length_before = pre['sentence_length_before'].max()

# Maximum sentence length after preprocessing
pre['sentence_length_after'] = pre['text_preprocessed'].apply(lambda x: len(str(x).split()))
max_sentence_length_after = pre['sentence_length_after'].max()

print(f'Maximum sentence length before preprocessing: {max_sentence_length_before}')
print(f'Maximum sentence length after preprocessing: {max_sentence_length_after}')
# Out:
# Maximum sentence length before preprocessing: 91
# Maximum sentence length after preprocessing: 65

# %%
# 2. Most Frequent Words Before and After Preprocessing

from collections import Counter

# Tokenize words before preprocessing and count their frequencies
words_before = ' '.join(pre['text']).split()
word_counts_before = Counter(words_before)

# Tokenize words after preprocessing and count their frequencies
words_after = ' '.join(pre['text_preprocessed']).split()
word_counts_after = Counter(words_after)

# Get the most common words (top 10 most frequent)
most_common_before = word_counts_before.most_common(10)
most_common_after = word_counts_after.most_common(10)

print(f'Most frequent words before preprocessing: {most_common_before}')
print(f'Most frequent words after preprocessing: {most_common_after}')
# Out:
# Most frequent words before preprocessing: [('the', 283966), ('to', 150894), ('in', 130800), ('a', 128658), ('of', 126737), ('and', 111113), ('on', 73823), ('The', 65433), ('has', 58972), ('for', 57700)]
# Most frequent words after preprocessing: [('said', 52517), ('india', 18248), ('also', 15016), ('added', 14291), ('us', 13094), ('police', 11577), ('government', 11412), ('people', 11225), ('first', 10954), ('indian', 10465)]

# %%
# 3. Most Frequent N-Grams (Bigrams or Trigrams) Before and After Preprocessing

from sklearn.feature_extraction.text import CountVectorizer

# Function to get the most frequent n-grams
def get_most_frequent_ngrams(text_data, n=2, top_n=10):
    vectorizer = CountVectorizer(ngram_range=(n, n), stop_words='english')
    ngram_matrix = vectorizer.fit_transform(text_data)
    ngram_counts = Counter(zip(*ngram_matrix.nonzero()))
    ngram_freq = {ngram: count for ngram, count in ngram_counts.items()}
    return Counter(ngram_freq).most_common(top_n)

# Get top 10 frequent bigrams before preprocessing
top_bigrams_before = get_most_frequent_ngrams(pre['text'], n=2)

# Get top 10 frequent bigrams after preprocessing
top_bigrams_after = get_most_frequent_ngrams(pre['text_preprocessed'], n=2)

print(f'Top 10 frequent bigrams before preprocessing: {top_bigrams_before}')
print(f'Top 10 frequent bigrams after preprocessing: {top_bigrams_after}')
# Out:
# Top 10 frequent bigrams before preprocessing: [((0, 1377967), 1), ((0, 850080), 1), ((0, 122104), 1), ((0, 1649092), 1), ((0, 763930), 1), ((0, 1155594), 1), ((0, 1222810), 1), ((0, 943862), 1), ((0, 901199), 1), ((0, 154257), 1)]
# Top 10 frequent bigrams after preprocessing: [((0, 1370958), 1), ((0, 843500), 1), ((0, 122259), 1), ((0, 1642124), 1), ((0, 758879), 1), ((0, 1148444), 1), ((0, 1215660), 1), ((0, 936593), 1), ((0, 894634), 1), ((0, 154243), 1)]

# %%
# 4. Average Sentence Length Before and After Preprocessing

# Average sentence length before preprocessing
avg_sentence_length_before = pre['sentence_length_before'].mean()

# Average sentence length after preprocessing
avg_sentence_length_after = pre['sentence_length_after'].mean()

print(f'Average sentence length before preprocessing: {avg_sentence_length_before}')
print(f'Average sentence length after preprocessing: {avg_sentence_length_after}')
# Out:
# Average sentence length before preprocessing: 58.24067434290434
# Average sentence length after preprocessing: 35.933585969003545

# %%
# 5. Word Count Before and After Preprocessing

# Total word count before preprocessing
total_word_count_before = pre['text'].apply(lambda x: len(str(x).split())).sum()

# Total word count after preprocessing
total_word_count_after = pre['text_preprocessed'].apply(lambda x: len(str(x).split())).sum()

print(f'Total word count before preprocessing: {total_word_count_before}')
print(f'Total word count after preprocessing: {total_word_count_after}')
# Out:
# Total word count before preprocessing: 5993839
# Total word count after preprocessing: 3698105

# %%
# 6. Unique Words Before and After Preprocessing

# Unique words before preprocessing
unique_words_before = len(set(words_before))

# Unique words after preprocessing
unique_words_after = len(set(words_after))

print(f'Unique words before preprocessing: {unique_words_before}')
print(f'Unique words after preprocessing: {unique_words_after}')
# Out:
# Unique words before preprocessing: 251170
# Unique words after preprocessing: 121326

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Create a figure with two subplots
plt.figure(figsize=(12, 6))

# Subplot 1: Before Preprocessing
plt.subplot(1, 2, 1)  # (rows, columns, index)
sns.histplot(pre['sentence_length_before'], color='blue', kde=True, stat='density', linewidth=2)
plt.title('Sentence Length Distribution Before Preprocessing')
plt.xlabel('Sentence Length (words)')
plt.ylabel('Density')

# Subplot 2: After Preprocessing
plt.subplot(1, 2, 2)  # (rows, columns, index)
sns.histplot(pre['sentence_length_after'], color='red', kde=True, stat='density', linewidth=2)
plt.title('Sentence Length Distribution After Preprocessing')
plt.xlabel('Sentence Length (words)')
plt.ylabel('Density')

# Show the plot
plt.tight_layout()  # Adjust layout to prevent overlap
plt.show()
# Out:
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
# 8. Character Length of Sentences (Before and After Preprocessing)

# Calculate character length of sentences before preprocessing
pre['char_length_before'] = pre['text'].apply(lambda x: len(str(x)))

# Calculate character length of sentences after preprocessing
pre['char_length_after'] = pre['text_preprocessed'].apply(lambda x: len(str(x)))

# Max character length before and after preprocessing
max_char_length_before = pre['char_length_before'].max()
max_char_length_after = pre['char_length_after'].max()

print(f'Max character length before preprocessing: {max_char_length_before}')
print(f'Max character length after preprocessing: {max_char_length_after}')
# Out:
# Max character length before preprocessing: 513
# Max character length after preprocessing: 410

# %%
from time import time
import spacy
nlp = spacy.load('en_core_web_sm', disable=['ner', 'parser']) 

t = time()
#spacy has the pipe method to increase the speed of prepocessing
#we need it because we are removing the urls and all the stuff from nearly 100k rows
text = [str(doc) for doc in nlp.pipe(brief_cleaning1, batch_size=5000)]

print('Time to clean up everything: {} mins'.format(round((time() - t) / 60, 2)))
# Out:
# Time to clean up everything: 4.27 mins

# %%
t = time()

summary = ['SOS '+ str(doc) + ' EOS' for doc in nlp.pipe(brief_cleaning2, batch_size=5000)]
print('Time to clean up everything: {} mins'.format(round((time() - t) / 60, 2)))
# Out:
# Time to clean up everything: 0.9 mins

# %%
text[0]
# Out:
# 'saurav kant alumnus upgrad iiit-b pg program machine learning artificial intelligence sr systems engineer infosys almost years work experience program upgrad 360-degree career support helped transition data scientist tech mahindra 90% salary hike upgrad online power learning powered lakh+ careers.'

# %%
summary[0]
# Out:
# 'SOS upgrad learner switches career ml al 90% salary hike EOS'

# %%
pre['cleaned_text'] = pd.Series(text)
pre['cleaned_summary'] = pd.Series(summary)

# %%
text_count = []
summary_count = []

# %%
for sent in pre['cleaned_text']:
    text_count.append(len(sent.split()))
for sent in pre['cleaned_summary']:
    summary_count.append(len(sent.split()))

# %%
graph_df= pd.DataFrame()
graph_df['text']=text_count
graph_df['summary']=summary_count

# %%
#Check how much % of summary have 0-15 words
cnt=0
for i in pre['cleaned_summary']:
    if(len(i.split())<=15):
        cnt=cnt+1
print(cnt/len(pre['cleaned_summary']))
# Out:
# 1.0

# %%
#Check how much % of text have 0-60 words
cnt=0
for i in pre['cleaned_text']:
    if(len(i.split())<=60):
        cnt=cnt+1
print(cnt/len(pre['cleaned_text']))
# Out:
# 0.9999902832434533

# %%
max_text_len=65
max_summary_len=30

# %%
cleaned_text =np.array(pre['cleaned_text'])
cleaned_summary=np.array(pre['cleaned_summary'])

short_text=[]
short_summary=[]

for i in range(len(cleaned_text)):
    if(len(cleaned_summary[i].split())<=max_summary_len and len(cleaned_text[i].split())<=max_text_len):
        short_text.append(cleaned_text[i])
        short_summary.append(cleaned_summary[i])
        
post_pre=pd.DataFrame({'text':short_text,'summary':short_summary})

# %%
post_pre.head(2)
# Out:
#                                                 text  \
# 0  saurav kant alumnus upgrad iiit-b pg program m...
# 1  kunal shah credit card bill payment platform c...
#
#                                              summary
# 0  SOS upgrad learner switches career ml al 90% s...
# 1  SOS delhi techie wins free food swiggy one yea...

# %%
post_pre['summary'] = post_pre['summary'].apply(lambda x : 'sostok '+ x + ' eostok')

# %%
from sklearn.model_selection import train_test_split
x_tr,x_val,y_tr,y_val=train_test_split(np.array(post_pre['text']),np.array(post_pre['summary']),test_size=0.1,random_state=0,shuffle=True)

# %%
from tensorflow.keras.preprocessing.text import Tokenizer 
from tensorflow.keras.preprocessing.sequence import pad_sequences

x_tokenizer = Tokenizer() 
x_tokenizer.fit_on_texts(list(x_tr))

# %%
thresh_hold=4

cnt=0
tot_cnt=0
freq=0
tot_freq=0

for key,value in x_tokenizer.word_counts.items():
    tot_cnt=tot_cnt+1
    tot_freq=tot_freq+value
    if(value<thresh_hold):
        cnt=cnt+1
        freq=freq+value
    
print("% of rare words in vocabulary:",(cnt/tot_cnt)*100)
print("Total Coverage of rare words:",(freq/tot_freq)*100)
# Out:
# % of rare words in vocabulary: 57.41433918802188
# Total Coverage of rare words: 2.0126089404339784

# %%
x_tokenizer = Tokenizer(num_words=tot_cnt-cnt) 
x_tokenizer.fit_on_texts(list(x_tr))

#convert text sequences into integer sequences (i.e one-hot encodeing all the words)
x_tr_seq    =   x_tokenizer.texts_to_sequences(x_tr) 
x_val_seq   =   x_tokenizer.texts_to_sequences(x_val)

#padding zero upto maximum length
x_tr    =   pad_sequences(x_tr_seq,  maxlen=max_text_len, padding='post')
x_val   =   pad_sequences(x_val_seq, maxlen=max_text_len, padding='post')

#size of vocabulary ( +1 for padding token)
x_voc   =  x_tokenizer.num_words + 1

print("Size of vocabulary in X = {}".format(x_voc))
# Out:
# Size of vocabulary in X = 34018

# %%
y_tokenizer = Tokenizer()   
y_tokenizer.fit_on_texts(list(y_tr))

# %%
thresh_hold=6

cnt=0
tot_cnt=0
freq=0
tot_freq=0

for key,value in y_tokenizer.word_counts.items():
    tot_cnt=tot_cnt+1
    tot_freq=tot_freq+value
    if(value<thresh_hold):
        cnt=cnt+1
        freq=freq+value
    
print("% of rare words in vocabulary:",(cnt/tot_cnt)*100)
print("Total Coverage of rare words:",(freq/tot_freq)*100)
# Out:
# % of rare words in vocabulary: 66.0056657223796
# Total Coverage of rare words: 4.071763353005182

# %%
y_tokenizer = Tokenizer(num_words=tot_cnt-cnt) 
y_tokenizer.fit_on_texts(list(y_tr))

#convert text sequences into integer sequences (i.e one hot encode the text in Y)
y_tr_seq    =   y_tokenizer.texts_to_sequences(y_tr) 
y_val_seq   =   y_tokenizer.texts_to_sequences(y_val) 

#padding zero upto maximum length
y_tr    =   pad_sequences(y_tr_seq, maxlen=max_summary_len, padding='post')
y_val   =   pad_sequences(y_val_seq, maxlen=max_summary_len, padding='post')

#size of vocabulary
y_voc  =   y_tokenizer.num_words +1
print("Size of vocabulary in Y = {}".format(y_voc))
# Out:
# Size of vocabulary in Y = 11761

# %%
ind=[]
for i in range(len(y_tr)):
    cnt=0
    for j in y_tr[i]:
        if j!=0:
            cnt=cnt+1
    if(cnt==2):
        ind.append(i)

y_tr=np.delete(y_tr,ind, axis=0)
x_tr=np.delete(x_tr,ind, axis=0)

# %%
ind=[]
for i in range(len(y_val)):
    cnt=0
    for j in y_val[i]:
        if j!=0:
            cnt=cnt+1
    if(cnt==2):
        ind.append(i)

y_val=np.delete(y_val,ind, axis=0)
x_val=np.delete(x_val,ind, axis=0)

# %%
from keras import backend as K 
import gensim
from numpy import *
import numpy as np
import pandas as pd 
import re
from bs4 import BeautifulSoup
from tensorflow.keras.preprocessing.text import Tokenizer 
from tensorflow.keras.preprocessing.sequence import pad_sequences
from nltk.corpus import stopwords
from tensorflow.keras.layers import Input, LSTM, Embedding, Dense, Concatenate, TimeDistributed
from tensorflow.keras.models import Model
from tensorflow.keras.callbacks import EarlyStopping
import warnings
pd.set_option("display.max_colwidth", 200)
warnings.filterwarnings("ignore")

print("Size of vocabulary from the w2v model = {}".format(x_voc))

K.clear_session()

latent_dim = 300
embedding_dim=200

# Encoder
encoder_inputs = Input(shape=(max_text_len,))

#embedding layer
enc_emb =  Embedding(x_voc, embedding_dim,trainable=True)(encoder_inputs)

#encoder lstm 1
encoder_lstm1 = LSTM(latent_dim,return_sequences=True,return_state=True,dropout=0.4,recurrent_dropout=0.4)
encoder_output1, state_h1, state_c1 = encoder_lstm1(enc_emb)

#encoder lstm 2
encoder_lstm2 = LSTM(latent_dim,return_sequences=True,return_state=True,dropout=0.4,recurrent_dropout=0.4)
encoder_output2, state_h2, state_c2 = encoder_lstm2(encoder_output1)

#encoder lstm 3
encoder_lstm3=LSTM(latent_dim, return_state=True, return_sequences=True,dropout=0.4,recurrent_dropout=0.4)
encoder_outputs, state_h, state_c= encoder_lstm3(encoder_output2)

# Set up the decoder, using `encoder_states` as initial state.
decoder_inputs = Input(shape=(None,))

#embedding layer
dec_emb_layer = Embedding(y_voc, embedding_dim,trainable=True)
dec_emb = dec_emb_layer(decoder_inputs)

decoder_lstm = LSTM(latent_dim, return_sequences=True, return_state=True,dropout=0.4,recurrent_dropout=0.2)
decoder_outputs,decoder_fwd_state, decoder_back_state = decoder_lstm(dec_emb,initial_state=[state_h, state_c])

#dense layer
decoder_dense =  TimeDistributed(Dense(y_voc, activation='softmax'))
decoder_outputs = decoder_dense(decoder_outputs)

# Define the model 
model = Model([encoder_inputs, decoder_inputs], decoder_outputs)

model.summary()
# Out:
# Size of vocabulary from the w2v model = 34018
# Model: "functional_1"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer         │ (None, 65)        │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ embedding           │ (None, 65, 200)   │  6,803,600 │ input_layer[0][0] │
# │ (Embedding)         │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ lstm (LSTM)         │ [(None, 65, 300), │    601,200 │ embedding[0][0]   │
# │                     │ (None, 300),      │            │                   │
# │                     │ (None, 300)]      │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ input_layer_1       │ (None, None)      │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ lstm_1 (LSTM)       │ [(None, 65, 300), │    721,200 │ lstm[0][0]        │
# │                     │ (None, 300),      │            │                   │
# │                     │ (None, 300)]      │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ embedding_1         │ (None, None, 200) │  2,352,200 │ input_layer_1[0]… │
# │ (Embedding)         │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ lstm_2 (LSTM)       │ [(None, 65, 300), │    721,200 │ lstm_1[0][0]      │
# │                     │ (None, 300),      │            │                   │
# │                     │ (None, 300)]      │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ lstm_3 (LSTM)       │ [(None, None,     │    601,200 │ embedding_1[0][0… │
# │                     │ 300), (None,      │            │ lstm_2[0][1],     │
# │                     │ 300), (None,      │            │ lstm_2[0][2]      │
# │                     │ 300)]             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ time_distributed    │ (None, None,      │  3,540,061 │ lstm_3[0][0]      │
# │ (TimeDistributed)   │ 11761)            │            │                   │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 15,340,661 (58.52 MB)
#  Trainable params: 15,340,661 (58.52 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
model.compile(optimizer='rmsprop', loss='sparse_categorical_crossentropy',metrics=['accuracy'])
es = EarlyStopping(monitor='val_loss', mode='min', verbose=1,patience=2)

# %%
history=model.fit([x_tr,y_tr[:,:-1]], y_tr.reshape(y_tr.shape[0],y_tr.shape[1], 1)[:,1:] ,epochs=50,callbacks=[es],batch_size=128, validation_data=([x_val,y_val[:,:-1]], y_val.reshape(y_val.shape[0],y_val.shape[1], 1)[:,1:]))
# Out:
# Epoch 1/50
# 724/724 ━━━━━━━━━━━━━━━━━━━━ 260s 345ms/step - accuracy: 0.7175 - loss: 2.6447 - val_accuracy: 0.7595 - val_loss: 2.0475
# Epoch 2/50
# 724/724 ━━━━━━━━━━━━━━━━━━━━ 249s 343ms/step - accuracy: 0.7582 - loss: 2.0597 - val_accuracy: 0.7593 - val_loss: 2.0410
# Epoch 3/50
# 724/724 ━━━━━━━━━━━━━━━━━━━━ 249s 344ms/step - accuracy: 0.7580 - loss: 2.0541 - val_accuracy: 0.7593 - val_loss: 2.0381
# Epoch 4/50
# 724/724 ━━━━━━━━━━━━━━━━━━━━ 248s 343ms/step - accuracy: 0.7581 - loss: 2.0486 - val_accuracy: 0.7600 - val_loss: 2.0280
# Epoch 5/50
# 724/724 ━━━━━━━━━━━━━━━━━━━━ 249s 344ms/step - accuracy: 0.7587 - loss: 2.0388 - val_accuracy: 0.7602 - val_loss: 2.0222
# Epoch 6/50
# 724/724 ━━━━━━━━━━━━━━━━━━━━ 248s 342ms/step - accuracy: 0.7590 - loss: 2.0312 - val_accuracy: 0.7606 - val_loss: 2.0104
# Epoch 7/50
# 724/724 ━━━━━━━━━━━━━━━━━━━━ 247s 342ms/step - accuracy: 0.7594 - loss: 2.0161 - val_accuracy: 0.7606 - val_loss: 2.0051
# Epoch 8/50
# 724/724 ━━━━━━━━━━━━━━━━━━━━ 249s 343ms/step - accuracy: 0.7594 - loss: 2.0063 - val_accuracy: 0.7612 - val_loss: 1.9899
# Epoch 9/50
# 724/724 ━━━━━━━━━━━━━━━━━━━━ 248s 343ms/step - accuracy: 0.7593 - loss: 1.9981 - val_accuracy: 0.7617 - val_loss: 1.9714
# Epoch 10/50
# 724/724 ━━━━━━━━━━━━━━━━━━━━ 248s 343ms/step - accuracy: 0.7602 - loss: 1.9702 - val_accuracy: 0.7620 - val_loss: 1.9473
# Epoch 11/50
# 724/724 ━━━━━━━━━━━━━━━━━━━━ 247s 342ms/step - accuracy: 0.7606 - loss: 1.9447 - val_accuracy: 0.7622 - val_loss: 1.9263
# Epoch 12/50
# 724/724 ━━━━━━━━━━━━━━━━━━━━ 248s 343ms/step - accuracy: 0.7609 - loss: 1.9287 - val_accuracy: 0.7628 - val_loss: 1.9121
# Epoch 13/50
# 724/724 ━━━━━━━━━━━━━━━━━━━━ 248s 343ms/step - accuracy: 0.7609 - loss: 1.9134 - val_accuracy: 0.7632 - val_loss: 1.8960
# Epoch 14/50
# 724/724 ━━━━━━━━━━━━━━━━━━━━ 248s 343ms/step - accuracy: 0.7622 - loss: 1.8874 - val_accuracy: 0.7647 - val_loss: 1.8652
# Epoch 15/50
# 724/724 ━━━━━━━━━━━━━━━━━━━━ 248s 342ms/step - accuracy: 0.7631 - loss: 1.8610 - val_accuracy: 0.7658 - val_loss: 1.8404
# Epoch 16/50
# 724/724 ━━━━━━━━━━━━━━━━━━━━ 249s 344ms/step - accuracy: 0.7640 - loss: 1.8362 - val_accuracy: 0.7662 - val_loss: 1.8195
# Epoch 17/50
# 724/724 ━━━━━━━━━━━━━━━━━━━━ 249s 344ms/step - accuracy: 0.7648 - loss: 1.8138 - val_accuracy: 0.7672 - val_loss: 1.7973
# Epoch 18/50
# 724/724 ━━━━━━━━━━━━━━━━━━━━ 248s 342ms/step - accuracy: 0.7655 - loss: 1.7927 - val_accuracy: 0.7680 - val_loss: 1.7782
# Epoch 19/50
# 724/724 ━━━━━━━━━━━━━━━━━━━━ 247s 342ms/step - accuracy: 0.7666 - loss: 1.7697 - val_accuracy: 0.7689 - val_loss: 1.7596
# Epoch 20/50
# 724/724 ━━━━━━━━━━━━━━━━━━━━ 248s 342ms/step - accuracy: 0.7671 - loss: 1.7493 - val_accuracy: 0.7694 - val_loss: 1.7416
# Epoch 21/50
# 724/724 ━━━━━━━━━━━━━━━━━━━━ 248s 343ms/step - accuracy: 0.7681 - loss: 1.7292 - val_accuracy: 0.7699 - val_loss: 1.7259
# Epoch 22/50
# 724/724 ━━━━━━━━━━━━━━━━━━━━ 249s 344ms/step - accuracy: 0.7688 - loss: 1.7103 - val_accuracy: 0.7711 - val_loss: 1.7095
# Epoch 23/50
# 724/724 ━━━━━━━━━━━━━━━━━━━━ 249s 344ms/step - accuracy: 0.7696 - loss: 1.6938 - val_accuracy: 0.7721 - val_loss: 1.6913
# Epoch 24/50
# 724/724 ━━━━━━━━━━━━━━━━━━━━ 250s 345ms/step - accuracy: 0.7709 - loss: 1.6715 - val_accuracy: 0.7729 - val_loss: 1.6765
# Epoch 25/50
# 724/724 ━━━━━━━━━━━━━━━━━━━━ 248s 342ms/step - accuracy: 0.7717 - loss: 1.6561 - val_accuracy: 0.7738 - val_loss: 1.6622
# Epoch 26/50
# 724/724 ━━━━━━━━━━━━━━━━━━━━ 249s 344ms/step - accuracy: 0.7721 - loss: 1.6432 - val_accuracy: 0.7745 - val_loss: 1.6508
# Epoch 27/50
# 724/724 ━━━━━━━━━━━━━━━━━━━━ 249s 344ms/step - accuracy: 0.7732 - loss: 1.6258 - val_accuracy: 0.7755 - val_loss: 1.6386
# Epoch 28/50
# 724/724 ━━━━━━━━━━━━━━━━━━━━ 248s 343ms/step - accuracy: 0.7737 - loss: 1.6126 - val_accuracy: 0.7761 - val_loss: 1.6252
# Epoch 29/50
# 724/724 ━━━━━━━━━━━━━━━━━━━━ 249s 343ms/step - accuracy: 0.7743 - loss: 1.5994 - val_accuracy: 0.7768 - val_loss: 1.6159
# Epoch 30/50
# 724/724 ━━━━━━━━━━━━━━━━━━━━ 249s 343ms/step - accuracy: 0.7752 - loss: 1.5872 - val_accuracy: 0.7773 - val_loss: 1.6057
# Epoch 31/50
# 724/724 ━━━━━━━━━━━━━━━━━━━━ 248s 342ms/step - accuracy: 0.7764 - loss: 1.5719 - val_accuracy: 0.7779 - val_loss: 1.5964
# Epoch 32/50
# 724/724 ━━━━━━━━━━━━━━━━━━━━ 248s 343ms/step - accuracy: 0.7767 - loss: 1.5609 - val_accuracy: 0.7785 - val_loss: 1.5891
# Epoch 33/50
# 724/724 ━━━━━━━━━━━━━━━━━━━━ 249s 343ms/step - accuracy: 0.7772 - loss: 1.5489 - val_accuracy: 0.7790 - val_loss: 1.5798
# Epoch 34/50
# 724/724 ━━━━━━━━━━━━━━━━━━━━ 248s 342ms/step - accuracy: 0.7780 - loss: 1.5381 - val_accuracy: 0.7793 - val_loss: 1.5721
# Epoch 35/50
# 724/724 ━━━━━━━━━━━━━━━━━━━━ 248s 343ms/step - accuracy: 0.7786 - loss: 1.5270 - val_accuracy: 0.7804 - val_loss: 1.5630
# Epoch 36/50
# 724/724 ━━━━━━━━━━━━━━━━━━━━ 248s 343ms/step - accuracy: 0.7794 - loss: 1.5165 - val_accuracy: 0.7806 - val_loss: 1.5555
# Epoch 37/50
# 724/724 ━━━━━━━━━━━━━━━━━━━━ 247s 342ms/step - accuracy: 0.7798 - loss: 1.5066 - val_accuracy: 0.7811 - val_loss: 1.5498
# Epoch 38/50
# 724/724 ━━━━━━━━━━━━━━━━━━━━ 248s 342ms/step - accuracy: 0.7805 - loss: 1.4962 - val_accuracy: 0.7818 - val_loss: 1.5404
# Epoch 39/50
# 724/724 ━━━━━━━━━━━━━━━━━━━━ 248s 342ms/step - accuracy: 0.7811 - loss: 1.4868 - val_accuracy: 0.7824 - val_loss: 1.5336
# Epoch 40/50
# 724/724 ━━━━━━━━━━━━━━━━━━━━ 248s 342ms/step - accuracy: 0.7819 - loss: 1.4753 - val_accuracy: 0.7829 - val_loss: 1.5251
# Epoch 41/50
# 724/724 ━━━━━━━━━━━━━━━━━━━━ 249s 343ms/step - accuracy: 0.7821 - loss: 1.4674 - val_accuracy: 0.7835 - val_loss: 1.5197
# Epoch 42/50
# 724/724 ━━━━━━━━━━━━━━━━━━━━ 247s 342ms/step - accuracy: 0.7830 - loss: 1.4575 - val_accuracy: 0.7841 - val_loss: 1.5118
# Epoch 43/50
# 724/724 ━━━━━━━━━━━━━━━━━━━━ 249s 343ms/step - accuracy: 0.7838 - loss: 1.4466 - val_accuracy: 0.7842 - val_loss: 1.5070
# Epoch 44/50
# 724/724 ━━━━━━━━━━━━━━━━━━━━ 249s 344ms/step - accuracy: 0.7845 - loss: 1.4369 - val_accuracy: 0.7849 - val_loss: 1.5001
# Epoch 45/50
# 724/724 ━━━━━━━━━━━━━━━━━━━━ 250s 346ms/step - accuracy: 0.7848 - loss: 1.4295 - val_accuracy: 0.7852 - val_loss: 1.4944
# Epoch 46/50
# 724/724 ━━━━━━━━━━━━━━━━━━━━ 250s 345ms/step - accuracy: 0.7854 - loss: 1.4191 - val_accuracy: 0.7859 - val_loss: 1.4889
# Epoch 47/50
# 724/724 ━━━━━━━━━━━━━━━━━━━━ 248s 342ms/step - accuracy: 0.7860 - loss: 1.4120 - val_accuracy: 0.7855 - val_loss: 1.4846
# Epoch 48/50
# 724/724 ━━━━━━━━━━━━━━━━━━━━ 248s 343ms/step - accuracy: 0.7867 - loss: 1.4025 - val_accuracy: 0.7865 - val_loss: 1.4774
# Epoch 49/50
# 724/724 ━━━━━━━━━━━━━━━━━━━━ 248s 342ms/step - accuracy: 0.7871 - loss: 1.3955 - val_accuracy: 0.7871 - val_loss: 1.4718
# Epoch 50/50
# 724/724 ━━━━━━━━━━━━━━━━━━━━ 248s 342ms/step - accuracy: 0.7874 - loss: 1.3894 - val_accuracy: 0.7874 - val_loss: 1.4667

# %%
from matplotlib import pyplot
pyplot.plot(history.history['loss'], label='train')
pyplot.plot(history.history['val_loss'], label='test')
pyplot.legend()
pyplot.show()

# %%
from matplotlib import pyplot
pyplot.plot(history.history['accuracy'], label='train')
pyplot.plot(history.history['val_accuracy'], label='test')
pyplot.legend()
pyplot.show()

# %%
import pickle
from tensorflow.keras.models import save_model

# Save the model
model.save("ns_model_30.h5") 
model.save("ns_model_30.keras") 

# Save the history object
with open("history_50.pkl", 'wb') as f:
    pickle.dump(history.history, f)  # Save the training history

# %%
reverse_target_word_index=y_tokenizer.index_word
reverse_source_word_index=x_tokenizer.index_word
target_word_index=y_tokenizer.word_index

# %%
encoder_model = Model(inputs=encoder_inputs,outputs=[encoder_outputs, state_h, state_c])

# Decoder setup
# Below tensors will hold the states of the previous time step
decoder_state_input_h = Input(shape=(latent_dim,))
decoder_state_input_c = Input(shape=(latent_dim,))
decoder_hidden_state_input = Input(shape=(max_text_len,latent_dim))

# Get the embeddings of the decoder sequence
dec_emb2= dec_emb_layer(decoder_inputs) 
# To predict the next word in the sequence, set the initial states to the states from the previous time step
decoder_outputs2, state_h2, state_c2 = decoder_lstm(dec_emb2, initial_state=[decoder_state_input_h, decoder_state_input_c])

# A dense softmax layer to generate prob dist. over the target vocabulary
decoder_outputs2 = decoder_dense(decoder_outputs2) 

# Final decoder model
decoder_model = Model(
    [decoder_inputs] + [decoder_hidden_state_input,decoder_state_input_h, decoder_state_input_c],
    [decoder_outputs2] + [state_h2, state_c2])

# %%
max_text_len
# Out:
# 65

# %%
def decode_sequence(input_seq):
    # Encode the input as state vectors.
    e_out, e_h, e_c = encoder_model.predict(input_seq)
    
    # Generate empty target sequence of length 1.
    target_seq = np.zeros((1,1))
    
    # Populate the first word of target sequence with the start word.
    target_seq[0, 0] = target_word_index['sostok']

    stop_condition = False
    decoded_sentence = ''
    while not stop_condition:
      
        output_tokens, h, c = decoder_model.predict([target_seq] + [e_out, e_h, e_c])

        # Sample a token
        sampled_token_index = np.argmax(output_tokens[0, -1, :])
        sampled_token = reverse_target_word_index[sampled_token_index]
        
        if(sampled_token!='eostok'):
            decoded_sentence += ' '+sampled_token

        # Exit condition: either hit max length or find stop word.
        if (sampled_token == 'eostok'  or len(decoded_sentence.split()) >= (max_summary_len-1)):
            stop_condition = True

        # Update the target sequence (of length 1).
        target_seq = np.zeros((1,1))
        target_seq[0, 0] = sampled_token_index

        # Update internal states
        e_h, e_c = h, c

    return decoded_sentence

# %%
def seq2summary(input_seq):
    newString=''
    for i in input_seq:
        if((i!=0 and i!=target_word_index['sostok']) and i!=target_word_index['eostok']):
            newString=newString+reverse_target_word_index[i]+' '
    return newString

def seq2text(input_seq):
    newString=''
    for i in input_seq:
        if(i!=0):
            newString=newString+reverse_source_word_index[i]+' '
    return newString

# %%
# print("Review:",seq2text(x_tr[3]))
# print("Original summary:",seq2summary(y_tr[3]))
# print("Predicted summary:",decode_sequence(x_tr[3].reshape(1,max_text_len)))
# print("\n")

# %%
decode_sequence(x_tr[2].reshape(1,max_text_len))
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 466ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 204ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# ' sos trump denies trump pay ã¢â\x82â¹1 000 crore eos'

# %%
for i in range(0,100):
    print("Review:",seq2text(x_tr[i]))
    print("Original summary:",seq2summary(y_tr[i]))
    print("Predicted summary:",decode_sequence(x_tr[i].reshape(1,max_text_len)))
    print("\n")
# Out:
# Review: believed 1920s radios needed advertisers help increase profits convinced businesses sold household goods become sponsors since audience daytime shows mostly female homemakers companies began advertise soaps hence introducing term soap later tv gained term advertising strategy remained
# Original summary: sos tv shows called eos
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# Predicted summary:  sos tv show auctioned eos
#
#
# Review: haryana health minister anil vij saturday tweeted even 100 dogs join hands cannot challenge lion bjp win gujarat polls narendra modi wave continues country vij added comes reports claimed patidar leader hardik patel join hands congress gujarat
# Original summary: sos 100 dogs challenge lion bjp win polls minister eos
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# Predicted summary:  sos bjp leader calls bjp leader eos
#
#
# Review: us media firm paid 30 000 around ã¢ââ¹20 lakh former trump world tower remain silent claims us president donald trump fathered child former housekeeper employees american media inc claimed money paid favour trump run up 2016 presidential elections
# Original summary: sos firm paid man ã¢ââ¹20l hide trump love child claim report eos
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Predicted summary:  sos trump denies trump pay ã¢ââ¹1 000 crore eos
#
#
# Review: sri lankan national bound india arrested international airport near colombo sunday allegedly trying smuggle gold worth nearly ã¢ââ¹20 lakh rectum allegedly hiding four gold bars eight jewellery pieces official said hiding gold rectum become increasingly common way smuggling gold india
# Original summary: sos sri lankan way india held smuggling gold rectum eos
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Predicted summary:  sos sri lanka airport held smuggling gold worth eos
#
#
# Review: rcb rubbished media reports claimed sacked virat kohli captain next season ipl reports emerged south africa ab de villiers would replace kohli skipper clarify record news incorrect kohli much captain next season well team spokesperson said
# Original summary: sos kohli much captain rcb deny reports changing skipper eos
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# Predicted summary:  sos virat kohli gets ipl ipl 2018 eos
#
#
# Review: union minister venkaiah naidu friday said central government bjp role cbi raids lalu prasad yadav family cbi duty allowed earlier allowed government came interference naidu added
# Original summary: sos govt bjp role cbi raids lalu venkaiah naidu eos
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# Predicted summary:  sos give notice india lalu eos
#
#
# Review: us soldier known living north korea five decades ago james died last year pledging loyalty great north korean leader kim jong un sons said deserted us korean war suffered fatal stroke november last year aged 74 added
# Original summary: sos sons confirm death last us defector north korea eos
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Predicted summary:  sos us nuclear missile attack korea eos
#
#
# Review: actress twinkle khanna took twitter share picture actor akshay kumar sets upcoming film padman arunachalam muruganantham inventor low cost sanitary pad making machine film based also seen picture film also star actresses sonam kapoor radhika apte
# Original summary: sos twinkle shares pic akshay sets padman eos
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Predicted summary:  sos akshay kumar star akshay kumar starrer padman eos
#
#
# Review: afghanistan national directorate security said explosives used taliban militants attack intercontinental hotel kabul last week came pakistan spy agency recovered van full explosives militants failed detonate least 22 people including 14 foreigners killed 13 hour siege
# Original summary: sos pakistan made explosives used kabul attack afghanistan eos
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Predicted summary:  sos taliban attack afghan attack afghanistan eos
#
#
# Review: people climbed carcass 66 foot long blue whale take pictures washed beach chile footprints could seen dead whale one person even ana love carcass whale later moved authorities hoping determine cause death
# Original summary: sos people climb dead whale write chile eos
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Predicted summary:  sos baby baby found dead baby eos
#
#
# Review: tantrik geeta maa detained friday seem links alleged mass suicide committed 11 members family burari police said interrogating detained video clip surfaced admitted deceased family commit suicide
# Original summary: sos tantrik geeta maa linked burari deaths delhi police eos
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# Predicted summary:  sos son shot dead jail delhi police eos
#
#
# Review: least 52 fighters un backed libyan government killed heavy clashes rival factions country capital tripoli according reports clashes erupted earlier week rival groups launched attack attempt recapture parts capital un security council condemned violence urging parties exercise restraint
# Original summary: sos 52 libyan govt forces dead clashes rival eos
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Predicted summary:  sos us state killed us state killed eos
#
#
# Review: chinese electric vehicle maker market value soared almost 12 billion shares closed 76 second day trading shanghai based company billed emerging tesla rival raised 1 billion us offering sells china although technology design teams based us uk germany
# Original summary: sos tesla rival valued 12 billion two days trading eos
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# Predicted summary:  sos china loses 1 billion market cap first time eos
#
#
# Review: centre told supreme court taking help us based national centre missing exploited children curb child porn india private body acts resource centre information missing exploited children reportedly trying establish secure communication link cbi sharing details
# Original summary: sos private us body helping india curb child porn centre sc eos
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Predicted summary:  sos centre asks centre sc asks centre eos
#
#
# Review: according reports snapdeal largest investor softbank threatened walk snapdeal flipkart merger minority shareholders vote favour deal reports also suggested japan based softbank might invest flipkart independently comes snapdeal founders reported pushing sale infibeam instead flipkart
# Original summary: sos softbank threatens walk snapdeal flipkart merger eos
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# Predicted summary:  sos walmart flipkart snapdeal flipkart flipkart flipkart eos
#
#
# Review: fifa world cup first time winner every 20 years since 1958 brazil first time 1958 argentina first time 1978 followed france maiden world cup title 1998 2018 edition final feature croatia marking maiden appearance world cup final
# Original summary: sos wc first time winner every 20 years since eos
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Predicted summary:  sos england win world cup semi semi eos
#
#
# Review: ministry skill development entrepreneurship secretary kp krishnan said private skill training centres india worse condition compared government ones said 84 around 14 000 industrial training institutes country belong private sector krishnan said private lack quality labs equipment
# Original summary: sos private skill training centres worse india govt official eos
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Predicted summary:  sos govt approves new policy eos
#
#
# Review: election commission pakistan rejected nomination papers filed pakistan tehreek e insaf pti chief imran khan upcoming general elections khan nomination paper filed islamabad constituency rejected fill affidavit per requirements nomination papers former pakistan prime minister shahid khaqan abbasi also rejected
# Original summary: sos pak election body rejects imran khan polls eos
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# Predicted summary:  sos pak imran imran khan sharif sharif eos
#
#
# Review: amid ongoing border standoff china defence minister arun jaitley friday told lok sabha indian armed forces fully equipped face contingency comes week cag slammed ordnance factory board inadequate quality ammunition supplied army since march 2013
# Original summary: sos govt rejects claims india lacks ammunition fight war eos
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Predicted summary:  sos india china agree pm modi eos
#
#
# Review: indian air force officer chaturvedi become country first woman fly fighter jet solo operated russian made mig 21 aircraft first training sortie monday one three first women batch inducted iaf fighter stream 2016 notably women barred combat roles army navy
# Original summary: sos iaf officer becomes 1st indian woman fly fighter jet solo eos
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# Predicted summary:  sos indian navy navy chief gets first time eos
#
#
# Review: spanish players attacked romanian referee vlad losing belgium rugby world cup qualifier match sunday defeat spain failed secure automatic qualification romania qualifying result everyone seen game judge referee gave 10 penalties us result comes spanish rugby federation president tweeted
# Original summary: sos spain attack romanian referee post losing wc spot eos
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# Predicted summary:  sos football team banned wc match russia eos
#
#
# Review: old video shows former prime minister atal bihari vajpayee playing national bravery award winning child 2003 award ceremony three time prime minister bharat ratna awardee passed away new delhi thursday funeral conducted today central government declared seven day state mourning across nation following demise
# Original summary: sos watch vajpayee plays bravery award winning child stage eos
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Predicted summary:  sos video shows pm vajpayee tribute vajpayee eos
#
#
# Review: uk court cleared extradition 50 year old bookie sanjeev chawla key accused 2000 match fixing scandal involving late south africa captain cronje india accused moved uk 1996 obtained british passport 2005 comes uk high court accepted assurances given india regarding tihar jail condition
# Original summary: sos uk court clears extradition accused 2000 match fixing scandal eos
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# Predicted summary:  sos uk court rejects plea fixing case eos
#
#
# Review: uk based woman lost jaw cancer seen cm bone grow back facial frame surgically attached january 55 year old woman part jaw removed battling mouth cancer 2015 fed tube left restricted speech following two failed surgeries
# Original summary: sos woman removed jaw bone cm mouth cancer eos
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# Predicted summary:  sos woman gives birth woman hiv surgery eos
#
#
# Review: actress deepika padukone set get wax statue madame tussauds london feel lot gratitude know give fans little movies really special said deepika said time visited madame tussauds london little
# Original summary: sos deepika get wax statue london madame tussauds eos
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# Predicted summary:  sos deepika padukone perform wax statue madame tussauds eos
#
#
# Review: bengaluru based vernacular social networking app sharechat banned 50 000 profiles problematic content like pornography violence fake news asked users report profiles problematic content reviewed complaints took appropriate action iit kanpur alumni sharechat lets users post content 14 local languages including telugu bhojpuri odia n
# Original summary: sos bans 50 000 profiles tackle porn fake news eos
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# Predicted summary:  sos app launches app users using users report eos
#
#
# Review: karnataka chief minister hd kumaraswamy said anyone mercy get position state chief minister charity statement comes video former karnataka cm siddaramaiah saying kumaraswamy became cm support surfaced online siddaramaiah talking discussions jd congress presenting fresh budget nn
# Original summary: sos anyone mercy get seat charity taka cm eos
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# Predicted summary:  sos andhra cm minister resigns cm eos
#
#
# Review: vice president venkaiah naidu tuesday said lessons emergency period included textbooks across india adding present generations know imposed former pm indira gandhi assent the then president fakhruddin ali ahmed imposed 21 month emergency june 25 1975 citing internal external threats india
# Original summary: sos emergency period included textbooks vice prez eos
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# Predicted summary:  sos vice prez naidu gandhi president eos
#
#
# Review: silver winning indian team asian games first ever 4x400m mixed relay accused runner winners bahrain blocking hima das race tuesday athletics federation india confirmed appeal lodged decision wednesday hima change lanes bahrain runner fell front her
# Original summary: sos 2nd placed india accuse winner bahrain blocking runner hima eos
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# Predicted summary:  sos india 1st indian women team asiad champ eos
#
#
# Review: former prison believed haunted britain opening guests overnight stay first time october 13 prison built among oldest prisons country stay guests served dinner breakfast get opportunity explore prison
# Original summary: sos former prison opening guests one night eos
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Predicted summary:  sos uk passes away aged lakh eos
#
#
# Review: royal challengers bangalore batsman chris gayle auction bat became first player score 10 000 t20 runs bat auctioned launch chris gayle foundation june along special golden bat gayle added wanted use golden bat get milestone
# Original summary: sos gayle auction bat used hit record 10 000th t20 run eos
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# Predicted summary:  sos gayle gayle smashes record ipl match eos
#
#
# Review: singer varsha singh alleged singer kailash kher used consider guru sent message read want make love also accused music composer toshi sexual misconduct influence alcohol put hand thigh toshi denied allegations
# Original summary: sos kailash kher saying want make love singer eos
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Predicted summary:  sos want like men sonu eos
#
#
# Review: screening film accidental prime minister cancelled kolkata hind cinema due security concerns amid protests youth congress activists close 100 activists protested front theatre west bengal youth congress president shadab khan said show reportedly halted first ten minutes film screened
# Original summary: sos accidental halted kolkata theatre amid protests eos
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# Predicted summary:  sos bjp leader inaugurates pm modi eos
#
#
# Review: former india captain mahendra singh dhoni slammed second fifty 11 year t20i career south africa wednesday playing 77th t20i innings dhoni smashed 52 28 balls including sixes fours dhoni scored fifty first 65 t20i innings scored two last 12 innings
# Original summary: sos dhoni smashes second fifty 11 year t20i career eos
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# Predicted summary:  sos dhoni slams dhoni record odi odi cricket eos
#
#
# Review: worldwide spending internet things iot security reach 1 5 billion 2018 according report research firm gartner represents 28 increase 1 2 billion spent iot security last year report said nearly 20 organisations observed least one iot based attack past three years report added
# Original summary: sos global security spending reach 1 5bn 2018 report eos
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Predicted summary:  sos us firm loses 1 billion deal eos
#
#
# Review: ben affleck said continue superhero character batman upcoming standalone film batman speaking san diego comic con added batman coolest king part universe dc marvel thrilled rumours affleck starring batman emerged quit film director
# Original summary: sos affleck says continue batman standalone film eos
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Predicted summary:  sos john star star wars actor eos
#
#
# Review: posing policemen two men allegedly raped 20 year old woman molested minor niece outer delhi sunday night accused approached woman niece claiming policemen police said victims statements recorded case registered men yet identified
# Original summary: sos posing policemen two men sexually assault woman niece eos
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Predicted summary:  sos delhi woman raped delhi woman raped eos
#
#
# Review: mukesh ambani led reliance industries reportedly talks acquire mumbai based cable broadband service provider hathway cable talks aimed using company platform speed commercial launch jio home broadband services deal expected value hathway around ã¢ââ¹2 500 crore
# Original summary: sos reliance talks buy broadband firm report eos
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# Predicted summary:  sos reliance jio shares fall ã¢ââ¹1 000 crore eos
#
#
# Review: government warned whatsapp take urgent steps prevent spread irresponsible explosive messages platform leading cases lynching ministry electronics information technology said statement company cannot evade accountability responsibility comes lynching incidents took place based forward messages circulated whatsapp
# Original summary: sos govt warns whatsapp leading mob lynchings eos
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Predicted summary:  sos govt asks users hacked social media eos
#
#
# Review: calcutta high court justice cs karnan thursday declined undergo medical examination ordered supreme court asserting normal stable mind alleged sc order amounts insult harassment guardian consent required medical examination since family town test possible karnan added
# Original summary: sos justice karnan refuses undergo medical test ordered sc eos
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# Predicted summary:  sos sc rejects plea plea plea sc eos
#
#
# Review: sri lankan president maithripala sirisena sunday announced nationwide state emergency lifted emergency imposed control communal violence buddhists muslims clashed country central district kandy two people killed hundreds muslim owned properties 20 mosques damaged according reports
# Original summary: sos sri lanka lifts nationwide emergency 12 days eos
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# Predicted summary:  sos sri lanka passes lanka test eos
#
#
# Review: guards jammu kashmir army camp area averted terror attack opened fire two motorcycle borne militants approaching camp police said militants approached camp tuesday morning fired sentry post guards retaliated forcing terrorists flee
# Original summary: sos 2 militants flee army camp guards open fire eos
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# Predicted summary:  sos army jawan killed encounter eos
#
#
# Review: virgin group founder richard branson friday said feeling united states president donald trump bizarre mistake pulling america paris climate deal terming trump withdrawal strange branson pointed head said knows goes added hopefully positive change mind
# Original summary: sos trump regrets bizarre paris climate richard branson eos
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# Predicted summary:  sos trump gates calls trump climate deal eos
#
#
# Review: twitter users across world trolled irani man posting picture biryani ketchup mayonnaise terming best way eat dish man tweeted pass india indians posted twitter pass arabs tweeted hand pakistan
# Original summary: sos twitter trolls man eating biryani eos
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# Predicted summary:  sos twitter reacts video shows india eos
#
#
# Review: filmmaker kabir khan speaking salman khan starrer film tubelight performance box office said disappointed however added unfair pitch every film 2015 film bajrangi bhaijaan also starred salman notably tubelight became salman khan lowest eid opening four years
# Original summary: sos disappointed kabir khan tubelight performance eos
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# Predicted summary:  sos salman khan star salman khan eos
#
#
# Review: indo canadian youtube personality lilly singh also known superwoman took instagram share picture visit school madhya pradesh although different places experience different challenges picture symbolises something universal humanity read part lilly caption visited school part unicef programme n
# Original summary: sos superwoman lilly singh shares pic mp school visit eos
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# Predicted summary:  sos twitter reacts tribute india concert eos
#
#
# Review: india growing pretty world bank president jim yong kim said wednesday adding levelling out developing economies speaking bloomberg global business forum kim predicted strong global growth year said terms indebtedness bank watching carefully debt to gdp ratios every single country
# Original summary: sos india growing pretty world bank president eos
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# Predicted summary:  sos india first time ever us president eos
#
#
# Review: congress mla pratap dudhat wednesday said hurled mic bjp leader gujarat assembly used abusive language dudhat congress mla amrish der suspended three years congress mla thakor suspended one year dudhat said suspended reduce congress voters upcoming rajya sabha elections
# Original summary: sos hurled mic bjp mla abused gujarat congress mla eos
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# Predicted summary:  sos bjp mla bjp mla bjp mla eos
#
#
# Review: groom married relative temple karnataka mysuru bride nandhini eloped lover day wedding groom asked marry relative venue wedding nandhini arranged parents feared cancelled wedding would put depression
# Original summary: sos groom marries relative venue bride eos
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Predicted summary:  sos couple takes birth wedding wedding eos
#
#
# Review: delhi court monday extended interim protection arrest given karti chidambaram till may aircel maxis case relief granted enforcement directorate sought time argue karti application seeking anticipatory bail case pertains karti role foreign investment approval granted aircel maxis deal father chidambaram finance minister
# Original summary: sos karti gets protection till may aircel maxis case eos
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Predicted summary:  sos ed raids karti cbi chief case eos
#
#
# Review: television journalist arnab goswami featured cover april issue men luxury lifestyle magazine man world india cover story titled neither sanghi arnab goswami seen wearing bow ties suits fashion shoot posing loudspeaker television set camera
# Original summary: sos arnab goswami features cover men magazine eos
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# Predicted summary:  sos women show india first time eos
#
#
# Review: president pranab mukherjee friday said traditional indian values yoga become good mechanisms support people suffering mental health disorders adding depression common form mental health disorders president asked medical fraternity focus traditional support systems spiritual beliefs practices providing well being all
# Original summary: sos yoga treating mental health problems president eos
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Predicted summary:  sos pranab kovind gandhi pranab mukherjee eos
#
#
# Review: cctv footage murdered journalist gauri lankesh locality shows alleged killer around crime scene least twice committed murder investigating officers said police estimates reveal aged 30 35 years accused arrived lankesh house two wheeler identified since wearing helmet
# Original summary: sos cctvs reveal killer lankesh house murder eos
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# Predicted summary:  sos woman sentenced death penalty killing eos
#
#
# Review: actor rishi kapoor appealed allowing pakistani cricketers play ipl tenth edition begins wednesday kapoor cited example afghanistan players playing first time tournament year saying hum bade log hain pakistani player part ipl 2008 year inception
# Original summary: sos rishi kapoor appeals pakistani cricketers play ipl eos
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# Predicted summary:  sos arjun tendulkar play pakistan team india eos
#
#
# Review: decomposed body three and a half foot dolphin washed ashore mumbai marine drive tuesday evening reportedly thirteenth marine mammal death city year official state mangrove cell said species indian ocean dolphin added forest department worried cases increasing rapidly
# Original summary: sos decomposed body dolphin washes ashore mumbai eos
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Predicted summary:  sos mumbai man dies falling train eos
#
#
# Review: bengaluru based daily commute startup zipgo acquired 100 stake pune based transport provider supreme trans concept company said first acquisition one zipgo co founder chief operating officer gupta said founded 2015 zipgo facilitates office commute offers app based intra well inter city bus services n
# Original summary: sos daily startup buys pune supreme trans concept eos
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Predicted summary:  sos bengaluru based startup raises 1 million eos
#
#
# Review: fitness trackers made defunct wearables startup jawbone remained sale even companion app shut earlier year according consumer watchdog trackers listed sale amazon groupon without functional app retailers removed trackers sale contacted
# Original summary: sos fitness sale despite app shutdown eos
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Predicted summary:  sos smart startup raises 000 million eos
#
#
# Review: one accused gauri lankesh murder case agreed undergo narco analysis test accused lawyer said adding accused undergo test prove innocence lawyer said applied city civil court came court asked accused ready undergo test
# Original summary: sos gauri lankesh murder accused agrees test lawyer eos
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# Predicted summary:  sos cbi files fir plea sexual harassment case eos
#
#
# Review: 5 7 metre long piano among longest world found new home dunedin fire brigade called shift new zealand built 28 year old adrian mann high school student piano weighs tonne mann said extra level depth resonance
# Original summary: sos one world longest moved fire brigade help eos
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Predicted summary:  sos world largest ship opens world largest eos
#
#
# Review: ghaziabad become first district uttar pradesh start using centre app provide real time information regarding power supply consumers officials said nearly lakh messages sent consumers within four days launch officials added notably consumers also inform authorities power cuts uploading messages app
# Original summary: sos ghaziabad starts real time power supply updates via app eos
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Predicted summary:  sos bengaluru govt launches app data eos
#
#
# Review: us national nuclear security administration announced along us air force successfully field tested modernised gravity nuclear bomb 12 march 14 test range nevada test intended evaluate weapon non nuclear functions aircraft capability deliver weapon said
# Original summary: sos us successfully tests new nuclear gravity bomb eos
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Predicted summary:  sos us nuclear missile missile missile eos
#
#
# Review: bangladeshi court monday upheld government ruling banning marriage citizens myanmar rohingya refugees bangladesh banned marriages rohingyas 2014 government said abused obtain citizenship six lakh rohingya refugees fled bangladesh myanmar last year following persecution community
# Original summary: sos court upholds ban marrying rohingya refugees eos
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Predicted summary:  sos un seeks un ban rohingya rights eos
#
#
# ...
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Predicted summary:  sos akshay kumar wins world title awards eos
#
#
# Review: historic meeting us president donald trump north korean leader kim jong un held june 12 take place capella hotel singapore island area around hotel marked special security zone summit first ever sitting us president north korean leader
# Original summary: sos singapore hotel named trump kim summit venue eos
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# Predicted summary:  sos trump kim jong un visit trump visit eos
#
#
# Review: residents bandra monte street said file criminal complaint authorities demolishing 120 year old cross april 29 want bmc reinstate cross criminal charge sheet wrongly marking shrine demolishing said residents also said cross legal owner private property
# Original summary: sos 120 yr old cross demolished residents file complaint eos
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Predicted summary:  sos mumbai woman fined 10 000 people eos
#
#
# Review: violence rohingya muslims myanmar looks like ethnic cleansing british government spokesperson said britain called myanmar authorities stop violence ensure access country rakhine state provide aid affected crisis myanmar forces crackdown rohingya militants caused exodus lakh rohingya refugees
# Original summary: sos rohingya violence looks like ethnic cleansing says britain eos
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# Predicted summary:  sos myanmar parliament calls rohingya rohingya rohingya crisis eos
#
#
# Review: india set get first sea bridge runway approval extend airport lakshadweep given airports authority india reinforced cement concrete platform built beach shallow area allow bigger atr aircraft operate island reports said
# Original summary: sos india get 1st runway sea bridge airport eos
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# Predicted summary:  sos india 1st indian flight opens fire eos
#
#
# Review: days four supreme court judges expressed concerns allocation cases chief justice dipak misra bar council india chairman manan kumar mishra said kahani khatam ho gayi story adding internal issue resolved said action taken criticising cji
# Original summary: sos ho gayi chairman sc judges dispute eos
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# Predicted summary:  sos sc rejects plea plea plea cji eos
#
#
# Review: philippine government revoked licence news website critical president rodrigo duterte war drugs denying move curbs freedom press authorities said media outlet violated clause limits media ownership philippine citizens termed ruling pure harassment
# Original summary: sos philippines shuts news website critical prez duterte eos
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# Predicted summary:  sos philippine prez duterte calls ban fake law eos
#
#
# Review: 18 year old national bravery award recipient khan designated special police officer agra police uttar pradesh khan awarded bravery award taking active measures thwart network drugs gambling rackets filed numerous police complaints also instrumental stopping kidnapping attempt six year old
# Original summary: sos bravery award winner special police officer eos
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Predicted summary:  sos bigg boss contestant wife commits suicide eos
#
#
# Review: indian batsman shikhar dhawan miss india first three odis australia wife tweeted photo wife ahead surgery glad wife strength moment time hope surgery going go well part caption read
# Original summary: sos shikhar dhawan shares photo wife ahead surgery eos
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Predicted summary:  sos shami wife shares wife wife eos
#
#
# Review: brazil based startup robotics partnership intel demonstrated ai powered adapter kit move wheelchair facial expressions gestures consumer electronics show ces 2019 las vegas kit learns user gestures automatically takes around seven minutes install plugged motorised wheelchair startup said
# Original summary: sos ai kit control wheelchair face shown ces eos
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Predicted summary:  sos startup makes ai users using ai eos
#
#
# Review: speaking different kinds roles alia bhatt said want diva also want top film awards want balance worlds added alia said every film different picking similar films
# Original summary: sos want also want top film awards alia eos
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Predicted summary:  sos want work alia alia eos
#
#
# Review: tvk leader velmurugan threatened party would let loose snakes inside chepauk stadium chennai csk first home match kkr goes tuesday comes amid protests state parties urging centre constitute cauvery management board earlier velmurugan said protestors responsible untoward incident stadium
# Original summary: sos let loose snakes stadium csk match tn leader eos
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Predicted summary:  sos hardik patel slams ipl 2018 eos
#
#
# Review: actor nafisa ali diagnosed stage cancer shared video grandchildren cutting hair asked grandchildren cut hair realise going chemo fun captioned video instagram recently also shared picture shedding hair
# Original summary: sos know gets hair cut eos
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# Predicted summary:  sos actress reveals cancer cancer eos
#
#
# Review: vaibhav kesarkar 24 year old cricketer mumbai died suffering heart attack field playing local cricket match kesarkar continued bat team despite chest pain severe discomfort according reports died nearby hospital taken medical examination
# Original summary: sos 24 yr old mumbai cricketer suffers heart attack playing dies eos
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Predicted summary:  sos fan dies falling match due match eos
#
#
# Review: air india wednesday rendered apology day passengers delayed pune delhi flight allowed deboard even complained air conditioners working causing discomfort last minute technical glitch led unfortunate delay flight process faced inconvenience deboarded clearance airline tweeted
# Original summary: sos air india apologises passengers locked flight without ac eos
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Predicted summary:  sos air india flight get emergency landing eos
#
#
# Review: first ever test match played england australia 1877 south africa became third test playing nation 1889 india debuted 1932 2000 bangladesh became fourth asian country tenth overall play test icc awarded test status nation 17 years thursday granting full membership ireland afghanistan
# Original summary: sos test nations play first ever test matches eos
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Predicted summary:  sos india 1st test cricket test cricket eos
#
#
# Review: prime minister narendra modi attended actress priyanka chopra american singer nick jonas wedding reception held delhi taj palace hotel tuesday priyanka wore white nude embellished lehenga nick chose velvet tuxedo occasion couple got married per christian well hindu rituals reportedly host another reception mumbai
# Original summary: sos pm narendra modi attends priyanka nick delhi wedding reception eos
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Predicted summary:  sos priyanka nick meets pm modi wedding reception eos
#
#
# Review: order fight misinformation rumours facebook owned messenger service whatsapp limiting text forwards five chats time users worldwide previously whatsapp user could forward message 20 individuals groups limit introduced india july spread rumours social media led killings lynching attempts
# Original summary: sos whatsapp limits text chats time worldwide eos
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# Predicted summary:  sos facebook launches app users facebook eos
#
#
# Review: oldest person world violet brown passed away age 117 friday brown born jamaica march 10 1900 suffered irregular heartbeat dehydrated days passed away following death 117 year old japanese woman nabi tajima born august 1900 become world oldest person
# Original summary: sos world oldest person dies aged 117 eos
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# Predicted summary:  sos world oldest woman dies aged aged aged eos
#
#
# Review: india delayed implementation higher tariffs goods imported us december 17 despite us removing least 50 indian products list items eligible duty free treatment india raise tariffs us goods november us move unilaterally raise import duties indian steel aluminium products
# Original summary: sos india delays retaliatory tariffs us goods eos
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# Predicted summary:  sos india trade largest oil oil steel eos
#
#
# Review: reliance naval engineering saturday said anil ambani resigned company director immediate effect ambani resigned compliance companies act 2013 prescribing limit 10 public companies company said reliance naval engineering operates indiaã¢ââs largest integrated shipbuilding facility facing financial constraints
# Original summary: sos anil ambani quits reliance naval engineering director eos
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# Predicted summary:  sos rcom ambani reliance jio quits eos

# %%
pip install rouge-score
# Out:
# Collecting rouge-score
#   Downloading rouge_score-0.1.2.tar.gz (17 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: absl-py in /opt/conda/lib/python3.10/site-packages (from rouge-score) (1.4.0)
# Requirement already satisfied: nltk in /opt/conda/lib/python3.10/site-packages (from rouge-score) (3.2.4)
# Requirement already satisfied: numpy in /opt/conda/lib/python3.10/site-packages (from rouge-score) (1.26.4)
# Requirement already satisfied: six>=1.14.0 in /opt/conda/lib/python3.10/site-packages (from rouge-score) (1.16.0)
# Building wheels for collected packages: rouge-score
#   Building wheel for rouge-score (setup.py) ... done
#   Created wheel for rouge-score: filename=rouge_score-0.1.2-py3-none-any.whl size=24934 sha256=d8dab89e205a4df5785108bf06def708515a53708a89fc25ea5cf2bdb0e0719e
#   Stored in directory: /root/.cache/pip/wheels/5f/dd/89/461065a73be61a532ff8599a28e9beef17985c9e9c31e541b4
# Successfully built rouge-score
# Installing collected packages: rouge-score
# Successfully installed rouge-score-0.1.2
# Note: you may need to restart the kernel to use updated packages.

# %%
from rouge_score import rouge_scorer

# Function to calculate ROUGE scores
def calculate_rouge(reference_summary, generated_summary):
    """
    Calculate ROUGE scores between reference and generated summaries.
    Args:
        reference_summary (str): The human-written reference summary.
        generated_summary (str): The model-generated summary.
    Returns:
        dict: A dictionary containing ROUGE-1, ROUGE-2, and ROUGE-L scores.
    """
    scorer = rouge_scorer.RougeScorer(['rouge1', 'rouge2', 'rougeL'], use_stemmer=True)
    scores = scorer.score(reference_summary, generated_summary)
    return scores

# Example Evaluation Loop
for i in range(100):  # Evaluate the first 5 examples; adjust as needed
    review = seq2text(x_tr[i])  # Convert input sequence to text
    original_summary = seq2summary(y_tr[i])  # Convert target sequence to text
    predicted_summary = decode_sequence(x_tr[i].reshape(1, max_text_len))  # Generate summary
    
    # Calculate ROUGE scores
    rouge_scores = calculate_rouge(original_summary, predicted_summary)
    
    # Print Results
    print(f"Review {i+1}: {review}")
    print(f"Original Summary: {original_summary}")
    print(f"Predicted Summary: {predicted_summary}")
    print("ROUGE Scores:")
    for metric, score in rouge_scores.items():
        print(f"  {metric.upper()} - Precision: {score.precision:.4f}, Recall: {score.recall:.4f}, F1 Score: {score.fmeasure:.4f}")
    print("\n" + "-"*80 + "\n")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# Review 1: believed 1920s radios needed advertisers help increase profits convinced businesses sold household goods become sponsors since audience daytime shows mostly female homemakers companies began advertise soaps hence introducing term soap later tv gained term advertising strategy remained
# Original Summary: sos tv shows called eos
# Predicted Summary:  sos tv show auctioned eos
# ROUGE Scores:
#   ROUGE1 - Precision: 0.8000, Recall: 0.8000, F1 Score: 0.8000
#   ROUGE2 - Precision: 0.5000, Recall: 0.5000, F1 Score: 0.5000
#   ROUGEL - Precision: 0.8000, Recall: 0.8000, F1 Score: 0.8000
#
# --------------------------------------------------------------------------------
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# Review 2: haryana health minister anil vij saturday tweeted even 100 dogs join hands cannot challenge lion bjp win gujarat polls narendra modi wave continues country vij added comes reports claimed patidar leader hardik patel join hands congress gujarat
# Original Summary: sos 100 dogs challenge lion bjp win polls minister eos
# Predicted Summary:  sos bjp leader calls bjp leader eos
# ROUGE Scores:
#   ROUGE1 - Precision: 0.4286, Recall: 0.3000, F1 Score: 0.3529
#   ROUGE2 - Precision: 0.0000, Recall: 0.0000, F1 Score: 0.0000
#   ROUGEL - Precision: 0.4286, Recall: 0.3000, F1 Score: 0.3529
#
# --------------------------------------------------------------------------------
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# Review 3: us media firm paid 30 000 around ã¢ââ¹20 lakh former trump world tower remain silent claims us president donald trump fathered child former housekeeper employees american media inc claimed money paid favour trump run up 2016 presidential elections
# Original Summary: sos firm paid man ã¢ââ¹20l hide trump love child claim report eos
# Predicted Summary:  sos trump denies trump pay ã¢ââ¹1 000 crore eos
# ROUGE Scores:
#   ROUGE1 - Precision: 0.3333, Recall: 0.2500, F1 Score: 0.2857
#   ROUGE2 - Precision: 0.0000, Recall: 0.0000, F1 Score: 0.0000
#   ROUGEL - Precision: 0.3333, Recall: 0.2500, F1 Score: 0.2857
#
# --------------------------------------------------------------------------------
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# Review 4: sri lankan national bound india arrested international airport near colombo sunday allegedly trying smuggle gold worth nearly ã¢ââ¹20 lakh rectum allegedly hiding four gold bars eight jewellery pieces official said hiding gold rectum become increasingly common way smuggling gold india
# Original Summary: sos sri lankan way india held smuggling gold rectum eos
# Predicted Summary:  sos sri lanka airport held smuggling gold worth eos
# ROUGE Scores:
#   ROUGE1 - Precision: 0.6667, Recall: 0.6000, F1 Score: 0.6316
#   ROUGE2 - Precision: 0.3750, Recall: 0.3333, F1 Score: 0.3529
#   ROUGEL - Precision: 0.6667, Recall: 0.6000, F1 Score: 0.6316
#
# --------------------------------------------------------------------------------
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# Review 5: rcb rubbished media reports claimed sacked virat kohli captain next season ipl reports emerged south africa ab de villiers would replace kohli skipper clarify record news incorrect kohli much captain next season well team spokesperson said
# Original Summary: sos kohli much captain rcb deny reports changing skipper eos
# Predicted Summary:  sos virat kohli gets ipl ipl 2018 eos
# ROUGE Scores:
#   ROUGE1 - Precision: 0.3750, Recall: 0.3000, F1 Score: 0.3333
#   ROUGE2 - Precision: 0.0000, Recall: 0.0000, F1 Score: 0.0000
#   ROUGEL - Precision: 0.3750, Recall: 0.3000, F1 Score: 0.3333
#
# --------------------------------------------------------------------------------
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# Review 6: union minister venkaiah naidu friday said central government bjp role cbi raids lalu prasad yadav family cbi duty allowed earlier allowed government came interference naidu added
# Original Summary: sos govt bjp role cbi raids lalu venkaiah naidu eos
# Predicted Summary:  sos give notice india lalu eos
# ROUGE Scores:
#   ROUGE1 - Precision: 0.5000, Recall: 0.3000, F1 Score: 0.3750
#   ROUGE2 - Precision: 0.0000, Recall: 0.0000, F1 Score: 0.0000
#   ROUGEL - Precision: 0.5000, Recall: 0.3000, F1 Score: 0.3750
#
# --------------------------------------------------------------------------------
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# Review 7: us soldier known living north korea five decades ago james died last year pledging loyalty great north korean leader kim jong un sons said deserted us korean war suffered fatal stroke november last year aged 74 added
# Original Summary: sos sons confirm death last us defector north korea eos
# Predicted Summary:  sos us nuclear missile attack korea eos
# ROUGE Scores:
#   ROUGE1 - Precision: 0.5714, Recall: 0.4000, F1 Score: 0.4706
#   ROUGE2 - Precision: 0.1667, Recall: 0.1111, F1 Score: 0.1333
#   ROUGEL - Precision: 0.5714, Recall: 0.4000, F1 Score: 0.4706
#
# --------------------------------------------------------------------------------
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Review 8: actress twinkle khanna took twitter share picture actor akshay kumar sets upcoming film padman arunachalam muruganantham inventor low cost sanitary pad making machine film based also seen picture film also star actresses sonam kapoor radhika apte
# Original Summary: sos twinkle shares pic akshay sets padman eos
# Predicted Summary:  sos akshay kumar star akshay kumar starrer padman eos
# ROUGE Scores:
#   ROUGE1 - Precision: 0.4444, Recall: 0.5000, F1 Score: 0.4706
#   ROUGE2 - Precision: 0.1250, Recall: 0.1429, F1 Score: 0.1333
#   ROUGEL - Precision: 0.4444, Recall: 0.5000, F1 Score: 0.4706
#
# --------------------------------------------------------------------------------
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# Review 9: afghanistan national directorate security said explosives used taliban militants attack intercontinental hotel kabul last week came pakistan spy agency recovered van full explosives militants failed detonate least 22 people including 14 foreigners killed 13 hour siege
# Original Summary: sos pakistan made explosives used kabul attack afghanistan eos
# Predicted Summary:  sos taliban attack afghan attack afghanistan eos
# ROUGE Scores:
#   ROUGE1 - Precision: 0.5714, Recall: 0.4444, F1 Score: 0.5000
#   ROUGE2 - Precision: 0.3333, Recall: 0.2500, F1 Score: 0.2857
#   ROUGEL - Precision: 0.5714, Recall: 0.4444, F1 Score: 0.5000
#
# --------------------------------------------------------------------------------
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Review 10: people climbed carcass 66 foot long blue whale take pictures washed beach chile footprints could seen dead whale one person even ana love carcass whale later moved authorities hoping determine cause death
# Original Summary: sos people climb dead whale write chile eos
# Predicted Summary:  sos baby baby found dead baby eos
# ROUGE Scores:
#   ROUGE1 - Precision: 0.4286, Recall: 0.3750, F1 Score: 0.4000
#   ROUGE2 - Precision: 0.0000, Recall: 0.0000, F1 Score: 0.0000
#   ROUGEL - Precision: 0.4286, Recall: 0.3750, F1 Score: 0.4000
#
# --------------------------------------------------------------------------------
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# Review 11: tantrik geeta maa detained friday seem links alleged mass suicide committed 11 members family burari police said interrogating detained video clip surfaced admitted deceased family commit suicide
# Original Summary: sos tantrik geeta maa linked burari deaths delhi police eos
# Predicted Summary:  sos son shot dead jail delhi police eos
# ROUGE Scores:
#   ROUGE1 - Precision: 0.5000, Recall: 0.4000, F1 Score: 0.4444
#   ROUGE2 - Precision: 0.2857, Recall: 0.2222, F1 Score: 0.2500
#   ROUGEL - Precision: 0.5000, Recall: 0.4000, F1 Score: 0.4444
#
# --------------------------------------------------------------------------------
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# Review 12: least 52 fighters un backed libyan government killed heavy clashes rival factions country capital tripoli according reports clashes erupted earlier week rival groups launched attack attempt recapture parts capital un security council condemned violence urging parties exercise restraint
# Original Summary: sos 52 libyan govt forces dead clashes rival eos
# Predicted Summary:  sos us state killed us state killed eos
# ROUGE Scores:
#   ROUGE1 - Precision: 0.2500, Recall: 0.2222, F1 Score: 0.2353
#   ROUGE2 - Precision: 0.0000, Recall: 0.0000, F1 Score: 0.0000
#   ROUGEL - Precision: 0.2500, Recall: 0.2222, F1 Score: 0.2353
#
# --------------------------------------------------------------------------------
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Review 13: chinese electric vehicle maker market value soared almost 12 billion shares closed 76 second day trading shanghai based company billed emerging tesla rival raised 1 billion us offering sells china although technology design teams based us uk germany
# Original Summary: sos tesla rival valued 12 billion two days trading eos
# Predicted Summary:  sos china loses 1 billion market cap first time eos
# ROUGE Scores:
#   ROUGE1 - Precision: 0.3000, Recall: 0.3000, F1 Score: 0.3000
#   ROUGE2 - Precision: 0.0000, Recall: 0.0000, F1 Score: 0.0000
#   ROUGEL - Precision: 0.3000, Recall: 0.3000, F1 Score: 0.3000
#
# --------------------------------------------------------------------------------
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# Review 14: centre told supreme court taking help us based national centre missing exploited children curb child porn india private body acts resource centre information missing exploited children reportedly trying establish secure communication link cbi sharing details
# Original Summary: sos private us body helping india curb child porn centre sc eos
# Predicted Summary:  sos centre asks centre sc asks centre eos
# ROUGE Scores:
#   ROUGE1 - Precision: 0.5000, Recall: 0.3333, F1 Score: 0.4000
#   ROUGE2 - Precision: 0.1429, Recall: 0.0909, F1 Score: 0.1111
#   ROUGEL - Precision: 0.5000, Recall: 0.3333, F1 Score: 0.4000
#
# --------------------------------------------------------------------------------
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# Review 15: according reports snapdeal largest investor softbank threatened walk snapdeal flipkart merger minority shareholders vote favour deal reports also suggested japan based softbank might invest flipkart independently comes snapdeal founders reported pushing sale infibeam instead flipkart
# Original Summary: sos softbank threatens walk snapdeal flipkart merger eos
# Predicted Summary:  sos walmart flipkart snapdeal flipkart flipkart flipkart eos
# ROUGE Scores:
#   ROUGE1 - Precision: 0.5000, Recall: 0.5000, F1 Score: 0.5000
#   ROUGE2 - Precision: 0.1429, Recall: 0.1429, F1 Score: 0.1429
#   ROUGEL - Precision: 0.5000, Recall: 0.5000, F1 Score: 0.5000
#
# --------------------------------------------------------------------------------
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Review 16: fifa world cup first time winner every 20 years since 1958 brazil first time 1958 argentina first time 1978 followed france maiden world cup title 1998 2018 edition final feature croatia marking maiden appearance world cup final
# Original Summary: sos wc first time winner every 20 years since eos
# Predicted Summary:  sos england win world cup semi semi eos
# ROUGE Scores:
#   ROUGE1 - Precision: 0.2500, Recall: 0.2000, F1 Score: 0.2222
#   ROUGE2 - Precision: 0.0000, Recall: 0.0000, F1 Score: 0.0000
#   ROUGEL - Precision: 0.2500, Recall: 0.2000, F1 Score: 0.2222
#
# --------------------------------------------------------------------------------
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# Review 17: ministry skill development entrepreneurship secretary kp krishnan said private skill training centres india worse condition compared government ones said 84 around 14 000 industrial training institutes country belong private sector krishnan said private lack quality labs equipment
# Original Summary: sos private skill training centres worse india govt official eos
# Predicted Summary:  sos govt approves new policy eos
# ROUGE Scores:
#   ROUGE1 - Precision: 0.5000, Recall: 0.3000, F1 Score: 0.3750
#   ROUGE2 - Precision: 0.0000, Recall: 0.0000, F1 Score: 0.0000
#   ROUGEL - Precision: 0.5000, Recall: 0.3000, F1 Score: 0.3750
#
# --------------------------------------------------------------------------------
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# Review 18: election commission pakistan rejected nomination papers filed pakistan tehreek e insaf pti chief imran khan upcoming general elections khan nomination paper filed islamabad constituency rejected fill affidavit per requirements nomination papers former pakistan prime minister shahid khaqan abbasi also rejected
# Original Summary: sos pak election body rejects imran khan polls eos
# Predicted Summary:  sos pak imran imran khan sharif sharif eos
# ROUGE Scores:
#   ROUGE1 - Precision: 0.6250, Recall: 0.5556, F1 Score: 0.5882
#   ROUGE2 - Precision: 0.2857, Recall: 0.2500, F1 Score: 0.2667
#   ROUGEL - Precision: 0.6250, Recall: 0.5556, F1 Score: 0.5882
#
# --------------------------------------------------------------------------------
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Review 19: amid ongoing border standoff china defence minister arun jaitley friday told lok sabha indian armed forces fully equipped face contingency comes week cag slammed ordnance factory board inadequate quality ammunition supplied army since march 2013
# Original Summary: sos govt rejects claims india lacks ammunition fight war eos
# Predicted Summary:  sos india china agree pm modi eos
# ROUGE Scores:
#   ROUGE1 - Precision: 0.4286, Recall: 0.3000, F1 Score: 0.3529
#   ROUGE2 - Precision: 0.0000, Recall: 0.0000, F1 Score: 0.0000
#   ROUGEL - Precision: 0.4286, Recall: 0.3000, F1 Score: 0.3529
#
# --------------------------------------------------------------------------------
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# Review 20: indian air force officer chaturvedi become country first woman fly fighter jet solo operated russian made mig 21 aircraft first training sortie monday one three first women batch inducted iaf fighter stream 2016 notably women barred combat roles army navy
# Original Summary: sos iaf officer becomes 1st indian woman fly fighter jet solo eos
# Predicted Summary:  sos indian navy navy chief gets first time eos
# ROUGE Scores:
#   ROUGE1 - Precision: 0.3333, Recall: 0.2500, F1 Score: 0.2857
#   ROUGE2 - Precision: 0.0000, Recall: 0.0000, F1 Score: 0.0000
#   ROUGEL - Precision: 0.3333, Recall: 0.2500, F1 Score: 0.2857
#
# --------------------------------------------------------------------------------
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Review 21: spanish players attacked romanian referee vlad losing belgium rugby world cup qualifier match sunday defeat spain failed secure automatic qualification romania qualifying result everyone seen game judge referee gave 10 penalties us result comes spanish rugby federation president tweeted
# Original Summary: sos spain attack romanian referee post losing wc spot eos
# Predicted Summary:  sos football team banned wc match russia eos
# ROUGE Scores:
#   ROUGE1 - Precision: 0.3750, Recall: 0.3000, F1 Score: 0.3333
#   ROUGE2 - Precision: 0.0000, Recall: 0.0000, F1 Score: 0.0000
#   ROUGEL - Precision: 0.3750, Recall: 0.3000, F1 Score: 0.3333
#
# --------------------------------------------------------------------------------
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Review 22: old video shows former prime minister atal bihari vajpayee playing national bravery award winning child 2003 award ceremony three time prime minister bharat ratna awardee passed away new delhi thursday funeral conducted today central government declared seven day state mourning across nation following demise
# Original Summary: sos watch vajpayee plays bravery award winning child stage eos
# Predicted Summary:  sos video shows pm vajpayee tribute vajpayee eos
# ROUGE Scores:
#   ROUGE1 - Precision: 0.3750, Recall: 0.3000, F1 Score: 0.3333
#   ROUGE2 - Precision: 0.0000, Recall: 0.0000, F1 Score: 0.0000
#   ROUGEL - Precision: 0.3750, Recall: 0.3000, F1 Score: 0.3333
#
# --------------------------------------------------------------------------------
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Review 23: uk court cleared extradition 50 year old bookie sanjeev chawla key accused 2000 match fixing scandal involving late south africa captain cronje india accused moved uk 1996 obtained british passport 2005 comes uk high court accepted assurances given india regarding tihar jail condition
# Original Summary: sos uk court clears extradition accused 2000 match fixing scandal eos
# Predicted Summary:  sos uk court rejects plea fixing case eos
# ROUGE Scores:
#   ROUGE1 - Precision: 0.6250, Recall: 0.4545, F1 Score: 0.5263
#   ROUGE2 - Precision: 0.2857, Recall: 0.2000, F1 Score: 0.2353
#   ROUGEL - Precision: 0.6250, Recall: 0.4545, F1 Score: 0.5263
#
# --------------------------------------------------------------------------------
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# Review 24: uk based woman lost jaw cancer seen cm bone grow back facial frame surgically attached january 55 year old woman part jaw removed battling mouth cancer 2015 fed tube left restricted speech following two failed surgeries
# Original Summary: sos woman removed jaw bone cm mouth cancer eos
# Predicted Summary:  sos woman gives birth woman hiv surgery eos
# ROUGE Scores:
#   ROUGE1 - Precision: 0.3750, Recall: 0.3333, F1 Score: 0.3529
#   ROUGE2 - Precision: 0.1429, Recall: 0.1250, F1 Score: 0.1333
#   ROUGEL - Precision: 0.3750, Recall: 0.3333, F1 Score: 0.3529
#
# --------------------------------------------------------------------------------
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# Review 25: actress deepika padukone set get wax statue madame tussauds london feel lot gratitude know give fans little movies really special said deepika said time visited madame tussauds london little
# Original Summary: sos deepika get wax statue london madame tussauds eos
# Predicted Summary:  sos deepika padukone perform wax statue madame tussauds eos
# ROUGE Scores:
#   ROUGE1 - Precision: 0.7778, Recall: 0.7778, F1 Score: 0.7778
#   ROUGE2 - Precision: 0.5000, Recall: 0.5000, F1 Score: 0.5000
#   ROUGEL - Precision: 0.7778, Recall: 0.7778, F1 Score: 0.7778
#
# --------------------------------------------------------------------------------
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# Review 26: bengaluru based vernacular social networking app sharechat banned 50 000 profiles problematic content like pornography violence fake news asked users report profiles problematic content reviewed complaints took appropriate action iit kanpur alumni sharechat lets users post content 14 local languages including telugu bhojpuri odia n
# Original Summary: sos bans 50 000 profiles tackle porn fake news eos
# Predicted Summary:  sos app launches app users using users report eos
# ROUGE Scores:
#   ROUGE1 - Precision: 0.2222, Recall: 0.2000, F1 Score: 0.2105
#   ROUGE2 - Precision: 0.0000, Recall: 0.0000, F1 Score: 0.0000
#   ROUGEL - Precision: 0.2222, Recall: 0.2000, F1 Score: 0.2105
#
# --------------------------------------------------------------------------------
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Review 27: karnataka chief minister hd kumaraswamy said anyone mercy get position state chief minister charity statement comes video former karnataka cm siddaramaiah saying kumaraswamy became cm support surfaced online siddaramaiah talking discussions jd congress presenting fresh budget nn
# Original Summary: sos anyone mercy get seat charity taka cm eos
# Predicted Summary:  sos andhra cm minister resigns cm eos
# ROUGE Scores:
#   ROUGE1 - Precision: 0.4286, Recall: 0.3333, F1 Score: 0.3750
#   ROUGE2 - Precision: 0.1667, Recall: 0.1250, F1 Score: 0.1429
#   ROUGEL - Precision: 0.4286, Recall: 0.3333, F1 Score: 0.3750
#
# --------------------------------------------------------------------------------
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Review 28: vice president venkaiah naidu tuesday said lessons emergency period included textbooks across india adding present generations know imposed former pm indira gandhi assent the then president fakhruddin ali ahmed imposed 21 month emergency june 25 1975 citing internal external threats india
# Original Summary: sos emergency period included textbooks vice prez eos
# Predicted Summary:  sos vice prez naidu gandhi president eos
# ROUGE Scores:
#   ROUGE1 - Precision: 0.5714, Recall: 0.5000, F1 Score: 0.5333
#   ROUGE2 - Precision: 0.1667, Recall: 0.1429, F1 Score: 0.1538
#   ROUGEL - Precision: 0.5714, Recall: 0.5000, F1 Score: 0.5333
#
# --------------------------------------------------------------------------------
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Review 29: silver winning indian team asian games first ever 4x400m mixed relay accused runner winners bahrain blocking hima das race tuesday athletics federation india confirmed appeal lodged decision wednesday hima change lanes bahrain runner fell front her
# Original Summary: sos 2nd placed india accuse winner bahrain blocking runner hima eos
# Predicted Summary:  sos india 1st indian women team asiad champ eos
# ROUGE Scores:
#   ROUGE1 - Precision: 0.3333, Recall: 0.2727, F1 Score: 0.3000
#   ROUGE2 - Precision: 0.0000, Recall: 0.0000, F1 Score: 0.0000
#   ROUGEL - Precision: 0.3333, Recall: 0.2727, F1 Score: 0.3000
#
# --------------------------------------------------------------------------------
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Review 30: former prison believed haunted britain opening guests overnight stay first time october 13 prison built among oldest prisons country stay guests served dinner breakfast get opportunity explore prison
# Original Summary: sos former prison opening guests one night eos
# Predicted Summary:  sos uk passes away aged lakh eos
# ROUGE Scores:
#   ROUGE1 - Precision: 0.2857, Recall: 0.2500, F1 Score: 0.2667
#   ROUGE2 - Precision: 0.0000, Recall: 0.0000, F1 Score: 0.0000
#   ROUGEL - Precision: 0.2857, Recall: 0.2500, F1 Score: 0.2667
#
# --------------------------------------------------------------------------------
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Review 31: royal challengers bangalore batsman chris gayle auction bat became first player score 10 000 t20 runs bat auctioned launch chris gayle foundation june along special golden bat gayle added wanted use golden bat get milestone
# Original Summary: sos gayle auction bat used hit record 10 000th t20 run eos
# Predicted Summary:  sos gayle gayle smashes record ipl match eos
# ROUGE Scores:
#   ROUGE1 - Precision: 0.5000, Recall: 0.3333, F1 Score: 0.4000
#   ROUGE2 - Precision: 0.1429, Recall: 0.0909, F1 Score: 0.1111
#   ROUGEL - Precision: 0.5000, Recall: 0.3333, F1 Score: 0.4000
#
# --------------------------------------------------------------------------------
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# Review 32: singer varsha singh alleged singer kailash kher used consider guru sent message read want make love also accused music composer toshi sexual misconduct influence alcohol put hand thigh toshi denied allegations
# Original Summary: sos kailash kher saying want make love singer eos
# Predicted Summary:  sos want like men sonu eos
# ROUGE Scores:
#   ROUGE1 - Precision: 0.5000, Recall: 0.3333, F1 Score: 0.4000
#   ROUGE2 - Precision: 0.0000, Recall: 0.0000, F1 Score: 0.0000
#   ROUGEL - Precision: 0.5000, Recall: 0.3333, F1 Score: 0.4000
#
# --------------------------------------------------------------------------------
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Review 33: screening film accidental prime minister cancelled kolkata hind cinema due security concerns amid protests youth congress activists close 100 activists protested front theatre west bengal youth congress president shadab khan said show reportedly halted first ten minutes film screened
# Original Summary: sos accidental halted kolkata theatre amid protests eos
# Predicted Summary:  sos bjp leader inaugurates pm modi eos
# ROUGE Scores:
#   ROUGE1 - Precision: 0.2857, Recall: 0.2500, F1 Score: 0.2667
#   ROUGE2 - Precision: 0.0000, Recall: 0.0000, F1 Score: 0.0000
#   ROUGEL - Precision: 0.2857, Recall: 0.2500, F1 Score: 0.2667
#
# --------------------------------------------------------------------------------
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# Review 34: former india captain mahendra singh dhoni slammed second fifty 11 year t20i career south africa wednesday playing 77th t20i innings dhoni smashed 52 28 balls including sixes fours dhoni scored fifty first 65 t20i innings scored two last 12 innings
# Original Summary: sos dhoni smashes second fifty 11 year t20i career eos
# Predicted Summary:  sos dhoni slams dhoni record odi odi cricket eos
# ROUGE Scores:
#   ROUGE1 - Precision: 0.3333, Recall: 0.3000, F1 Score: 0.3158
#   ROUGE2 - Precision: 0.1250, Recall: 0.1111, F1 Score: 0.1176
#   ROUGEL - Precision: 0.3333, Recall: 0.3000, F1 Score: 0.3158
#
# --------------------------------------------------------------------------------
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# Review 35: worldwide spending internet things iot security reach 1 5 billion 2018 according report research firm gartner represents 28 increase 1 2 billion spent iot security last year report said nearly 20 organisations observed least one iot based attack past three years report added
# Original Summary: sos global security spending reach 1 5bn 2018 report eos
# Predicted Summary:  sos us firm loses 1 billion deal eos
# ROUGE Scores:
#   ROUGE1 - Precision: 0.3750, Recall: 0.3000, F1 Score: 0.3333
#   ROUGE2 - Precision: 0.0000, Recall: 0.0000, F1 Score: 0.0000
#   ROUGEL - Precision: 0.3750, Recall: 0.3000, F1 Score: 0.3333
#
# --------------------------------------------------------------------------------
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# Review 36: ben affleck said continue superhero character batman upcoming standalone film batman speaking san diego comic con added batman coolest king part universe dc marvel thrilled rumours affleck starring batman emerged quit film director
# Original Summary: sos affleck says continue batman standalone film eos
# Predicted Summary:  sos john star star wars actor eos
# ROUGE Scores:
#   ROUGE1 - Precision: 0.2857, Recall: 0.2500, F1 Score: 0.2667
#   ROUGE2 - Precision: 0.0000, Recall: 0.0000, F1 Score: 0.0000
#   ROUGEL - Precision: 0.2857, Recall: 0.2500, F1 Score: 0.2667
#
# --------------------------------------------------------------------------------
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# Review 37: posing policemen two men allegedly raped 20 year old woman molested minor niece outer delhi sunday night accused approached woman niece claiming policemen police said victims statements recorded case registered men yet identified
# Original Summary: sos posing policemen two men sexually assault woman niece eos
# Predicted Summary:  sos delhi woman raped delhi woman raped eos
# ROUGE Scores:
#   ROUGE1 - Precision: 0.3750, Recall: 0.3000, F1 Score: 0.3333
#   ROUGE2 - Precision: 0.0000, Recall: 0.0000, F1 Score: 0.0000
#   ROUGEL - Precision: 0.3750, Recall: 0.3000, F1 Score: 0.3333
#
# --------------------------------------------------------------------------------
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# Review 38: mukesh ambani led reliance industries reportedly talks acquire mumbai based cable broadband service provider hathway cable talks aimed using company platform speed commercial launch jio home broadband services deal expected value hathway around ã¢ââ¹2 500 crore
# Original Summary: sos reliance talks buy broadband firm report eos
# Predicted Summary:  sos reliance jio shares fall ã¢ââ¹1 000 crore eos
# ROUGE Scores:
#   ROUGE1 - Precision: 0.3333, Recall: 0.3750, F1 Score: 0.3529
#   ROUGE2 - Precision: 0.1250, Recall: 0.1429, F1 Score: 0.1333
#   ROUGEL - Precision: 0.3333, Recall: 0.3750, F1 Score: 0.3529
#
# --------------------------------------------------------------------------------
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# Review 39: government warned whatsapp take urgent steps prevent spread irresponsible explosive messages platform leading cases lynching ministry electronics information technology said statement company cannot evade accountability responsibility comes lynching incidents took place based forward messages circulated whatsapp
# Original Summary: sos govt warns whatsapp leading mob lynchings eos
# Predicted Summary:  sos govt asks users hacked social media eos
# ROUGE Scores:
#   ROUGE1 - Precision: 0.3750, Recall: 0.3750, F1 Score: 0.3750
#   ROUGE2 - Precision: 0.1429, Recall: 0.1429, F1 Score: 0.1429
#   ROUGEL - Precision: 0.3750, Recall: 0.3750, F1 Score: 0.3750
#
# --------------------------------------------------------------------------------
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Review 40: calcutta high court justice cs karnan thursday declined undergo medical examination ordered supreme court asserting normal stable mind alleged sc order amounts insult harassment guardian consent required medical examination since family town test possible karnan added
# Original Summary: sos justice karnan refuses undergo medical test ordered sc eos
# Predicted Summary:  sos sc rejects plea plea plea sc eos
# ROUGE Scores:
#   ROUGE1 - Precision: 0.3750, Recall: 0.3000, F1 Score: 0.3333
#   ROUGE2 - Precision: 0.1429, Recall: 0.1111, F1 Score: 0.1250
#   ROUGEL - Precision: 0.3750, Recall: 0.3000, F1 Score: 0.3333
#
# --------------------------------------------------------------------------------
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# Review 41: sri lankan president maithripala sirisena sunday announced nationwide state emergency lifted emergency imposed control communal violence buddhists muslims clashed country central district kandy two people killed hundreds muslim owned properties 20 mosques damaged according reports
# Original Summary: sos sri lanka lifts nationwide emergency 12 days eos
# Predicted Summary:  sos sri lanka passes lanka test eos
# ROUGE Scores:
#   ROUGE1 - Precision: 0.5714, Recall: 0.4444, F1 Score: 0.5000
#   ROUGE2 - Precision: 0.3333, Recall: 0.2500, F1 Score: 0.2857
#   ROUGEL - Precision: 0.5714, Recall: 0.4444, F1 Score: 0.5000
#
# --------------------------------------------------------------------------------
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# Review 42: guards jammu kashmir army camp area averted terror attack opened fire two motorcycle borne militants approaching camp police said militants approached camp tuesday morning fired sentry post guards retaliated forcing terrorists flee
# Original Summary: sos 2 militants flee army camp guards open fire eos
# Predicted Summary:  sos army jawan killed encounter eos
# ROUGE Scores:
#   ROUGE1 - Precision: 0.5000, Recall: 0.3000, F1 Score: 0.3750
#   ROUGE2 - Precision: 0.0000, Recall: 0.0000, F1 Score: 0.0000
#   ROUGEL - Precision: 0.5000, Recall: 0.3000, F1 Score: 0.3750
#
# --------------------------------------------------------------------------------
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Review 43: virgin group founder richard branson friday said feeling united states president donald trump bizarre mistake pulling america paris climate deal terming trump withdrawal strange branson pointed head said knows goes added hopefully positive change mind
# Original Summary: sos trump regrets bizarre paris climate richard branson eos
# Predicted Summary:  sos trump gates calls trump climate deal eos
# ROUGE Scores:
#   ROUGE1 - Precision: 0.5000, Recall: 0.4444, F1 Score: 0.4706
#   ROUGE2 - Precision: 0.1429, Recall: 0.1250, F1 Score: 0.1333
#   ROUGEL - Precision: 0.5000, Recall: 0.4444, F1 Score: 0.4706
#
# --------------------------------------------------------------------------------
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Review 44: twitter users across world trolled irani man posting picture biryani ketchup mayonnaise terming best way eat dish man tweeted pass india indians posted twitter pass arabs tweeted hand pakistan
# Original Summary: sos twitter trolls man eating biryani eos
# Predicted Summary:  sos twitter reacts video shows india eos
# ROUGE Scores:
#   ROUGE1 - Precision: 0.4286, Recall: 0.4286, F1 Score: 0.4286
#   ROUGE2 - Precision: 0.1667, Recall: 0.1667, F1 Score: 0.1667
#   ROUGEL - Precision: 0.4286, Recall: 0.4286, F1 Score: 0.4286
#
# --------------------------------------------------------------------------------
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# Review 45: filmmaker kabir khan speaking salman khan starrer film tubelight performance box office said disappointed however added unfair pitch every film 2015 film bajrangi bhaijaan also starred salman notably tubelight became salman khan lowest eid opening four years
# Original Summary: sos disappointed kabir khan tubelight performance eos
# Predicted Summary:  sos salman khan star salman khan eos
# ROUGE Scores:
#   ROUGE1 - Precision: 0.4286, Recall: 0.4286, F1 Score: 0.4286
#   ROUGE2 - Precision: 0.0000, Recall: 0.0000, F1 Score: 0.0000
#   ROUGEL - Precision: 0.4286, Recall: 0.4286, F1 Score: 0.4286
#
# --------------------------------------------------------------------------------
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# ...
#
# --------------------------------------------------------------------------------
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# Review 86: philippine government revoked licence news website critical president rodrigo duterte war drugs denying move curbs freedom press authorities said media outlet violated clause limits media ownership philippine citizens termed ruling pure harassment
# Original Summary: sos philippines shuts news website critical prez duterte eos
# Predicted Summary:  sos philippine prez duterte calls ban fake law eos
# ROUGE Scores:
#   ROUGE1 - Precision: 0.5556, Recall: 0.5556, F1 Score: 0.5556
#   ROUGE2 - Precision: 0.2500, Recall: 0.2500, F1 Score: 0.2500
#   ROUGEL - Precision: 0.5556, Recall: 0.5556, F1 Score: 0.5556
#
# --------------------------------------------------------------------------------
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# Review 87: 18 year old national bravery award recipient khan designated special police officer agra police uttar pradesh khan awarded bravery award taking active measures thwart network drugs gambling rackets filed numerous police complaints also instrumental stopping kidnapping attempt six year old
# Original Summary: sos bravery award winner special police officer eos
# Predicted Summary:  sos bigg boss contestant wife commits suicide eos
# ROUGE Scores:
#   ROUGE1 - Precision: 0.2500, Recall: 0.2500, F1 Score: 0.2500
#   ROUGE2 - Precision: 0.0000, Recall: 0.0000, F1 Score: 0.0000
#   ROUGEL - Precision: 0.2500, Recall: 0.2500, F1 Score: 0.2500
#
# --------------------------------------------------------------------------------
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# Review 88: indian batsman shikhar dhawan miss india first three odis australia wife tweeted photo wife ahead surgery glad wife strength moment time hope surgery going go well part caption read
# Original Summary: sos shikhar dhawan shares photo wife ahead surgery eos
# Predicted Summary:  sos shami wife shares wife wife eos
# ROUGE Scores:
#   ROUGE1 - Precision: 0.5714, Recall: 0.4444, F1 Score: 0.5000
#   ROUGE2 - Precision: 0.0000, Recall: 0.0000, F1 Score: 0.0000
#   ROUGEL - Precision: 0.5714, Recall: 0.4444, F1 Score: 0.5000
#
# --------------------------------------------------------------------------------
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# Review 89: brazil based startup robotics partnership intel demonstrated ai powered adapter kit move wheelchair facial expressions gestures consumer electronics show ces 2019 las vegas kit learns user gestures automatically takes around seven minutes install plugged motorised wheelchair startup said
# Original Summary: sos ai kit control wheelchair face shown ces eos
# Predicted Summary:  sos startup makes ai users using ai eos
# ROUGE Scores:
#   ROUGE1 - Precision: 0.3750, Recall: 0.3333, F1 Score: 0.3529
#   ROUGE2 - Precision: 0.0000, Recall: 0.0000, F1 Score: 0.0000
#   ROUGEL - Precision: 0.3750, Recall: 0.3333, F1 Score: 0.3529
#
# --------------------------------------------------------------------------------
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# Review 90: speaking different kinds roles alia bhatt said want diva also want top film awards want balance worlds added alia said every film different picking similar films
# Original Summary: sos want also want top film awards alia eos
# Predicted Summary:  sos want work alia alia eos
# ROUGE Scores:
#   ROUGE1 - Precision: 0.6667, Recall: 0.4444, F1 Score: 0.5333
#   ROUGE2 - Precision: 0.4000, Recall: 0.2500, F1 Score: 0.3077
#   ROUGEL - Precision: 0.6667, Recall: 0.4444, F1 Score: 0.5333
#
# --------------------------------------------------------------------------------
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# Review 91: tvk leader velmurugan threatened party would let loose snakes inside chepauk stadium chennai csk first home match kkr goes tuesday comes amid protests state parties urging centre constitute cauvery management board earlier velmurugan said protestors responsible untoward incident stadium
# Original Summary: sos let loose snakes stadium csk match tn leader eos
# Predicted Summary:  sos hardik patel slams ipl 2018 eos
# ROUGE Scores:
#   ROUGE1 - Precision: 0.2857, Recall: 0.2000, F1 Score: 0.2353
#   ROUGE2 - Precision: 0.0000, Recall: 0.0000, F1 Score: 0.0000
#   ROUGEL - Precision: 0.2857, Recall: 0.2000, F1 Score: 0.2353
#
# --------------------------------------------------------------------------------
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# Review 92: actor nafisa ali diagnosed stage cancer shared video grandchildren cutting hair asked grandchildren cut hair realise going chemo fun captioned video instagram recently also shared picture shedding hair
# Original Summary: sos know gets hair cut eos
# Predicted Summary:  sos actress reveals cancer cancer eos
# ROUGE Scores:
#   ROUGE1 - Precision: 0.3333, Recall: 0.3333, F1 Score: 0.3333
#   ROUGE2 - Precision: 0.0000, Recall: 0.0000, F1 Score: 0.0000
#   ROUGEL - Precision: 0.3333, Recall: 0.3333, F1 Score: 0.3333
#
# --------------------------------------------------------------------------------
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Review 93: vaibhav kesarkar 24 year old cricketer mumbai died suffering heart attack field playing local cricket match kesarkar continued bat team despite chest pain severe discomfort according reports died nearby hospital taken medical examination
# Original Summary: sos 24 yr old mumbai cricketer suffers heart attack playing dies eos
# Predicted Summary:  sos fan dies falling match due match eos
# ROUGE Scores:
#   ROUGE1 - Precision: 0.3750, Recall: 0.2500, F1 Score: 0.3000
#   ROUGE2 - Precision: 0.0000, Recall: 0.0000, F1 Score: 0.0000
#   ROUGEL - Precision: 0.3750, Recall: 0.2500, F1 Score: 0.3000
#
# --------------------------------------------------------------------------------
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Review 94: air india wednesday rendered apology day passengers delayed pune delhi flight allowed deboard even complained air conditioners working causing discomfort last minute technical glitch led unfortunate delay flight process faced inconvenience deboarded clearance airline tweeted
# Original Summary: sos air india apologises passengers locked flight without ac eos
# Predicted Summary:  sos air india flight get emergency landing eos
# ROUGE Scores:
#   ROUGE1 - Precision: 0.6250, Recall: 0.5000, F1 Score: 0.5556
#   ROUGE2 - Precision: 0.2857, Recall: 0.2222, F1 Score: 0.2500
#   ROUGEL - Precision: 0.6250, Recall: 0.5000, F1 Score: 0.5556
#
# --------------------------------------------------------------------------------
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# Review 95: first ever test match played england australia 1877 south africa became third test playing nation 1889 india debuted 1932 2000 bangladesh became fourth asian country tenth overall play test icc awarded test status nation 17 years thursday granting full membership ireland afghanistan
# Original Summary: sos test nations play first ever test matches eos
# Predicted Summary:  sos india 1st test cricket test cricket eos
# ROUGE Scores:
#   ROUGE1 - Precision: 0.5000, Recall: 0.4444, F1 Score: 0.4706
#   ROUGE2 - Precision: 0.0000, Recall: 0.0000, F1 Score: 0.0000
#   ROUGEL - Precision: 0.5000, Recall: 0.4444, F1 Score: 0.4706
#
# --------------------------------------------------------------------------------
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# Review 96: prime minister narendra modi attended actress priyanka chopra american singer nick jonas wedding reception held delhi taj palace hotel tuesday priyanka wore white nude embellished lehenga nick chose velvet tuxedo occasion couple got married per christian well hindu rituals reportedly host another reception mumbai
# Original Summary: sos pm narendra modi attends priyanka nick delhi wedding reception eos
# Predicted Summary:  sos priyanka nick meets pm modi wedding reception eos
# ROUGE Scores:
#   ROUGE1 - Precision: 0.8889, Recall: 0.7273, F1 Score: 0.8000
#   ROUGE2 - Precision: 0.3750, Recall: 0.3000, F1 Score: 0.3333
#   ROUGEL - Precision: 0.6667, Recall: 0.5455, F1 Score: 0.6000
#
# --------------------------------------------------------------------------------
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Review 97: order fight misinformation rumours facebook owned messenger service whatsapp limiting text forwards five chats time users worldwide previously whatsapp user could forward message 20 individuals groups limit introduced india july spread rumours social media led killings lynching attempts
# Original Summary: sos whatsapp limits text chats time worldwide eos
# Predicted Summary:  sos facebook launches app users facebook eos
# ROUGE Scores:
#   ROUGE1 - Precision: 0.2857, Recall: 0.2500, F1 Score: 0.2667
#   ROUGE2 - Precision: 0.0000, Recall: 0.0000, F1 Score: 0.0000
#   ROUGEL - Precision: 0.2857, Recall: 0.2500, F1 Score: 0.2667
#
# --------------------------------------------------------------------------------
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# Review 98: oldest person world violet brown passed away age 117 friday brown born jamaica march 10 1900 suffered irregular heartbeat dehydrated days passed away following death 117 year old japanese woman nabi tajima born august 1900 become world oldest person
# Original Summary: sos world oldest person dies aged 117 eos
# Predicted Summary:  sos world oldest woman dies aged aged aged eos
# ROUGE Scores:
#   ROUGE1 - Precision: 0.6667, Recall: 0.7500, F1 Score: 0.7059
#   ROUGE2 - Precision: 0.3750, Recall: 0.4286, F1 Score: 0.4000
#   ROUGEL - Precision: 0.6667, Recall: 0.7500, F1 Score: 0.7059
#
# --------------------------------------------------------------------------------
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# Review 99: india delayed implementation higher tariffs goods imported us december 17 despite us removing least 50 indian products list items eligible duty free treatment india raise tariffs us goods november us move unilaterally raise import duties indian steel aluminium products
# Original Summary: sos india delays retaliatory tariffs us goods eos
# Predicted Summary:  sos india trade largest oil oil steel eos
# ROUGE Scores:
#   ROUGE1 - Precision: 0.3750, Recall: 0.3750, F1 Score: 0.3750
#   ROUGE2 - Precision: 0.1429, Recall: 0.1429, F1 Score: 0.1429
#   ROUGEL - Precision: 0.3750, Recall: 0.3750, F1 Score: 0.3750
#
# --------------------------------------------------------------------------------
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# Review 100: reliance naval engineering saturday said anil ambani resigned company director immediate effect ambani resigned compliance companies act 2013 prescribing limit 10 public companies company said reliance naval engineering operates indiaã¢ââs largest integrated shipbuilding facility facing financial constraints
# Original Summary: sos anil ambani quits reliance naval engineering director eos
# Predicted Summary:  sos rcom ambani reliance jio quits eos
# ROUGE Scores:
#   ROUGE1 - Precision: 0.7143, Recall: 0.5556, F1 Score: 0.6250
#   ROUGE2 - Precision: 0.0000, Recall: 0.0000, F1 Score: 0.0000
#   ROUGEL - Precision: 0.5714, Recall: 0.4444, F1 Score: 0.5000
#
# --------------------------------------------------------------------------------

# %%
import pickle

# Save tokenizers
with open("source_tokenizer.pkl", "wb") as f:
    pickle.dump(x_tokenizer, f)  # Assuming x_tokenizer is your source tokenizer

with open("target_tokenizer.pkl", "wb") as f:
    pickle.dump(y_tokenizer, f)  # Assuming y_tokenizer is your target tokenizer

# %%
parameters = {
    "max_text_len": max_text_len,
    "max_summary_len": max_summary_len,
}

with open("parameters.pkl", "wb") as f:
    pickle.dump(parameters, f)
