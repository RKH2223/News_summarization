# %%
import numpy as np 
import pandas as pd

# %%
summary = pd.read_csv(r"/kaggle/input/news-summary/news_summary_HT.csv",encoding='iso-8859-1')
summary.head()
# Out:
#                author                  date  \
# 0        Chhavi Tyagi  03 Aug 2017,Thursday
# 1         Daisy Mowke  03 Aug 2017,Thursday
# 2      Arshiya Chopra  03 Aug 2017,Thursday
# 3       Sumedha Sehra  03 Aug 2017,Thursday
# 4  Aarushi Maheshwari  03 Aug 2017,Thursday
#
#                                            headlines  \
# 0  Daman & Diu revokes mandatory Rakshabandhan in...
# 1  Malaika slams user who trolled her for 'divorc...
# 2  'Virgin' now corrected to 'Unmarried' in IGIMS...
# 3  Aaj aapne pakad liya: LeT man Dujana before be...
# 4  Hotel staff to get training to spot signs of s...
#
#                                            read_more  \
# 0  http://www.hindustantimes.com/india-news/raksh...
# 1  http://www.hindustantimes.com/bollywood/malaik...
# 2  http://www.hindustantimes.com/patna/bihar-igim...
# 3  http://indiatoday.intoday.in/story/abu-dujana-...
# 4  http://indiatoday.intoday.in/story/sex-traffic...
#
#                                                 text  \
# 0  The Administration of Union Territory Daman an...
# 1  Malaika Arora slammed an Instagram user who tr...
# 2  The Indira Gandhi Institute of Medical Science...
# 3  Lashkar-e-Taiba's Kashmir commander Abu Dujana...
# 4  Hotels in Maharashtra will train their staff t...
#
#                                                ctext
# 0  The Daman and Diu administration on Wednesday ...
# 1  From her special numbers to TV?appearances, Bo...
# 2  The Indira Gandhi Institute of Medical Science...
# 3  Lashkar-e-Taiba's Kashmir commander Abu Dujana...
# 4  Hotels in Mumbai and other Indian cities are t...

# %%
summary['headlines'][1]
# Out:
# "Malaika slams user who trolled her for 'divorcing rich man' "

# %%
summary['text'][1]
# Out:
# 'Malaika Arora slammed an Instagram user who trolled her for "divorcing a rich man" and "having fun with the alimony". "Her life now is all about wearing short clothes, going to gym or salon, enjoying vacation[s]," the user commented. Malaika responded, "You certainly got to get your damn facts right before spewing sh*t on me...when you know nothing about me."'

# %%
summary['ctext'][1]
# Out:
# 'From her special numbers to TV?appearances, Bollywood actor Malaika Arora Khan has managed to carve her own identity. The actor, who made her debut in the Hindi film industry with the blockbuster debut opposite Shah Rukh Khan in Chaiyya Chaiyya from Dil Se (1998), is still remembered for the song. However, for trolls, she is a woman first and what matters right now is that she divorced a ?rich man?.  On Wednesday, Malaika Arora shared a gorgeous picture of herself on Instagram and a follower decided to troll her for using her ?alumni? (read alimony) money to wear ?short clothes and going to gym or salon?. Little did he/she know that the Munni Badnam star would reply with the perfect comeback. Take a look at the interaction:     Super excited to be affiliated with Khanna Jewellers @khannajewellerskj as their brand ambassador. Crafted to perfection, their stunning statement jewellery is a must have for every jewellery lover. #khannajewellers...#maksquad?? #hair @hairbypriyanka #stylist @manekaharisinghani #manager @ektakauroberoi #mua? @subbu28 #photographer @prasdnaik A post shared by Malaika Arora Khan (@malaikaarorakhanofficial) on Aug 2, 2017 at 6:20am PDT Then, Malaika decided to reply: The entire conversation only proves that no matter if a woman is successful, she will be attacked the moment she decides to step out of bounds the society decided for her. Apart from being a successful woman who lives life on her own terms, Malaika has literally played all the roles traditionally prescribed for a woman - she married quite early, had a son and raised him and was always around with the ?khandan?. But then, she got divorced and alimony is the taunt being thrown at her. The details of the alimony are only known to Malaika, her husband Arbaaz Khan and perhaps the family. The couple has handled the divorce with the utmost dignity. But we can vouch for the fact that she did not  need an alimony to buy clothes (short or not, her choice), go on vacations and enjoy her life. If anything, she is as successful, if not more, than her ex-husband.What happened between Arbaaz and Malaika is their personal concern. But to claim that Malaika married and then divorced Arbaaz for money doesn?t hold water. For those who do not agree, please get a course in feminism and for others, here?s a playlist of some of her most popular songs. Follow @htshowbiz for more'

# %%
raw = pd.read_csv('/kaggle/input/news-summary-dataset/news_summary_more.csv', encoding='iso-8859-1')
raw.head()
# Out:
#                                            headlines  \
# 0  upGrad learner switches to career in ML & Al w...
# 1  Delhi techie wins free food from Swiggy for on...
# 2  New Zealand end Rohit Sharma-led India's 12-ma...
# 3  Aegon life iTerm insurance plan helps customer...
# 4  Have known Hirani for yrs, what if MeToo claim...
#
#                                                 text
# 0  Saurav Kant, an alumnus of upGrad and IIIT-B's...
# 1  Kunal Shah's credit card bill payment platform...
# 2  New Zealand defeated India by 8 wickets in the...
# 3  With Aegon Life iTerm Insurance plan, customer...
# 4  Speaking about the sexual harassment allegatio...

# %%
raw['headlines'][1]
# Out:
# 'Delhi techie wins free food from Swiggy for one year on CRED'

# %%
raw['text'][1]
# Out:
# "Kunal Shah's credit card bill payment platform, CRED, gave users a chance to win free food from Swiggy for one year. Pranav Kaushik, a Delhi techie, bagged this reward after spending 2000 CRED coins. Users get one CRED coin per rupee of bill paid, which can be used to avail rewards from brands like Ixigo, BookMyShow, UberEats, Cult.Fit and more."

# %%
pre1 =  raw.iloc[:,0:2].copy()
pre1['head + text'] = pre1['headlines'].str.cat(pre1['text'], sep =" ")

# %%
pre1.head()
# Out:
#                                            headlines  \
# 0  upGrad learner switches to career in ML & Al w...
# 1  Delhi techie wins free food from Swiggy for on...
# 2  New Zealand end Rohit Sharma-led India's 12-ma...
# 3  Aegon life iTerm insurance plan helps customer...
# 4  Have known Hirani for yrs, what if MeToo claim...
#
#                                                 text  \
# 0  Saurav Kant, an alumnus of upGrad and IIIT-B's...
# 1  Kunal Shah's credit card bill payment platform...
# 2  New Zealand defeated India by 8 wickets in the...
# 3  With Aegon Life iTerm Insurance plan, customer...
# 4  Speaking about the sexual harassment allegatio...
#
#                                          head + text
# 0  upGrad learner switches to career in ML & Al w...
# 1  Delhi techie wins free food from Swiggy for on...
# 2  New Zealand end Rohit Sharma-led India's 12-ma...
# 3  Aegon life iTerm insurance plan helps customer...
# 4  Have known Hirani for yrs, what if MeToo claim...

# %%
pre2 = summary.iloc[:,0:6].copy()
pre2['head + text'] = pre2['author'].str.cat(pre2['date'].str.cat(pre2['headlines'].str.cat(pre2['read_more'].str.cat(pre2['text'].str.cat(pre2['ctext'], sep = " "), sep =" "),sep= " "), sep = " "),sep= " ")

# %%
pre2.head()
# Out:
#                author                  date  \
# 0        Chhavi Tyagi  03 Aug 2017,Thursday
# 1         Daisy Mowke  03 Aug 2017,Thursday
# 2      Arshiya Chopra  03 Aug 2017,Thursday
# 3       Sumedha Sehra  03 Aug 2017,Thursday
# 4  Aarushi Maheshwari  03 Aug 2017,Thursday
#
#                                            headlines  \
# 0  Daman & Diu revokes mandatory Rakshabandhan in...
# 1  Malaika slams user who trolled her for 'divorc...
# 2  'Virgin' now corrected to 'Unmarried' in IGIMS...
# 3  Aaj aapne pakad liya: LeT man Dujana before be...
# 4  Hotel staff to get training to spot signs of s...
#
#                                            read_more  \
# 0  http://www.hindustantimes.com/india-news/raksh...
# 1  http://www.hindustantimes.com/bollywood/malaik...
# 2  http://www.hindustantimes.com/patna/bihar-igim...
# 3  http://indiatoday.intoday.in/story/abu-dujana-...
# 4  http://indiatoday.intoday.in/story/sex-traffic...
#
#                                                 text  \
# 0  The Administration of Union Territory Daman an...
# 1  Malaika Arora slammed an Instagram user who tr...
# 2  The Indira Gandhi Institute of Medical Science...
# 3  Lashkar-e-Taiba's Kashmir commander Abu Dujana...
# 4  Hotels in Maharashtra will train their staff t...
#
#                                                ctext  \
# 0  The Daman and Diu administration on Wednesday ...
# 1  From her special numbers to TV?appearances, Bo...
# 2  The Indira Gandhi Institute of Medical Science...
# 3  Lashkar-e-Taiba's Kashmir commander Abu Dujana...
# 4  Hotels in Mumbai and other Indian cities are t...
#
#                                          head + text
# 0  Chhavi Tyagi 03 Aug 2017,Thursday Daman & Diu ...
# 1  Daisy Mowke 03 Aug 2017,Thursday Malaika slams...
# 2  Arshiya Chopra 03 Aug 2017,Thursday 'Virgin' n...
# 3  Sumedha Sehra 03 Aug 2017,Thursday Aaj aapne p...
# 4  Aarushi Maheshwari 03 Aug 2017,Thursday Hotel ...

# %%
pre2['head + text'][500]
# Out:
# 'Chhavi Tyagi 26 Jul 2017,Wednesday Nitish Kumar did not ask for Tejashwi\'s resignation: Lalu http://indiatoday.intoday.in/story/tejashwi-nitish-kumar-lalu-yadav-mahagathbandhan-jdu-rjd/1/1011250.html?utm_source=inshorts&utm_medium=referral&utm_campaign=fullarticle  RJD Chief Lalu Prasad Yadav on Wednesday said that Bihar Chief Minister Nitish Kumar has not asked for his son Tejashwi Yadav\'s resignation after the CBI raided him over corruption allegations. "We will not tolerate any disrespect towards him (Nitish Kumar). We have formed the grand alliance, made Nitish CM. Why will we break the alliance," Lalu said. As Nitish Kumar meets his party - Janata Dal United - MLAs later in the evening today in Patna, senior alliance partner Lalu Prasad today reiterated that his son Tejashwi Yadav won\'t resign. Deputy CM Tejashwi is facing corruption allegations after the CBI filed a case against him."Tejashwi will not resign. Nitish Kumar is leader of the alliance but he has not asked for his resignation," Lalu told reporters after a separate meeting of RJD MLAs.\xa0 "Nitish Kumar is leader of grand alliance. We will not tolerate any disrespect towards him. We have formed the grand alliance, made Nitish CM. Why will we break the alliance," Lalu said. "We have spoken to Nitish Kumar and he said he is not asking for Tejaswi\'s resignation. BJP is trying to frame us but are we are not afraid of their tactic," former CM Rabri Devi added.\xa0 The fate of Bihar\'s Mahagathbandhan or grand alliance (RJD, JD-U and Congress) is likely to be decided today or by tomorrow as the JD-U is firm on Tejashwi\'s resignation.Nitish Kumar is expected to make some tough decision before the start of Bihar Asssembly\'s Monsoon Session (July 28) which the BJP has threatened to disrupt demanding the CM to take a call on his deputy.Tejashwi and his party RJD, which has most number of MLAs\xa0 of the three alliance partners, have repeatedly described the corruption charges as a conspiracy by Opposition BJP. Earlier this month, Tejashwi and Nitish had a closed door meeting during which the deputy CM tabled his stance and claimed that he was being framed. Insiders said Nitish was not convinced with Tejashwi\'s explanation.It is believed that Nitish is miffed with Tejashwi as he has failed to present solid evidence in support of his \'not guilty\' claim despite being given ample time.Congress President Sonia Gandhi and son Rahul Gandhi have also tried to bridge the ever-widening gap between the JD-U and RJD but in vain.The JD-U has made abundantly clear that Nitish Kumar\'s taintless image is more important to the party than sticking with power. "Nitish is the leader of Mahagathbandhan, no one else. Those who are threatening of having 80 MLAs with them should not be in any kind of confusion. It will not take us even 5 minutes to quit government, power," JD-U spokesperson Ajay Alok had told India Today.The Janata Dal (United) has 71 MLAs, while Lalu\'s RJD has 80 seats\xa0 in the 243-seat Bihar Assembly.\xa0 ALSO READ:Nitish Kumar calls meeting of JD-U MLAs, pressure mounts further on Tejashwi YadavRevealed: What Tejashwi Yadav told Nitish Kumar in their 45-minute meeting behind closed doors'

# %%
pre = pd.DataFrame()
pre['text'] = pd.concat([pre1['text'], pre2['text']], ignore_index=True)
pre['summary'] = pd.concat([pre1['headlines'],pre2['headlines']],ignore_index = True)

# %%
pre.head()
# Out:
#                                                 text  \
# 0  Saurav Kant, an alumnus of upGrad and IIIT-B's...
# 1  Kunal Shah's credit card bill payment platform...
# 2  New Zealand defeated India by 8 wickets in the...
# 3  With Aegon Life iTerm Insurance plan, customer...
# 4  Speaking about the sexual harassment allegatio...
#
#                                              summary
# 0  upGrad learner switches to career in ML & Al w...
# 1  Delhi techie wins free food from Swiggy for on...
# 2  New Zealand end Rohit Sharma-led India's 12-ma...
# 3  Aegon life iTerm insurance plan helps customer...
# 4  Have known Hirani for yrs, what if MeToo claim...

# %%
pre['text'][:10]
# Out:
# 0    Saurav Kant, an alumnus of upGrad and IIIT-B's...
# 1    Kunal Shah's credit card bill payment platform...
# 2    New Zealand defeated India by 8 wickets in the...
# 3    With Aegon Life iTerm Insurance plan, customer...
# 4    Speaking about the sexual harassment allegatio...
# 5    Pakistani singer Rahat Fateh Ali Khan has deni...
# 6    India recorded their lowest ODI total in New Z...
# 7    Weeks after ex-CBI Director Alok Verma told th...
# 8    Andhra Pradesh CM N Chandrababu Naidu has said...
# 9    Congress candidate Shafia Zubair won the Ramga...
# Name: text, dtype: object

# %%
# Cleaning Operations:

'''1.Remove Special Characters: Handles unwanted symbols like tabs (\t), carriage returns (\r), and newlines (\n).
2.Normalize Case: Converts text to lowercase.
3.Handle Redundant Patterns: Replaces multiple underscores, dashes, tildes, and other repeated symbols with spaces.
4.Sanitize URLs: Extracts and retains the domain name, removing the rest of the URL.
5.Replace Identifiable Patterns:
6.Replaces sequences like "INC1234" or "CM1234" with placeholders (INC_NUM, CM_NUM).
7.Remove Extraneous Characters: Removes brackets, quotes, and non-alphanumeric symbols.
8.Reduce Redundant Spaces: Consolidates multiple spaces into a single space.'''
# Out:
# '1.Remove Special Characters: Handles unwanted symbols like tabs (\t), carriage returns (\r), and newlines (\n).\n2.Normalize Case: Converts text to lowercase.\n3.Handle Redundant Patterns: Replaces multiple underscores, dashes, tildes, and other repeated symbols with spaces.\n4.Sanitize URLs: Extracts and retains the domain name, removing the rest of the URL.\n5.Replace Identifiable Patterns:\n6.Replaces sequences like "INC1234" or "CM1234" with placeholders (INC_NUM, CM_NUM).\n7.Remove Extraneous Characters: Removes brackets, quotes, and non-alphanumeric symbols.\n8.Reduce Redundant Spaces: Consolidates multiple spaces into a single space.'

# %%
import re 
def text_strip(column):

  for row in column:    
    row=re.sub("(\\t)", ' ', str(row)).lower() 
    row=re.sub("(\\r)", ' ', str(row)).lower() 
    row=re.sub("(\\n)", ' ', str(row)).lower()
    
    row=re.sub("(__+)", ' ', str(row)).lower()   
    row=re.sub("(--+)", ' ', str(row)).lower()   
    row=re.sub("(~~+)", ' ', str(row)).lower()   
    row=re.sub("(\+\++)", ' ', str(row)).lower()   
    row=re.sub("(\.\.+)", ' ', str(row)).lower()  
    
    row=re.sub(r"[<>()|&©ø\[\]\'\",;?~*!]", ' ', str(row)).lower() 
    
    row=re.sub("(mailto:)", ' ', str(row)).lower() 
    row=re.sub(r"(\\x9\d)", ' ', str(row)).lower() 
    row=re.sub("([iI][nN][cC]\d+)", 'INC_NUM', str(row)).lower() 
    row=re.sub("([cC][mM]\d+)|([cC][hH][gG]\d+)", 'CM_NUM', str(row)).lower() 
    
    
    row=re.sub("(\.\s+)", ' ', str(row)).lower() 
    row=re.sub("(\-\s+)", ' ', str(row)).lower() 
    row=re.sub("(\:\s+)", ' ', str(row)).lower() 
    
    row=re.sub("(\s+.\s+)", ' ', str(row)).lower() 

    # to replace an url
    try:
        url = re.search(r'((https*:\/*)([^\/\s]+))(.[^\s]+)', str(row))
        repl_url = url.group(3)
        row = re.sub(r'((https*:\/*)([^\/\s]+))(.[^\s]+)',repl_url, str(row))
    except:
        pass
    

    
    row = re.sub("(\s+)",' ',str(row)).lower() #remove multiple spaces
    
    row=re.sub("(\s+.\s+)", ' ', str(row)).lower()

    
    
    yield row

# %%
'''import re
import nltk
from nltk.corpus import stopwords

# Download the NLTK stopwords (you only need to do this once)
nltk.download('stopwords')

# Get the list of English stopwords
stop_words = set(stopwords.words('english'))

def text_strip(column):
    for row in column:
        # Basic cleaning
        row = re.sub("(\\t)", ' ', str(row)).lower()
        row = re.sub("(\\r)", ' ', str(row)).lower()
        row = re.sub("(\\n)", ' ', str(row)).lower()

        # More cleaning rules
        row = re.sub("(__+)", ' ', str(row)).lower()
        row = re.sub("(--+)", ' ', str(row)).lower()
        row = re.sub("(~~+)", ' ', str(row)).lower()
        row = re.sub("(\+\++)", ' ', str(row)).lower()
        row = re.sub("(\.\.+)", ' ', str(row)).lower()

        row = re.sub(r"[<>()|&©ø\[\]\'\",;?~*!]", ' ', str(row)).lower()

        row = re.sub("(mailto:)", ' ', str(row)).lower()
        row = re.sub(r"(\\x9\d)", ' ', str(row)).lower()
        row = re.sub("([iI][nN][cC]\d+)", 'INC_NUM', str(row)).lower()
        row = re.sub("([cC][mM]\d+)|([cC][hH][gG]\d+)", 'CM_NUM', str(row)).lower()

        row = re.sub("(\.\s+)", ' ', str(row)).lower()
        row = re.sub("(\-\s+)", ' ', str(row)).lower()
        row = re.sub("(\:\s+)", ' ', str(row)).lower()

        row = re.sub("(\s+.\s+)", ' ', str(row)).lower()

        # Replace URLs
        try:
            url = re.search(r'((https*:\/*)([^\/\s]+))(.[^\s]+)', str(row))
            repl_url = url.group(3)
            row = re.sub(r'((https*:\/*)([^\/\s]+))(.[^\s]+)', repl_url, str(row))
        except:
            pass

        row = re.sub("(\s+)", ' ', str(row)).lower()  # Remove multiple spaces
        row = re.sub("(\s+.\s+)", ' ', str(row)).lower()

        # Remove stopwords
        row = ' '.join([word for word in row.split() if word not in stop_words])

        # Yield the cleaned text row
        yield row
'''
# Out:
# 'import re\nimport nltk\nfrom nltk.corpus import stopwords\n\n# Download the NLTK stopwords (you only need to do this once)\nnltk.download(\'stopwords\')\n\n# Get the list of English stopwords\nstop_words = set(stopwords.words(\'english\'))\n\ndef text_strip(column):\n    for row in column:\n        # Basic cleaning\n        row = re.sub("(\\t)", \' \', str(row)).lower()\n        row = re.sub("(\\r)", \' \', str(row)).lower()\n        row = re.sub("(\\n)", \' \', str(row)).lower()\n\n        # More cleaning rules\n        row = re.sub("(__+)", \' \', str(row)).lower()\n        row = re.sub("(--+)", \' \', str(row)).lower()\n        row = re.sub("(~~+)", \' \', str(row)).lower()\n        row = re.sub("(\\+\\++)", \' \', str(row)).lower()\n        row = re.sub("(\\.\\.+)", \' \', str(row)).lower()\n\n        row = re.sub(r"[<>()|&©ø\\[\\]\'",;?~*!]", \' \', str(row)).lower()\n\n        row = re.sub("(mailto:)", \' \', str(row)).lower()\n        row = re.sub(r"(\\x9\\d)", \' \', str(row)).lower()\n        row = re.sub("([iI][nN][cC]\\d+)", \'INC_NUM\', str(row)).lower()\n        row = re.sub("([cC][mM]\\d+)|([cC][hH][gG]\\d+)", \'CM_NUM\', str(row)).lower()\n\n        row = re.sub("(\\.\\s+)", \' \', str(row)).lower()\n        row = re.sub("(\\-\\s+)", \' \', str(row)).lower()\n        row = re.sub("(\\:\\s+)", \' \', str(row)).lower()\n\n        row = re.sub("(\\s+.\\s+)", \' \', str(row)).lower()\n\n        # Replace URLs\n        try:\n            url = re.search(r\'((https*:\\/*)([^\\/\\s]+))(.[^\\s]+)\', str(row))\n            repl_url = url.group(3)\n            row = re.sub(r\'((https*:\\/*)([^\\/\\s]+))(.[^\\s]+)\', repl_url, str(row))\n        except:\n            pass\n\n        row = re.sub("(\\s+)", \' \', str(row)).lower()  # Remove multiple spaces\n        row = re.sub("(\\s+.\\s+)", \' \', str(row)).lower()\n\n        # Remove stopwords\n        row = \' \'.join([word for word in row.split() if word not in stop_words])\n\n        # Yield the cleaned text row\n        yield row\n'

# %%
# Count the number of words in the 'text' and 'summary' columns before preprocessing
pre['text_word_count_before'] = pre['text'].apply(lambda x: len(str(x).split()))
pre['summary_word_count_before'] = pre['summary'].apply(lambda x: len(str(x).split()))

# Calculate total word count before preprocessing
total_text_words_before = pre['text_word_count_before'].sum()
total_summary_words_before = pre['summary_word_count_before'].sum()

print(f'Total words in text before preprocessing: {total_text_words_before}')
print(f'Total words in summary before preprocessing: {total_summary_words_before}')
# Out:
# Total words in text before preprocessing: 5993839
# Total words in summary before preprocessing: 982067

# %%
# Apply the preprocessing function to 'text' and 'summary' columns
pre['text_preprocessed'] = list(text_strip(pre['text']))
pre['summary_preprocessed'] = list(text_strip(pre['summary']))

# Count the number of words in the preprocessed columns
pre['text_word_count_after'] = pre['text_preprocessed'].apply(lambda x: len(str(x).split()))
pre['summary_word_count_after'] = pre['summary_preprocessed'].apply(lambda x: len(str(x).split()))

# Calculate total word count after preprocessing
total_text_words_after = pre['text_word_count_after'].sum()
total_summary_words_after = pre['summary_word_count_after'].sum()

print(f'Total words in text after preprocessing: {total_text_words_after}')
print(f'Total words in summary after preprocessing: {total_summary_words_after}')
# Out:
# Total words in text after preprocessing: 5858431
# Total words in summary after preprocessing: 971330

# %%
pre
# Out:
#                                                      text  \
# 0       Saurav Kant, an alumnus of upGrad and IIIT-B's...
# 1       Kunal Shah's credit card bill payment platform...
# 2       New Zealand defeated India by 8 wickets in the...
# 3       With Aegon Life iTerm Insurance plan, customer...
# 4       Speaking about the sexual harassment allegatio...
# ...                                                   ...
# 102910  Fruit juice concentrate maker Rasna is eyeing ...
# 102911  Former Indian cricketer Sachin Tendulkar atten...
# 102912  Aamir Khan, while talking about reality shows ...
# 102913  The Maharashtra government has initiated an in...
# 102914  At least 400 languages or more than half langu...
#
#                                                   summary  \
# 0       upGrad learner switches to career in ML & Al w...
# 1       Delhi techie wins free food from Swiggy for on...
# 2       New Zealand end Rohit Sharma-led India's 12-ma...
# 3       Aegon life iTerm insurance plan helps customer...
# 4       Have known Hirani for yrs, what if MeToo claim...
# ...                                                   ...
# 102910  Rasna seeking ?250 cr revenue from snack categ...
# 102911  Sachin attends Rajya Sabha after questions on ...
# 102912  Shouldn't rob their childhood: Aamir on kids r...
# 102913  Asha Bhosle gets ?53,000 power bill for unused...
# 102914  More than half of India's languages may die in...
#
#         text_word_count_before  summary_word_count_before  \
# 0                           60                         13
# 1                           60                         12
# 2                           60                          9
# 3                           60                          9
# 4                           60                         13
# ...                        ...                        ...
# 102910                      60                          9
# 102911                      60                          8
# 102912                      59                          9
# 102913                      59                          9
# 102914                      60                         11
#
#                                         text_preprocessed  \
# 0       saurav kant an alumnus of upgrad and iiit-b pg...
# 1       kunal shah credit card bill payment platform c...
# 2       new zealand defeated india by wickets in the f...
# 3       with aegon life iterm insurance plan customers...
# 4       speaking about the sexual harassment allegatio...
# ...                                                   ...
# 102910  fruit juice concentrate maker rasna is eyeing ...
# 102911  former indian cricketer sachin tendulkar atten...
# 102912  aamir khan while talking about reality shows o...
# 102913  the maharashtra government has initiated an in...
# 102914  at least 400 languages or more than half langu...
#
#                                      summary_preprocessed  \
# 0       upgrad learner switches to career in ml al wit...
# 1       delhi techie wins free food from swiggy for on...
# 2       new zealand end rohit sharma-led india 12-matc...
# 3       aegon life iterm insurance plan helps customer...
# 4       have known hirani for yrs what if metoo claims...
# ...                                                   ...
# 102910  rasna seeking 250 cr revenue from snack catego...
# 102911  sachin attends rajya sabha after questions on ...
# 102912  shouldn rob their childhood aamir on kids real...
# 102913  asha bhosle gets 53 000 power bill for unused ...
# 102914  more than half of india languages may die in 5...
#
#         text_word_count_after  summary_word_count_after
# 0                          56                        12
# 1                          58                        12
# 2                          59                         9
# 3                          60                         9
# 4                          60                        13
# ...                       ...                       ...
# 102910                     59                         9
# 102911                     59                         8
# 102912                     59                         9
# 102913                     60                        10
# 102914                     58                        11
#
# [102915 rows x 8 columns]

# %%
pre['text_preprocessed'][0]
# Out:
# 'saurav kant an alumnus of upgrad and iiit-b pg program in machine learning and artificial intelligence was sr systems engineer at infosys with almost years of work experience the program and upgrad 360-degree career support helped him transition to data scientist at tech mahindra with 90% salary hike upgrad online power learning has powered lakh+ careers.'

# %%
pre['summary_preprocessed'][0]
# Out:
# 'upgrad learner switches to career in ml al with 90% salary hike'

# %%
brief_cleaning1 = text_strip(pre['text'])
brief_cleaning2 = text_strip(pre['summary'])

# %%
print(brief_cleaning1)
# Out:
# <generator object text_strip at 0x7f9cd2ec7b50>

# %%
# 1. Maximum Sentence Length Before and After Preprocessing
# Maximum sentence length before preprocessing
pre['sentence_length_before'] = pre['text'].apply(lambda x: len(str(x).split()))
max_sentence_length_before = pre['sentence_length_before'].max()

# Maximum sentence length after preprocessing
pre['sentence_length_after'] = pre['text_preprocessed'].apply(lambda x: len(str(x).split()))
max_sentence_length_after = pre['sentence_length_after'].max()

print(f'Maximum sentence length before preprocessing: {max_sentence_length_before}')
print(f'Maximum sentence length after preprocessing: {max_sentence_length_after}')
# Out:
# Maximum sentence length before preprocessing: 91
# Maximum sentence length after preprocessing: 84

# %%
# 2. Most Frequent Words Before and After Preprocessing

from collections import Counter

# Tokenize words before preprocessing and count their frequencies
words_before = ' '.join(pre['text']).split()
word_counts_before = Counter(words_before)

# Tokenize words after preprocessing and count their frequencies
words_after = ' '.join(pre['text_preprocessed']).split()
word_counts_after = Counter(words_after)

# Get the most common words (top 10 most frequent)
most_common_before = word_counts_before.most_common(10)
most_common_after = word_counts_after.most_common(10)

print(f'Most frequent words before preprocessing: {most_common_before}')
print(f'Most frequent words after preprocessing: {most_common_after}')
# Out:
# Most frequent words before preprocessing: [('the', 283966), ('to', 150894), ('in', 130800), ('a', 128658), ('of', 126737), ('and', 111113), ('on', 73823), ('The', 65433), ('has', 58972), ('for', 57700)]
# Most frequent words after preprocessing: [('the', 354092), ('to', 152016), ('in', 135482), ('of', 127329), ('and', 112005), ('on', 75122), ('has', 59185), ('for', 58548), ('that', 54279), ('said', 52517)]

# %%
# 3. Most Frequent N-Grams (Bigrams or Trigrams) Before and After Preprocessing

from sklearn.feature_extraction.text import CountVectorizer

# Function to get the most frequent n-grams
def get_most_frequent_ngrams(text_data, n=2, top_n=10):
    vectorizer = CountVectorizer(ngram_range=(n, n), stop_words='english')
    ngram_matrix = vectorizer.fit_transform(text_data)
    ngram_counts = Counter(zip(*ngram_matrix.nonzero()))
    ngram_freq = {ngram: count for ngram, count in ngram_counts.items()}
    return Counter(ngram_freq).most_common(top_n)

# Get top 10 frequent bigrams before preprocessing
top_bigrams_before = get_most_frequent_ngrams(pre['text'], n=2)

# Get top 10 frequent bigrams after preprocessing
top_bigrams_after = get_most_frequent_ngrams(pre['text_preprocessed'], n=2)

print(f'Top 10 frequent bigrams before preprocessing: {top_bigrams_before}')
print(f'Top 10 frequent bigrams after preprocessing: {top_bigrams_after}')
# Out:
# Top 10 frequent bigrams before preprocessing: [((0, 1377967), 1), ((0, 850080), 1), ((0, 122104), 1), ((0, 1649092), 1), ((0, 763930), 1), ((0, 1155594), 1), ((0, 1222810), 1), ((0, 943862), 1), ((0, 901199), 1), ((0, 154257), 1)]
# Top 10 frequent bigrams after preprocessing: [((0, 1377964), 1), ((0, 850077), 1), ((0, 122104), 1), ((0, 1649087), 1), ((0, 763927), 1), ((0, 1155591), 1), ((0, 1222807), 1), ((0, 943859), 1), ((0, 901196), 1), ((0, 154257), 1)]

# %%
# 4. Average Sentence Length Before and After Preprocessing

# Average sentence length before preprocessing
avg_sentence_length_before = pre['sentence_length_before'].mean()

# Average sentence length after preprocessing
avg_sentence_length_after = pre['sentence_length_after'].mean()

print(f'Average sentence length before preprocessing: {avg_sentence_length_before}')
print(f'Average sentence length after preprocessing: {avg_sentence_length_after}')
# Out:
# Average sentence length before preprocessing: 58.24067434290434
# Average sentence length after preprocessing: 56.92494777243356

# %%
# 5. Word Count Before and After Preprocessing

# Total word count before preprocessing
total_word_count_before = pre['text'].apply(lambda x: len(str(x).split())).sum()

# Total word count after preprocessing
total_word_count_after = pre['text_preprocessed'].apply(lambda x: len(str(x).split())).sum()

print(f'Total word count before preprocessing: {total_word_count_before}')
print(f'Total word count after preprocessing: {total_word_count_after}')
# Out:
# Total word count before preprocessing: 5993839
# Total word count after preprocessing: 5858431

# %%
# 6. Unique Words Before and After Preprocessing

# Unique words before preprocessing
unique_words_before = len(set(words_before))

# Unique words after preprocessing
unique_words_after = len(set(words_after))

print(f'Unique words before preprocessing: {unique_words_before}')
print(f'Unique words after preprocessing: {unique_words_after}')
# Out:
# Unique words before preprocessing: 251170
# Unique words after preprocessing: 121478

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Create a figure with two subplots
plt.figure(figsize=(12, 6))

# Subplot 1: Before Preprocessing
plt.subplot(1, 2, 1)  # (rows, columns, index)
sns.histplot(pre['sentence_length_before'], color='blue', kde=True, stat='density', linewidth=2)
plt.title('Sentence Length Distribution Before Preprocessing')
plt.xlabel('Sentence Length (words)')
plt.ylabel('Density')

# Subplot 2: After Preprocessing
plt.subplot(1, 2, 2)  # (rows, columns, index)
sns.histplot(pre['sentence_length_after'], color='red', kde=True, stat='density', linewidth=2)
plt.title('Sentence Length Distribution After Preprocessing')
plt.xlabel('Sentence Length (words)')
plt.ylabel('Density')

# Show the plot
plt.tight_layout()  # Adjust layout to prevent overlap
plt.show()
# Out:
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
# 8. Character Length of Sentences (Before and After Preprocessing)

# Calculate character length of sentences before preprocessing
pre['char_length_before'] = pre['text'].apply(lambda x: len(str(x)))

# Calculate character length of sentences after preprocessing
pre['char_length_after'] = pre['text_preprocessed'].apply(lambda x: len(str(x)))

# Max character length before and after preprocessing
max_char_length_before = pre['char_length_before'].max()
max_char_length_after = pre['char_length_after'].max()

print(f'Max character length before preprocessing: {max_char_length_before}')
print(f'Max character length after preprocessing: {max_char_length_after}')
# Out:
# Max character length before preprocessing: 513
# Max character length after preprocessing: 485

# %%
from time import time
import spacy
nlp = spacy.load('en_core_web_sm', disable=['ner', 'parser']) 

t = time()
#spacy has the pipe method to increase the speed of prepocessing
#we need it because we are removing the urls and all the stuff from nearly 100k rows
text = [str(doc) for doc in nlp.pipe(brief_cleaning1, batch_size=5000)]

print('Time to clean up everything: {} mins'.format(round((time() - t) / 60, 2)))
# Out:
# Time to clean up everything: 6.14 mins

# %%
t = time()

summary = ['SOS '+ str(doc) + ' EOS' for doc in nlp.pipe(brief_cleaning2, batch_size=5000)]
print('Time to clean up everything: {} mins'.format(round((time() - t) / 60, 2)))
# Out:
# Time to clean up everything: 1.06 mins

# %%
text[0]
# Out:
# 'saurav kant an alumnus of upgrad and iiit-b pg program in machine learning and artificial intelligence was sr systems engineer at infosys with almost years of work experience the program and upgrad 360-degree career support helped him transition to data scientist at tech mahindra with 90% salary hike upgrad online power learning has powered lakh+ careers.'

# %%
summary[0]
# Out:
# 'SOS upgrad learner switches to career in ml al with 90% salary hike EOS'

# %%
pre['cleaned_text'] = pd.Series(text)
pre['cleaned_summary'] = pd.Series(summary)

# %%
text_count = []
summary_count = []

# %%
for sent in pre['cleaned_text']:
    text_count.append(len(sent.split()))
for sent in pre['cleaned_summary']:
    summary_count.append(len(sent.split()))

# %%
graph_df= pd.DataFrame()
graph_df['text']=text_count
graph_df['summary']=summary_count

# %%
#Check how much % of summary have 0-15 words
cnt=0
for i in pre['cleaned_summary']:
    if(len(i.split())<=15):
        cnt=cnt+1
print(cnt/len(pre['cleaned_summary']))
# Out:
# 0.9978234465335472

# %%
#Check how much % of text have 0-60 words
cnt=0
for i in pre['cleaned_text']:
    if(len(i.split())<=60):
        cnt=cnt+1
print(cnt/len(pre['cleaned_text']))
# Out:
# 0.9689258125637662

# %%
max_text_len=75
max_summary_len=35

# %%
cleaned_text =np.array(pre['cleaned_text'])
cleaned_summary=np.array(pre['cleaned_summary'])

short_text=[]
short_summary=[]

for i in range(len(cleaned_text)):
    if(len(cleaned_summary[i].split())<=max_summary_len and len(cleaned_text[i].split())<=max_text_len):
        short_text.append(cleaned_text[i])
        short_summary.append(cleaned_summary[i])
        
post_pre=pd.DataFrame({'text':short_text,'summary':short_summary})

# %%
post_pre.head(2)
# Out:
#                                                 text  \
# 0  saurav kant an alumnus of upgrad and iiit-b pg...
# 1  kunal shah credit card bill payment platform c...
#
#                                              summary
# 0  SOS upgrad learner switches to career in ml al...
# 1  SOS delhi techie wins free food from swiggy fo...

# %%
post_pre['summary'] = post_pre['summary'].apply(lambda x : 'sostok '+ x + ' eostok')

# %%
from sklearn.model_selection import train_test_split
x_tr,x_val,y_tr,y_val=train_test_split(np.array(post_pre['text']),np.array(post_pre['summary']),test_size=0.1,random_state=0,shuffle=True)

# %%
from tensorflow.keras.preprocessing.text import Tokenizer 
from tensorflow.keras.preprocessing.sequence import pad_sequences

x_tokenizer = Tokenizer() 
x_tokenizer.fit_on_texts(list(x_tr))

# %%
thresh_hold=4

cnt=0
tot_cnt=0
freq=0
tot_freq=0

for key,value in x_tokenizer.word_counts.items():
    tot_cnt=tot_cnt+1
    tot_freq=tot_freq+value
    if(value<thresh_hold):
        cnt=cnt+1
        freq=freq+value
    
print("% of rare words in vocabulary:",(cnt/tot_cnt)*100)
print("Total Coverage of rare words:",(freq/tot_freq)*100)
# Out:
# % of rare words in vocabulary: 57.372738087784114
# Total Coverage of rare words: 1.2838591363115908

# %%
x_tokenizer = Tokenizer(num_words=tot_cnt-cnt) 
x_tokenizer.fit_on_texts(list(x_tr))

#convert text sequences into integer sequences (i.e one-hot encodeing all the words)
x_tr_seq    =   x_tokenizer.texts_to_sequences(x_tr) 
x_val_seq   =   x_tokenizer.texts_to_sequences(x_val)

#padding zero upto maximum length
x_tr    =   pad_sequences(x_tr_seq,  maxlen=max_text_len, padding='post')
x_val   =   pad_sequences(x_val_seq, maxlen=max_text_len, padding='post')

#size of vocabulary ( +1 for padding token)
x_voc   =  x_tokenizer.num_words + 1

print("Size of vocabulary in X = {}".format(x_voc))
# Out:
# Size of vocabulary in X = 34041

# %%
y_tokenizer = Tokenizer()   
y_tokenizer.fit_on_texts(list(y_tr))

# %%
thresh_hold=6

cnt=0
tot_cnt=0
freq=0
tot_freq=0

for key,value in y_tokenizer.word_counts.items():
    tot_cnt=tot_cnt+1
    tot_freq=tot_freq+value
    if(value<thresh_hold):
        cnt=cnt+1
        freq=freq+value
    
print("% of rare words in vocabulary:",(cnt/tot_cnt)*100)
print("Total Coverage of rare words:",(freq/tot_freq)*100)
# Out:
# % of rare words in vocabulary: 65.8062653385304
# Total Coverage of rare words: 3.4367651185493466

# %%
y_tokenizer = Tokenizer(num_words=tot_cnt-cnt) 
y_tokenizer.fit_on_texts(list(y_tr))

#convert text sequences into integer sequences (i.e one hot encode the text in Y)
y_tr_seq    =   y_tokenizer.texts_to_sequences(y_tr) 
y_val_seq   =   y_tokenizer.texts_to_sequences(y_val) 

#padding zero upto maximum length
y_tr    =   pad_sequences(y_tr_seq, maxlen=max_summary_len, padding='post')
y_val   =   pad_sequences(y_val_seq, maxlen=max_summary_len, padding='post')

#size of vocabulary
y_voc  =   y_tokenizer.num_words +1
print("Size of vocabulary in Y = {}".format(y_voc))
# Out:
# Size of vocabulary in Y = 11844

# %%
ind=[]
for i in range(len(y_tr)):
    cnt=0
    for j in y_tr[i]:
        if j!=0:
            cnt=cnt+1
    if(cnt==2):
        ind.append(i)

y_tr=np.delete(y_tr,ind, axis=0)
x_tr=np.delete(x_tr,ind, axis=0)

# %%
ind=[]
for i in range(len(y_val)):
    cnt=0
    for j in y_val[i]:
        if j!=0:
            cnt=cnt+1
    if(cnt==2):
        ind.append(i)

y_val=np.delete(y_val,ind, axis=0)
x_val=np.delete(x_val,ind, axis=0)

# %%
from keras import backend as K 
import gensim
from numpy import *
import numpy as np
import pandas as pd 
import re
from bs4 import BeautifulSoup
from tensorflow.keras.preprocessing.text import Tokenizer 
from tensorflow.keras.preprocessing.sequence import pad_sequences
from nltk.corpus import stopwords
from tensorflow.keras.layers import Input, LSTM, Embedding, Dense, Concatenate, TimeDistributed
from tensorflow.keras.models import Model
from tensorflow.keras.callbacks import EarlyStopping
import warnings
pd.set_option("display.max_colwidth", 200)
warnings.filterwarnings("ignore")

print("Size of vocabulary from the w2v model = {}".format(x_voc))

K.clear_session()

latent_dim = 300
embedding_dim=200

# Encoder
encoder_inputs = Input(shape=(max_text_len,))

#embedding layer
enc_emb =  Embedding(x_voc, embedding_dim,trainable=True)(encoder_inputs)

#encoder lstm 1
encoder_lstm1 = LSTM(latent_dim,return_sequences=True,return_state=True,dropout=0.4,recurrent_dropout=0.4)
encoder_output1, state_h1, state_c1 = encoder_lstm1(enc_emb)

#encoder lstm 2
encoder_lstm2 = LSTM(latent_dim,return_sequences=True,return_state=True,dropout=0.4,recurrent_dropout=0.4)
encoder_output2, state_h2, state_c2 = encoder_lstm2(encoder_output1)

#encoder lstm 3
encoder_lstm3=LSTM(latent_dim, return_state=True, return_sequences=True,dropout=0.4,recurrent_dropout=0.4)
encoder_outputs, state_h, state_c= encoder_lstm3(encoder_output2)

# Set up the decoder, using `encoder_states` as initial state.
decoder_inputs = Input(shape=(None,))

#embedding layer
dec_emb_layer = Embedding(y_voc, embedding_dim,trainable=True)
dec_emb = dec_emb_layer(decoder_inputs)

decoder_lstm = LSTM(latent_dim, return_sequences=True, return_state=True,dropout=0.4,recurrent_dropout=0.2)
decoder_outputs,decoder_fwd_state, decoder_back_state = decoder_lstm(dec_emb,initial_state=[state_h, state_c])

#dense layer
decoder_dense =  TimeDistributed(Dense(y_voc, activation='softmax'))
decoder_outputs = decoder_dense(decoder_outputs)

# Define the model 
model = Model([encoder_inputs, decoder_inputs], decoder_outputs)

model.summary()
# Out:
# Size of vocabulary from the w2v model = 34041
# Model: "functional_1"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer         │ (None, 75)        │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ embedding           │ (None, 75, 200)   │  6,808,200 │ input_layer[0][0] │
# │ (Embedding)         │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ lstm (LSTM)         │ [(None, 75, 300), │    601,200 │ embedding[0][0]   │
# │                     │ (None, 300),      │            │                   │
# │                     │ (None, 300)]      │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ input_layer_1       │ (None, None)      │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ lstm_1 (LSTM)       │ [(None, 75, 300), │    721,200 │ lstm[0][0]        │
# │                     │ (None, 300),      │            │                   │
# │                     │ (None, 300)]      │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ embedding_1         │ (None, None, 200) │  2,368,800 │ input_layer_1[0]… │
# │ (Embedding)         │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ lstm_2 (LSTM)       │ [(None, 75, 300), │    721,200 │ lstm_1[0][0]      │
# │                     │ (None, 300),      │            │                   │
# │                     │ (None, 300)]      │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ lstm_3 (LSTM)       │ [(None, None,     │    601,200 │ embedding_1[0][0… │
# │                     │ 300), (None,      │            │ lstm_2[0][1],     │
# │                     │ 300), (None,      │            │ lstm_2[0][2]      │
# │                     │ 300)]             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ time_distributed    │ (None, None,      │  3,565,044 │ lstm_3[0][0]      │
# │ (TimeDistributed)   │ 11844)            │            │                   │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 15,386,844 (58.70 MB)
#  Trainable params: 15,386,844 (58.70 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
model.compile(optimizer='rmsprop', loss='sparse_categorical_crossentropy',metrics=['accuracy'])
es = EarlyStopping(monitor='val_loss', mode='min', verbose=1,patience=2)

# %%
history=model.fit([x_tr,y_tr[:,:-1]], y_tr.reshape(y_tr.shape[0],y_tr.shape[1], 1)[:,1:] ,epochs=60,callbacks=[es],batch_size=128, validation_data=([x_val,y_val[:,:-1]], y_val.reshape(y_val.shape[0],y_val.shape[1], 1)[:,1:]))
# Out:
# Epoch 1/50
# 724/724 ━━━━━━━━━━━━━━━━━━━━ 306s 408ms/step - accuracy: 0.6984 - loss: 2.7055 - val_accuracy: 0.7379 - val_loss: 2.1073
# Epoch 2/50
# 724/724 ━━━━━━━━━━━━━━━━━━━━ 295s 408ms/step - accuracy: 0.7366 - loss: 2.1172 - val_accuracy: 0.7382 - val_loss: 2.0839
# Epoch 3/50
# 724/724 ━━━━━━━━━━━━━━━━━━━━ 296s 408ms/step - accuracy: 0.7374 - loss: 2.0884 - val_accuracy: 0.7385 - val_loss: 2.0609
# Epoch 4/50
# 724/724 ━━━━━━━━━━━━━━━━━━━━ 296s 409ms/step - accuracy: 0.7375 - loss: 2.0657 - val_accuracy: 0.7391 - val_loss: 2.0443
# Epoch 5/50
# 724/724 ━━━━━━━━━━━━━━━━━━━━ 295s 408ms/step - accuracy: 0.7379 - loss: 2.0500 - val_accuracy: 0.7395 - val_loss: 2.0336
# Epoch 6/50
# 724/724 ━━━━━━━━━━━━━━━━━━━━ 295s 407ms/step - accuracy: 0.7387 - loss: 2.0353 - val_accuracy: 0.7399 - val_loss: 2.0212
# Epoch 7/50
# 724/724 ━━━━━━━━━━━━━━━━━━━━ 295s 408ms/step - accuracy: 0.7392 - loss: 2.0250 - val_accuracy: 0.7401 - val_loss: 2.0133
# Epoch 8/50
# 724/724 ━━━━━━━━━━━━━━━━━━━━ 295s 408ms/step - accuracy: 0.7397 - loss: 2.0156 - val_accuracy: 0.7407 - val_loss: 2.0040
# Epoch 9/50
# 724/724 ━━━━━━━━━━━━━━━━━━━━ 295s 408ms/step - accuracy: 0.7406 - loss: 2.0036 - val_accuracy: 0.7413 - val_loss: 1.9951
# Epoch 10/50
# 724/724 ━━━━━━━━━━━━━━━━━━━━ 295s 407ms/step - accuracy: 0.7412 - loss: 1.9921 - val_accuracy: 0.7426 - val_loss: 1.9832
# Epoch 11/50
# 724/724 ━━━━━━━━━━━━━━━━━━━━ 295s 408ms/step - accuracy: 0.7420 - loss: 1.9809 - val_accuracy: 0.7435 - val_loss: 1.9739
# Epoch 12/50
# 724/724 ━━━━━━━━━━━━━━━━━━━━ 295s 408ms/step - accuracy: 0.7425 - loss: 1.9703 - val_accuracy: 0.7441 - val_loss: 1.9604
# Epoch 13/50
# 724/724 ━━━━━━━━━━━━━━━━━━━━ 296s 409ms/step - accuracy: 0.7431 - loss: 1.9577 - val_accuracy: 0.7447 - val_loss: 1.9494
# Epoch 14/50
# 724/724 ━━━━━━━━━━━━━━━━━━━━ 297s 410ms/step - accuracy: 0.7442 - loss: 1.9428 - val_accuracy: 0.7454 - val_loss: 1.9385
# Epoch 15/50
# 724/724 ━━━━━━━━━━━━━━━━━━━━ 295s 407ms/step - accuracy: 0.7448 - loss: 1.9297 - val_accuracy: 0.7458 - val_loss: 1.9305
# Epoch 16/50
# 724/724 ━━━━━━━━━━━━━━━━━━━━ 295s 407ms/step - accuracy: 0.7458 - loss: 1.9164 - val_accuracy: 0.7468 - val_loss: 1.9070
# Epoch 17/50
# 724/724 ━━━━━━━━━━━━━━━━━━━━ 295s 407ms/step - accuracy: 0.7467 - loss: 1.8965 - val_accuracy: 0.7488 - val_loss: 1.8865
# Epoch 18/50
# 724/724 ━━━━━━━━━━━━━━━━━━━━ 295s 407ms/step - accuracy: 0.7480 - loss: 1.8739 - val_accuracy: 0.7496 - val_loss: 1.8685
# Epoch 19/50
# 724/724 ━━━━━━━━━━━━━━━━━━━━ 295s 407ms/step - accuracy: 0.7489 - loss: 1.8562 - val_accuracy: 0.7504 - val_loss: 1.8507
# Epoch 20/50
# 724/724 ━━━━━━━━━━━━━━━━━━━━ 295s 408ms/step - accuracy: 0.7500 - loss: 1.8368 - val_accuracy: 0.7509 - val_loss: 1.8418
# Epoch 21/50
# 724/724 ━━━━━━━━━━━━━━━━━━━━ 296s 408ms/step - accuracy: 0.7506 - loss: 1.8210 - val_accuracy: 0.7520 - val_loss: 1.8208
# Epoch 22/50
# 724/724 ━━━━━━━━━━━━━━━━━━━━ 296s 409ms/step - accuracy: 0.7515 - loss: 1.8031 - val_accuracy: 0.7529 - val_loss: 1.8063
# Epoch 23/50
# 724/724 ━━━━━━━━━━━━━━━━━━━━ 296s 408ms/step - accuracy: 0.7522 - loss: 1.7877 - val_accuracy: 0.7535 - val_loss: 1.7910
# Epoch 24/50
# 724/724 ━━━━━━━━━━━━━━━━━━━━ 295s 408ms/step - accuracy: 0.7531 - loss: 1.7684 - val_accuracy: 0.7542 - val_loss: 1.7772
# Epoch 25/50
# 724/724 ━━━━━━━━━━━━━━━━━━━━ 296s 408ms/step - accuracy: 0.7538 - loss: 1.7533 - val_accuracy: 0.7551 - val_loss: 1.7587
# Epoch 26/50
# 724/724 ━━━━━━━━━━━━━━━━━━━━ 295s 408ms/step - accuracy: 0.7548 - loss: 1.7361 - val_accuracy: 0.7560 - val_loss: 1.7461
# Epoch 27/50
# 724/724 ━━━━━━━━━━━━━━━━━━━━ 295s 407ms/step - accuracy: 0.7561 - loss: 1.7186 - val_accuracy: 0.7574 - val_loss: 1.7269
# Epoch 28/50
# 724/724 ━━━━━━━━━━━━━━━━━━━━ 295s 407ms/step - accuracy: 0.7568 - loss: 1.7025 - val_accuracy: 0.7581 - val_loss: 1.7147
# Epoch 29/50
# 724/724 ━━━━━━━━━━━━━━━━━━━━ 295s 407ms/step - accuracy: 0.7579 - loss: 1.6857 - val_accuracy: 0.7589 - val_loss: 1.6995
# Epoch 30/50
# 724/724 ━━━━━━━━━━━━━━━━━━━━ 296s 408ms/step - accuracy: 0.7585 - loss: 1.6697 - val_accuracy: 0.7592 - val_loss: 1.6877
# Epoch 31/50
# 724/724 ━━━━━━━━━━━━━━━━━━━━ 296s 409ms/step - accuracy: 0.7595 - loss: 1.6543 - val_accuracy: 0.7602 - val_loss: 1.6749
# Epoch 32/50
# 724/724 ━━━━━━━━━━━━━━━━━━━━ 295s 408ms/step - accuracy: 0.7605 - loss: 1.6385 - val_accuracy: 0.7607 - val_loss: 1.6651
# Epoch 33/50
# 724/724 ━━━━━━━━━━━━━━━━━━━━ 296s 408ms/step - accuracy: 0.7608 - loss: 1.6267 - val_accuracy: 0.7614 - val_loss: 1.6519
# Epoch 34/50
# 724/724 ━━━━━━━━━━━━━━━━━━━━ 295s 407ms/step - accuracy: 0.7616 - loss: 1.6133 - val_accuracy: 0.7620 - val_loss: 1.6432
# Epoch 35/50
# 724/724 ━━━━━━━━━━━━━━━━━━━━ 295s 408ms/step - accuracy: 0.7625 - loss: 1.6004 - val_accuracy: 0.7627 - val_loss: 1.6346
# Epoch 36/50
# 724/724 ━━━━━━━━━━━━━━━━━━━━ 296s 408ms/step - accuracy: 0.7631 - loss: 1.5897 - val_accuracy: 0.7628 - val_loss: 1.6263
# Epoch 37/50
# 724/724 ━━━━━━━━━━━━━━━━━━━━ 297s 410ms/step - accuracy: 0.7636 - loss: 1.5813 - val_accuracy: 0.7634 - val_loss: 1.6184
# Epoch 38/50
# 724/724 ━━━━━━━━━━━━━━━━━━━━ 295s 408ms/step - accuracy: 0.7644 - loss: 1.5686 - val_accuracy: 0.7645 - val_loss: 1.6079
# Epoch 39/50
# 724/724 ━━━━━━━━━━━━━━━━━━━━ 296s 409ms/step - accuracy: 0.7647 - loss: 1.5590 - val_accuracy: 0.7646 - val_loss: 1.6010
# Epoch 40/50
# 724/724 ━━━━━━━━━━━━━━━━━━━━ 296s 409ms/step - accuracy: 0.7654 - loss: 1.5489 - val_accuracy: 0.7650 - val_loss: 1.5925
# Epoch 41/50
# 724/724 ━━━━━━━━━━━━━━━━━━━━ 296s 409ms/step - accuracy: 0.7661 - loss: 1.5389 - val_accuracy: 0.7657 - val_loss: 1.5842
# Epoch 42/50
# 724/724 ━━━━━━━━━━━━━━━━━━━━ 296s 409ms/step - accuracy: 0.7670 - loss: 1.5282 - val_accuracy: 0.7665 - val_loss: 1.5766
# Epoch 43/50
# 724/724 ━━━━━━━━━━━━━━━━━━━━ 295s 408ms/step - accuracy: 0.7677 - loss: 1.5192 - val_accuracy: 0.7670 - val_loss: 1.5703
# Epoch 44/50
# 724/724 ━━━━━━━━━━━━━━━━━━━━ 297s 410ms/step - accuracy: 0.7681 - loss: 1.5108 - val_accuracy: 0.7673 - val_loss: 1.5634
# Epoch 45/50
# 724/724 ━━━━━━━━━━━━━━━━━━━━ 297s 410ms/step - accuracy: 0.7685 - loss: 1.5000 - val_accuracy: 0.7680 - val_loss: 1.5547
# Epoch 46/50
# 724/724 ━━━━━━━━━━━━━━━━━━━━ 296s 409ms/step - accuracy: 0.7691 - loss: 1.4929 - val_accuracy: 0.7684 - val_loss: 1.5482
# Epoch 47/50
# 724/724 ━━━━━━━━━━━━━━━━━━━━ 296s 409ms/step - accuracy: 0.7699 - loss: 1.4822 - val_accuracy: 0.7684 - val_loss: 1.5433
# Epoch 48/50
# 724/724 ━━━━━━━━━━━━━━━━━━━━ 296s 409ms/step - accuracy: 0.7706 - loss: 1.4728 - val_accuracy: 0.7696 - val_loss: 1.5341
# Epoch 49/50
# 724/724 ━━━━━━━━━━━━━━━━━━━━ 296s 408ms/step - accuracy: 0.7710 - loss: 1.4651 - val_accuracy: 0.7698 - val_loss: 1.5300
# Epoch 50/50
# 724/724 ━━━━━━━━━━━━━━━━━━━━ 296s 409ms/step - accuracy: 0.7717 - loss: 1.4572 - val_accuracy: 0.7700 - val_loss: 1.5238

# %%
from matplotlib import pyplot
pyplot.plot(history.history['loss'], label='train')
pyplot.plot(history.history['val_loss'], label='test')
pyplot.legend()
pyplot.show()

# %%
from matplotlib import pyplot
pyplot.plot(history.history['accuracy'], label='train')
pyplot.plot(history.history['val_accuracy'], label='test')
pyplot.legend()
pyplot.show()

# %%
import pickle
from tensorflow.keras.models import save_model

# Save the model
model.save("ns_model_60.h5") 
model.save("ns_model_60.keras") 

# Save the history object
with open("history_60.pkl", 'wb') as f:
    pickle.dump(history.history, f)  # Save the training history

# %%
reverse_target_word_index=y_tokenizer.index_word
reverse_source_word_index=x_tokenizer.index_word
target_word_index=y_tokenizer.word_index

# %%
encoder_model = Model(inputs=encoder_inputs,outputs=[encoder_outputs, state_h, state_c])

# Decoder setup
# Below tensors will hold the states of the previous time step
decoder_state_input_h = Input(shape=(latent_dim,))
decoder_state_input_c = Input(shape=(latent_dim,))
decoder_hidden_state_input = Input(shape=(max_text_len,latent_dim))

# Get the embeddings of the decoder sequence
dec_emb2= dec_emb_layer(decoder_inputs) 
# To predict the next word in the sequence, set the initial states to the states from the previous time step
decoder_outputs2, state_h2, state_c2 = decoder_lstm(dec_emb2, initial_state=[decoder_state_input_h, decoder_state_input_c])

# A dense softmax layer to generate prob dist. over the target vocabulary
decoder_outputs2 = decoder_dense(decoder_outputs2) 

# Final decoder model
decoder_model = Model(
    [decoder_inputs] + [decoder_hidden_state_input,decoder_state_input_h, decoder_state_input_c],
    [decoder_outputs2] + [state_h2, state_c2])

# %%
max_text_len
# Out:
# 75

# %%
def decode_sequence(input_seq):
    # Encode the input as state vectors.
    e_out, e_h, e_c = encoder_model.predict(input_seq)
    
    # Generate empty target sequence of length 1.
    target_seq = np.zeros((1,1))
    
    # Populate the first word of target sequence with the start word.
    target_seq[0, 0] = target_word_index['sostok']

    stop_condition = False
    decoded_sentence = ''
    while not stop_condition:
      
        output_tokens, h, c = decoder_model.predict([target_seq] + [e_out, e_h, e_c])

        # Sample a token
        sampled_token_index = np.argmax(output_tokens[0, -1, :])
        sampled_token = reverse_target_word_index[sampled_token_index]
        
        if(sampled_token!='eostok'):
            decoded_sentence += ' '+sampled_token

        # Exit condition: either hit max length or find stop word.
        if (sampled_token == 'eostok'  or len(decoded_sentence.split()) >= (max_summary_len-1)):
            stop_condition = True

        # Update the target sequence (of length 1).
        target_seq = np.zeros((1,1))
        target_seq[0, 0] = sampled_token_index

        # Update internal states
        e_h, e_c = h, c

    return decoded_sentence

# %%
def seq2summary(input_seq):
    newString=''
    for i in input_seq:
        if((i!=0 and i!=target_word_index['sostok']) and i!=target_word_index['eostok']):
            newString=newString+reverse_target_word_index[i]+' '
    return newString

def seq2text(input_seq):
    newString=''
    for i in input_seq:
        if(i!=0):
            newString=newString+reverse_source_word_index[i]+' '
    return newString

# %%
# print("Review:",seq2text(x_tr[3]))
# print("Original summary:",seq2summary(y_tr[3]))
# print("Predicted summary:",decode_sequence(x_tr[3].reshape(1,max_text_len)))
# print("\n")

# %%
decode_sequence(x_tr[2].reshape(1,max_text_len))
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 508ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 200ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# ' sos rohit sharma to play ipl in australia in ipl 2018 eos'

# %%
for i in range(0,100):
    print("Review:",seq2text(x_tr[i]))
    print("Original summary:",seq2summary(y_tr[i]))
    print("Predicted summary:",decode_sequence(x_tr[i].reshape(1,max_text_len)))
    print("\n")
# Out:
# Review: hailing the supreme court verdict on right to privacy union minister ravi shankar prasad said that it is not an absolute right and added if want to give speech naked wonã¢âât be allowed like other fundamental rights privacy is also subject to reasonable restrictions he said however prasad refused to comment on the legal challenge to aadhaar
# Original summary: sos if want to give speech naked wonã¢âât be allowed prasad eos
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Predicted summary:  sos can be ready to change sc judge on sc st act eos
#
#
# Review: actress bipasha basu and husband karan singh grover left singer justin bieber mumbai concert on wednesday within five minutes of arriving as it was too crowded we didn get security with us and it is too crowded so we are leaving said bipasha meanwhile celebrities including alia bhatt sridevi arbaaz khan malaika arora and kriti sanon attended the concert
# Original summary: sos bipasha karan left bieber concert within min due to crowd eos
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Predicted summary:  sos priyanka chopra to be paid for 1st time in yrs eos
#
#
# Review: shikhar dhawan became the first indian to get out in nineties in t20i cricket after getting dismissed for 90 49 against sri lanka on tuesday dhawan whose previous highest t20i score was 80 slammed six fours and six sixes during his knock vinoo mankad and kris srikkanth were the first indians to get out in 90s in tests and odis respectively
# Original summary: sos dhawan first indian batsman to get out in 90s in t20i eos
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# Predicted summary:  sos rohit sharma to play ipl in australia in ipl 2018 eos
#
#
# Review: prime minister narendra modi on tuesday tweeted birthday wishes to former prime minister dr manmohan singh pm modi wished long life filled with good health to singh who has turned 85 years old singh who started his political career in 1991 as the finance minister helped in liberalisation and privatisation to the indian economy
# Original summary: sos modi wishes manmohan singh on his birthday eos
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Predicted summary:  sos pm modi is the pm modi on pm modi eos
#
#
# Review: female employees of the central government who choose to have child through surrogacy will be entitled to maternity leave of 26 weeks government notification said the directive is based on 2015 delhi high court verdict in case wherein government employed teacher was denied maternity leave on grounds that she was not the biological mother
# Original summary: sos govt staff having child via surrogacy to get maternity leave eos
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Predicted summary:  sos court orders to pay for not wearing sex abuse eos
#
#
# Review: experiments show that clear ice shaped in the form of disk can be used to create fire after are removed from an ice slab it can be melted and by using the heat of hands when the piece is held to the sun the concentration of sunlight on particular spot results in creation of fire
# Original summary: sos fire can be created using ice eos
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# Predicted summary:  sos new york to get its first ever eos
#
#
# Review: karan johar has said that there is tremendous potential in regional cinema he further said cinema is growing by leaps and taking big we keep dividing it calling it regional cinema we should just call it indian cinema and be proud of it johar added that he wants to showcase the talent and do much more in regional cinema
# Original summary: sos there tremendous potential in regional cinema karan johar eos
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# Predicted summary:  sos i have been the most powerful actor eos
#
#
# Review: the makers of vijay starrer mersal have muted the dialogues mocking gst and digital india from its telugu version this comes after the bharatiya janata party tamil nadu unit objected to the references in the film bjp leader raja state president tamilisai and union minister pon radhakrishnan had earlier demanded that the references should be deleted
# Original summary: sos makers of mersal mute dialogues on gst in telugu version eos
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Predicted summary:  sos gst is the most powerful president eos
#
#
# Review: a jet airways air hostess was arrested with 480 200 around ã¢ââ¹3 crore onboard delhi hong kong flight on monday officials said the initial investigation suggested she was part of an elaborate scheme to bring gold into india in exchange for black money meanwhile jet airways released statement saying it would take further action against the employee following the investigation
# Original summary: sos jet airways air hostess arrested with ã¢ââ¹3 crore in us eos
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Predicted summary:  sos air india flight gets air air air air force flight eos
#
#
# Review: new pictures of actor hrithik roshan from the sets of his upcoming film super 30 have surfaced online the pictures are reportedly from the streets of jaipur the actor will be seen portraying mathematician anand kumar who is credited with starting an educational initiative to prepare thirty meritorious but financially challenged students for the iit examination
# Original summary: sos new pics of hrithik from sets of super 30 surface online eos
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# Predicted summary:  sos new poster of thrones released eos
#
#
# Review: nearly 60 000 children in north korea face potential starvation due to international sanctions against the regime the unicef has said although providing humanitarian assistance is exempted from the sanctions the absence of adequate shipping routes delays the delivery of aid global sanctions have been imposed against north korea over its ballistic and nuclear missile programme
# Original summary: sos 60 000 north korean kids may due to sanctions unicef eos
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# Predicted summary:  sos us sanctions against korea over korea eos
#
#
# Review: paris mayor anne has called for ban on black feminist festival saying it is prohibited to white people the festival has reserved 80 of its area only for black women while the rest is divided into an area open to black men and women and an area open to all anti racist groups have condemned the festival
# Original summary: sos paris mayor demands ban on black event eos
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# Predicted summary:  sos uk university bans women from its name eos
#
#
# Review: chinese electric vehicle maker market value soared to almost 12 billion after its shares closed up 76 on their second day of trading the shanghai based company which billed itself as an emerging tesla rival raised 1 billion in us offering sells only in china although its technology and design teams are based in the us uk and germany
# Original summary: sos tesla rival valued at 12 billion in two days of trading eos
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Predicted summary:  sos china to buy its own own cryptocurrency eos
#
#
# Review: human rights watch hrw has accused the un security council of failing to investigate war crimes and rights abuses by anti isis forces in iraq calling un approach as flawed and selective the organisation said it misses the opportunity to investigate crimes committed by all parties of the conflict hrw added that the un deliberately chose not to investigate the abuses
# Original summary: sos un failed to investigate crimes in iraq human rights watch eos
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# Predicted summary:  sos us to give action against us over rohingya violence eos
#
#
# Review: a 23 year old man has been arrested for sending obscene messages to television actress sonarika bhadoria she revealed that the man used 25 different numbers to contact her and had been calling her since eight months sonarika is known for her portrayal of goddess parvati and adi shakti in the television serial devon ke dev mahadev
# Original summary: sos man arrested for sending obscene messages to tv actress eos
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Predicted summary:  sos man arrested for posting video of his son in up eos
#
#
# Review: former pakistan pm nawaz sharif son hussain has alleged that his father was deprived of bed in jail and that the bathroom there was extremely dirty sharif was arrested along with his daughter maryam on their return to lahore from london on friday earlier reports stated that the father daughter duo will get facilities like ac and tv in jail
# Original summary: sos no bed dirty washroom for nawaz sharif in jail alleges son eos
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# Predicted summary:  sos pak pm wife wife to be shot by his wife eos
#
#
# Review: the external affairs ministry has announced that the last page of passports which carries the holder address will no longer be printed making the document an invalid address proof this comes after committee recommended that the father name which is also on the last page be omitted however no timeline has been announced for the implementation of the change
# Original summary: sos new indian passports cannot be used as an address proof eos
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Predicted summary:  sos india to be part of india in india eos
#
#
# Review: the us navy destroyer which recently collided with philippine flagged container ship in japan failed to respond to warning signals or take evasive action before the collision according to the philippine ship captain the accident claimed the lives of seven us navy sailors in the greatest loss of life on us navy vessel since 2000 nn
# Original summary: sos us destroyer which with ship didn act to warnings eos
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# Predicted summary:  sos us navy to death after being hit by isis eos
#
#
# Review: police have arrested five people including prominent lawyer surendra and delhi man rana jacob in connection with the bhima koregaon riots in maharashtra in january police also searched the house of nagpur university professor with alleged maoist links the violence had been triggered during gathering by dalits for the 200th anniversary celebrations of the bhima koregaon battle
# Original summary: sos lawyer activists among arrested over bhima koregaon riots eos
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Predicted summary:  sos police arrests ex cop for refusing to kill him eos
#
#
# Review: south africa registered 6 wicket victory in the second t20i at centurion on wednesday to end india winning streak of five t20i matches and level the three match series 1 1 india had last lost t20i match on november 2017 against new zealand at rajkot the series decider will take place at cape town on saturday
# Original summary: sos sa end india 5 match winning streak level series 1 1 eos
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# Predicted summary:  sos australia beat sl to win their first odi series in t20i eos
#
#
# Review: users have reported that bug affecting samsung galaxy and galaxy note sent users pictures to their contacts without their permission they claimed that the issue affected samsung messages following mobile network t mobile update for advanced messaging between carriers samsung spokesperson said it is aware of the issue and is looking into the matter
# Original summary: sos bug makes samsung phones send photos to random contacts eos
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Predicted summary:  sos google launches feature to let users eos
#
#
# Review: around 27 children in india are married before the age of 18 years as compared to the global average of 28 according to united nations fund for population activities report the report also states india maternal mortality rate mmr that is mothers dying per 00 000 live births is 174 against the world average of 216
# Original summary: sos 27 children in india are married before they turn 18 un eos
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Predicted summary:  sos indian origin women to be auctioned for years eos
#
#
# Review: a uk court has cleared extradition of 50 year old bookie sanjeev chawla key accused in the 2000 match fixing scandal involving late south africa captain hansie cronje to india the accused had moved to the uk in 1996 and obtained british passport in 2005 this comes after the uk high court accepted assurances given by india regarding tihar jail condition
# Original summary: sos uk court clears extradition of accused in 2000 match fixing scandal eos
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# Predicted summary:  sos pak court dismisses plea against pak over his tweet eos
#
#
# Review: actor abhay deol has revealed that only one actress called to support him after he slammed bollywood actors including shah rukh khan deepika padukone and sonam kapoor for endorsing fairness creams received lot of support from people and media from corporates and filmmakers no why would they am calling them out for their practices he added
# Original summary: sos only actress supported me abhay on fairness cream post eos
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# Predicted summary:  sos i am not my life with me saif on ranbir kapoor eos
#
#
# Review: the 14th dalai lama said that historically the indians and tibetans have had long enduring relationship as teachers gurus and disciples chelas we are not only chelas but quite reliable chelas he added the dalai lama who was on nine day visit to arunachal pradesh has traveled to the indian state on six earlier occasions since 1983
# Original summary: sos india is the guru tibetans are dalai lama eos
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Predicted summary:  sos india to be part of india china eos
#
#
# Review: bengaluru based vernacular social networking app sharechat has banned 50 000 profiles with problematic content like pornography violence and fake news it asked users to report profiles with problematic content reviewed the complaints and then took appropriate action by iit kanpur alumni sharechat lets users post content in 14 local languages including telugu bhojpuri and odia n
# Original summary: sos bans 50 000 profiles to tackle porn fake news eos
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# Predicted summary:  sos iit group makes users to let users eos
#
#
# Review: the panchayat in bihar village asked man to pay compensation of ã¢ââ¹20 000 to girl whom he kissed twice on the cheek without her consent when she was returning home however the girl refused to take compensation and said he the accused has earned me much disrepute in the society and he will have to marry me
# Original summary: sos panchayat fines man for kissing girl she wants to marry him eos
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Predicted summary:  sos man arrested for raping woman in up for months eos
#
#
# Review: china has opposed pm narendra modi visit to arunachal pradesh which it claims as part of south tibet adding that it has never recognised the so called arunachal pradesh china said that it would lodge diplomatic protest with india over the visit this was pm modi first visit to the indian state since the india china doklam standoff last year nn
# Original summary: sos china opposes pm narendra modi visit to arunachal pradesh eos
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Predicted summary:  sos china to visit india to visit india eos
#
#
# Review: the border security force bsf on monday seized pakistani boat loaded with 400 kg fish near sutlej river in punjab border area and an investigation has been launched into the matter last month the pakistan navy apprehended 88 indian fishermen and 15 boats off the gujarat coast in the arabian sea for allegedly straying into its territorial waters
# Original summary: sos bsf seizes pak boat from river in punjab eos
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# Predicted summary:  sos army kills 11 civilians in air strike over air india eos
#
#
# Review: deepika padukone broke down on the sets of 2013 film goliyon ki rasleela ram leela because of some last minute changes in the dialogues revealed the film writer she deepika usually very good with her lines but the change meant completely upsetting her pattern said co writer garima the writers later worked on the lines till deepika was comfortable with them
# Original summary: sos deepika broke down on ram leela sets due to dialogue change eos
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Predicted summary:  sos deepika ranveer to star in film reports eos
#
#
# Review: attorney general kk venugopal on saturday said unity among supreme court judges will be restored by monday this comes after four senior most sc judges held press conference voicing concerns over cji dipak misra and the administration of the judiciary ag venugopal further said he hoped that the judges will not let the issue escalate
# Original summary: sos unity in sc judges will return by monday attorney general eos
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# Predicted summary:  sos sc to hear plea against cji to hear plea eos
#
#
# Review: singer varsha singh alleged that singer kailash kher who she used to consider her guru once sent her message that read want to make love to you she also accused music composer of sexual misconduct when under the influence of alcohol he put his hand on her thigh has denied the allegations
# Original summary: sos kailash kher saying want to make love to you singer eos
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Predicted summary:  sos i am not to be called me as actress eos
#
#
# Review: the screening of the film the accidental prime minister was cancelled at kolkata hind cinema due to security concerns amid protests by youth congress activists close to 100 activists protested in front of the theatre west bengal youth congress president shadab khan said the show was reportedly halted after the first ten minutes of the film were screened
# Original summary: sos the accidental halted in kolkata theatre amid protests eos
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# Predicted summary:  sos bjp leader who killed in encounter in up eos
#
#
# Review: org parody of us president donald trump owned hotels website com displays photos of immigrants in temporary detention centres the website which mocks trump zero tolerance immigration policy also features his quotes supporting the same the domain name records reportedly show that the org domain was registered last week through proxy service
# Original summary: sos parody site of com shows images of immigrants eos
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Predicted summary:  sos trump asks president to visit us prez eos
#
#
# Review: ken 97 year old war veteran who survived the battle of dunkirk during world war ii attended the premiere of christopher nolan film dunkirk in calgary canada was 20 when that happened but watching the movie could see my old friends again and lot of them died later in the war said ken
# Original summary: sos war veteran who survived wwii attends premiere eos
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# Predicted summary:  sos i was the world cup after being called eos
#
#
# Review: english singer songwriter ed sheeran who performed in mumbai on sunday at his second concert ever in india has said that bollywood is bright and colourful and film with actor shah rukh khan would be quite cool sheeran added had to come back to india last time when performed here loved it people are so welcoming here
# Original summary: sos a film with shah rukh khan would be quite cool ed sheeran eos
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# Predicted summary:  sos i am the most expensive actress on being demise eos
#
#
# Review: posing as policemen two men allegedly raped 20 year old woman and molested her minor niece in outer delhi on sunday night the accused had approached the woman and her niece claiming they were policemen the police said the victims statements were recorded and case was registered but the men are yet to be identified
# Original summary: sos posing as policemen two men sexually assault woman niece eos
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# Predicted summary:  sos delhi man held for raping woman in delhi eos
#
#
# Review: mukesh ambani led reliance industries is reportedly in talks to acquire mumbai based cable and broadband service provider hathway cable and the talks are aimed at using the company platform to speed up the commercial launch of its jio home broadband services the deal is expected to value hathway at around ã¢ââ¹2 500 crore
# Original summary: sos reliance in talks to buy broadband firm report eos
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# Predicted summary:  sos flipkart to invest in india in india eos
#
#
# Review: hrd ministry secretary anil swarup has revealed that while the cbse received an email regarding class 10 maths paper leak nine hours before the exam the board didn have enough time to cancel it stating that the email was seen by cbse chairperson anita karwal at around am swarup said the leak was confirmed after the exam had commenced
# Original summary: sos had no time to cancel class 10 maths exam hrd ministry eos
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# Predicted summary:  sos hc to hear plea to jail for women to be mahal eos
#
#
# Review: instagram only had 13 employees when it was bought by facebook for 1 billion in combined cash and stock deal on april 2012 instagram had closed 50 million round at valuation of 500 million right before the sale founded in 2010 by mike krieger and kevin systrom the app had zero revenue at the time of acquisition
# Original summary: sos instagram only had 13 employees when fb bought it for 1 bn eos
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# Predicted summary:  sos facebook to pay crore in us for its first time eos
#
#
# Review: stating that no restrictions have been imposed on performing aarti and other rituals in amarnath cave shrine the national green tribunal on thursday clarified that the silent zone restrictions will be imposed only around the this comes after reports claimed that the tribunal had directed the amarnath shrine board to restrict chanting of mantras or in amarnath temple
# Original summary: sos no restrictions on aarti in amarnath shrine clarifies ngt eos
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# Predicted summary:  sos india to be allowed to be held for 1st time in yrs eos
#
#
# Review: russian foreign minister sergey lavrov has said that south korea decision to deploy the thaad anti missile system from the us is disproportionate to the threat posed by north korea the us global ballistic missile defence poses deep risk to the security of the asia pacific region lavrov added the us started deploying thaad in south korea despite opposition from russia
# Original summary: sos thaad deployment disproportionate to korean threat russia eos
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# Predicted summary:  sos us sanctions against us over us sanctions against us eos
#
#
# Review: virgin group founder richard branson on friday said he had feeling united states president donald trump was the bizarre mistake of pulling america out of the paris climate deal terming trump withdrawal very very strange branson pointed to his head and said who knows what goes in there he added hopefully there is positive change of mind
# Original summary: sos trump regrets bizarre paris climate richard branson eos
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Predicted summary:  sos trump calls us for most powerful president eos
#
#
# Review: twitter users from across the world trolled an irani man for posting picture of biryani with ketchup and mayonnaise and terming it as the best way to eat the dish the man tweeted to pass him to india while indians posted on twitter to pass him to arabs and they tweeted to hand him over to pakistan
# Original summary: sos twitter trolls man for eating biryani with and eos
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Predicted summary:  sos twitter shares video of his daughter eos
#
#
# Review: former ac milan and real madrid midfielder kaka who lifted the 2002 world cup with brazil announced his retirement from football on sunday kaka who won the champions league and the ballon or award in 2007 while playing for ac milan had become the most expensive footballer in history after his then world record million transfer from milan to madrid
# Original summary: sos 2002 world cup winner retires from football eos
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Predicted summary:  sos ronaldo scores in the world cup final eos
#
#
# Review: actor akshay kumar on twitter condoled the demise of nri businessman mathews who inspired his role of ranjit katyal in 2016 film airlift mathews played key role in evacuating indians based in kuwait during the iraqi invasion in 1990 notably akshay won the national film award for best actor for his performance in airlift along with rustom n
# Original summary: sos akshay condoles demise of businessman who inspired eos
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# Predicted summary:  sos priyanka chopra shares pic of his film with his film eos
#
#
# Review: veteran actress shyama known for her films like and ki raat passed away on tuesday at the age of 82 shyama whose original name is khurshid akhtar also starred in films such as sawan milan and for her role in shyama won the filmfare award in the best supporting actress category
# Original summary: sos actress passes away at 82 eos
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Predicted summary:  sos actress to star in film on october reports eos
#
#
# Review: the congress has approached the election commission alleging that names of thousands of voters from minority community are missing from voters list for karnataka assembly elections the party said only one voter is registered on the electoral roll per family in 10 000 cases earlier an organisation alleged that names of 18 lakh muslim voters were missing from the list
# Original summary: sos thousands of names missing from taka voters list cong eos
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# Predicted summary:  sos bjp mp to be held for not paying for 2019 polls eos
#
#
# Review: it major infosys has dumped its long term revenue target of 20 billion to address criticism including that from co founder narayana murthy infosys decision last year to award higher salary to ceo vishal sikka was based on this revenue goal the company also had search firm evaluate its board members and set up three member panel to sikka
# Original summary: sos infosys dumps 20 billion revenue goal on murthy criticism eos
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Predicted summary:  sos infosys ceo quits as ceo of infosys eos
#
#
# Review: billionaire anand mahindra on sunday said that he would volunteer for the execution of brutal rapists murderers of young girls the mahindra group chairman comments came in reaction to the rape of 9 year old girl in surat whose body was found with 86 injury marks his tweet also comes amid nationwide protests over kathua and unnao rape cases
# ...
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# Predicted summary:  sos i am not my career with me akshay on his birthday eos
#
#
# Review: stating that there was no comparison between pm narendra modi and congress leaders union minister narendra singh tomar on saturday said the two were as different as the hair of moustache and tail the minister who was addressing gathering of bjp workers in madhya pradesh added that congress leaders would take long time to become like pm modi
# Original summary: sos pm cong different like hair of moustache tail minister eos
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# Predicted summary:  sos pm modi is the nation to be held with pm modi eos
#
#
# Review: billionaire sir james dyson has announced that his uk based company dyson is building track stretching over 16 km to test electric vehicles it would include dynamic handling track an off road route fast road route and handling road route the company known for its vacuum cleaners is planning to commercialise its electric vehicles by 2021
# Original summary: sos billionaire building 16 km track to test electric cars eos
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Predicted summary:  sos us to launch its first ever eos
#
#
# Review: thirty congress mlas have been suspended from chhattisgarh assembly after they protested against cm raman singh invitation to foreign based mining corporation for investment the mlas claimed the company had links with pnb fraud accused nirav modi and was blacklisted in the state the legislators broke assembly rules and were automatically suspended for rushing to the well of the house
# Original summary: sos 30 congress mlas suspended from chhattisgarh assembly eos
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Predicted summary:  sos cbi arrests aap leader for cheating of corruption eos
#
#
# Review: australian pacer nathan coulter nile became the only bowler to dismiss indian captain virat kohli for duck twice in his career after getting him caught by glenn maxwell in the first india australia odi on sunday earlier this year coulter nile had dismissed kohli for duck in the kkr rcb game in ipl in kolkata
# Original summary: sos only bowler has dismissed virat kohli for duck twice eos
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Predicted summary:  sos kohli takes out of most runs in test cricket eos
#
#
# Review: brazil based startup robotics in partnership with intel demonstrated an ai powered adapter kit wheelie to move wheelchair with facial expressions and gestures at the consumer electronics show ces 2019 in las vegas the kit learns about the user gestures automatically and takes around seven minutes to install it can be plugged into any motorised wheelchair the startup said
# Original summary: sos ai kit that can control wheelchair with face shown at ces eos
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Predicted summary:  sos startup makes ai that can detect users from eos
#
#
# Review: a frequent bus rider in the united states was given lifetime bus pass on the occasion of her birthday the woman barbara said it means everything to me look at how much can save who lives independently takes the bus to church around four times week
# Original summary: sos woman gets lifetime bus pass as birthday gift eos
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Predicted summary:  sos video shows cop who died in car in mumbai eos
#
#
# Review: the motion poster of the upcoming thriller film aksar which is sequel to the emraan hashmi dino and udita goswami starrer 2006 film aksar has been released the sequel stars actors khan and gautam rode in lead roles it has been directed by ananth narayan mahadevan who also directed the first film
# Original summary: sos motion poster of aksar released eos
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Predicted summary:  sos release date of film released eos
#
#
# Review: actor nafisa ali who has been diagnosed with stage cancer shared video of her grandchildren cutting her hair asked my grandchildren to cut my hair as then they will not realise that am going through chemo we had fun she captioned the video on instagram recently she also shared picture of her shedding hair
# Original summary: sos they won know about my gets hair cut by eos
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Predicted summary:  sos i was my son on my life after being cancer eos
#
#
# Review: vaibhav kesarkar 24 year old cricketer from mumbai died after suffering heart attack on the field while playing local cricket match kesarkar continued to bat for his team despite the chest pain and severe discomfort according to reports he died at nearby hospital where he was taken for medical examination
# Original summary: sos 24 yr old mumbai cricketer suffers heart attack while playing dies eos
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# Predicted summary:  sos video shows player who died in football match eos
#
#
# Review: air india on wednesday rendered an apology day after passengers on its delayed pune delhi flight weren allowed to deboard even as they complained that the air conditioners weren working causing them discomfort last minute technical glitch led to the unfortunate delay of the flight in this process faced inconvenience as they couldn be deboarded before clearance the airline tweeted
# Original summary: sos air india apologises after passengers locked in flight without ac eos
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Predicted summary:  sos air india flight gets to air india flight eos
#
#
# Review: the uttarakhand high court has banned the state government from purchasing luxury items like cars and cellphones over its failure to provide basic amenities in state run schools the court observed that government which cannot provide basic amenities to children has no moral right to spend money on luxuries this comes after an hc order on facilities in government schools
# Original summary: sos uttarakhand hc bans state govt from buying cars eos
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Predicted summary:  sos govt approves new rules for not paying for eos
#
#
# Review: prime minister narendra modi attended actress priyanka chopra and american singer nick jonas wedding reception held in delhi taj palace hotel on tuesday while priyanka wore white and nude embellished lehenga nick chose velvet tuxedo for the occasion the couple who got married as per christian as well as hindu rituals will reportedly host another reception in mumbai
# Original summary: sos pm narendra modi attends priyanka nick delhi wedding reception eos
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# Predicted summary:  sos priyanka nick to be held for daughter in mumbai eos
#
#
# Review: in order to fight misinformation and rumours facebook owned messenger service whatsapp is limiting the text forwards to five chats at time for users worldwide previously whatsapp user could forward message to 20 individuals or groups the limit was introduced in india in july after the spread of rumours on social media led to killings and lynching attempts
# Original summary: sos whatsapp limits text to chats at time worldwide eos
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# Predicted summary:  sos facebook ceo resigns after users quit eos
#
#
# Review: uk based scientists have claimed that molecules brought to earth by meteorites could potentially be converted into the building blocks of dna supporting theory that life on earth was seeded by material from outer space the team demonstrated molecules from interstellar ice in presence of amino acids could be converted to biologically relevant or the ingredients for life
# Original summary: sos life ingredients can be made from deep space material study eos
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Predicted summary:  sos scientists create new new species eos
#
#
# Review: india has delayed implementation of higher tariffs on some goods imported from the us to december 17 despite the us removing at least 50 indian products from the list of items eligible for duty free treatment india was to raise tariffs on us goods on november over us move to unilaterally raise import duties on indian steel and aluminium products
# Original summary: sos india delays of retaliatory tariffs on us goods eos
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Predicted summary:  sos india to be used by us in india eos
#
#
# Review: actor varun dhawan has said that actors should stop behaving like it only their film while adding that putting all the pressure on the actor is also wrong the actor should also stop behaving like main karta hoon main kar meri picture hai added varun he further said feel we give less credit to our directors
# Original summary: sos actors should stop behaving like it only their film varun eos
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# Predicted summary:  sos i am not to be part of my film on film eos

# %%
pip install rouge-score
# Out:
# Collecting rouge-score
#   Downloading rouge_score-0.1.2.tar.gz (17 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: absl-py in /opt/conda/lib/python3.10/site-packages (from rouge-score) (1.4.0)
# Requirement already satisfied: nltk in /opt/conda/lib/python3.10/site-packages (from rouge-score) (3.2.4)
# Requirement already satisfied: numpy in /opt/conda/lib/python3.10/site-packages (from rouge-score) (1.26.4)
# Requirement already satisfied: six>=1.14.0 in /opt/conda/lib/python3.10/site-packages (from rouge-score) (1.16.0)
# Building wheels for collected packages: rouge-score
#   Building wheel for rouge-score (setup.py) ... done
#   Created wheel for rouge-score: filename=rouge_score-0.1.2-py3-none-any.whl size=24934 sha256=18fe3416dd6e71fca74bba01f7acd7d726171234b6c82e679a822e30139474e0
#   Stored in directory: /root/.cache/pip/wheels/5f/dd/89/461065a73be61a532ff8599a28e9beef17985c9e9c31e541b4
# Successfully built rouge-score
# Installing collected packages: rouge-score
# Successfully installed rouge-score-0.1.2
# Note: you may need to restart the kernel to use updated packages.

# %%
from rouge_score import rouge_scorer

# Function to calculate ROUGE scores
def calculate_rouge(reference_summary, generated_summary):
    """
    Calculate ROUGE scores between reference and generated summaries.
    Args:
        reference_summary (str): The human-written reference summary.
        generated_summary (str): The model-generated summary.
    Returns:
        dict: A dictionary containing ROUGE-1, ROUGE-2, and ROUGE-L scores.
    """
    scorer = rouge_scorer.RougeScorer(['rouge1', 'rouge2', 'rougeL'], use_stemmer=True)
    scores = scorer.score(reference_summary, generated_summary)
    return scores

# Example Evaluation Loop
for i in range(100):  # Evaluate the first 5 examples; adjust as needed
    review = seq2text(x_tr[i])  # Convert input sequence to text
    original_summary = seq2summary(y_tr[i])  # Convert target sequence to text
    predicted_summary = decode_sequence(x_tr[i].reshape(1, max_text_len))  # Generate summary
    
    # Calculate ROUGE scores
    rouge_scores = calculate_rouge(original_summary, predicted_summary)
    
    # Print Results
    print(f"Review {i+1}: {review}")
    print(f"Original Summary: {original_summary}")
    print(f"Predicted Summary: {predicted_summary}")
    print("ROUGE Scores:")
    for metric, score in rouge_scores.items():
        print(f"  {metric.upper()} - Precision: {score.precision:.4f}, Recall: {score.recall:.4f}, F1 Score: {score.fmeasure:.4f}")
    print("\n" + "-"*80 + "\n")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# Review 1: hailing the supreme court verdict on right to privacy union minister ravi shankar prasad said that it is not an absolute right and added if want to give speech naked wonã¢âât be allowed like other fundamental rights privacy is also subject to reasonable restrictions he said however prasad refused to comment on the legal challenge to aadhaar
# Original Summary: sos if want to give speech naked wonã¢âât be allowed prasad eos
# Predicted Summary:  sos can be ready to change sc judge on sc st act eos
# ROUGE Scores:
#   ROUGE1 - Precision: 0.3077, Recall: 0.3077, F1 Score: 0.3077
#   ROUGE2 - Precision: 0.0000, Recall: 0.0000, F1 Score: 0.0000
#   ROUGEL - Precision: 0.2308, Recall: 0.2308, F1 Score: 0.2308
#
# --------------------------------------------------------------------------------
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# Review 2: actress bipasha basu and husband karan singh grover left singer justin bieber mumbai concert on wednesday within five minutes of arriving as it was too crowded we didn get security with us and it is too crowded so we are leaving said bipasha meanwhile celebrities including alia bhatt sridevi arbaaz khan malaika arora and kriti sanon attended the concert
# Original Summary: sos bipasha karan left bieber concert within min due to crowd eos
# Predicted Summary:  sos priyanka chopra to be paid for 1st time in yrs eos
# ROUGE Scores:
#   ROUGE1 - Precision: 0.2500, Recall: 0.2500, F1 Score: 0.2500
#   ROUGE2 - Precision: 0.0000, Recall: 0.0000, F1 Score: 0.0000
#   ROUGEL - Precision: 0.2500, Recall: 0.2500, F1 Score: 0.2500
#
# --------------------------------------------------------------------------------
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Review 3: shikhar dhawan became the first indian to get out in nineties in t20i cricket after getting dismissed for 90 49 against sri lanka on tuesday dhawan whose previous highest t20i score was 80 slammed six fours and six sixes during his knock vinoo mankad and kris srikkanth were the first indians to get out in 90s in tests and odis respectively
# Original Summary: sos dhawan first indian batsman to get out in 90s in t20i eos
# Predicted Summary:  sos rohit sharma to play ipl in australia in ipl 2018 eos
# ROUGE Scores:
#   ROUGE1 - Precision: 0.4167, Recall: 0.3846, F1 Score: 0.4000
#   ROUGE2 - Precision: 0.0000, Recall: 0.0000, F1 Score: 0.0000
#   ROUGEL - Precision: 0.4167, Recall: 0.3846, F1 Score: 0.4000
#
# --------------------------------------------------------------------------------
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# Review 4: prime minister narendra modi on tuesday tweeted birthday wishes to former prime minister dr manmohan singh pm modi wished long life filled with good health to singh who has turned 85 years old singh who started his political career in 1991 as the finance minister helped in liberalisation and privatisation to the indian economy
# Original Summary: sos modi wishes manmohan singh on his birthday eos
# Predicted Summary:  sos pm modi is the pm modi on pm modi eos
# ROUGE Scores:
#   ROUGE1 - Precision: 0.3636, Recall: 0.4444, F1 Score: 0.4000
#   ROUGE2 - Precision: 0.0000, Recall: 0.0000, F1 Score: 0.0000
#   ROUGEL - Precision: 0.3636, Recall: 0.4444, F1 Score: 0.4000
#
# --------------------------------------------------------------------------------
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Review 5: female employees of the central government who choose to have child through surrogacy will be entitled to maternity leave of 26 weeks government notification said the directive is based on 2015 delhi high court verdict in case wherein government employed teacher was denied maternity leave on grounds that she was not the biological mother
# Original Summary: sos govt staff having child via surrogacy to get maternity leave eos
# Predicted Summary:  sos court orders to pay for not wearing sex abuse eos
# ROUGE Scores:
#   ROUGE1 - Precision: 0.2727, Recall: 0.2500, F1 Score: 0.2609
#   ROUGE2 - Precision: 0.0000, Recall: 0.0000, F1 Score: 0.0000
#   ROUGEL - Precision: 0.2727, Recall: 0.2500, F1 Score: 0.2609
#
# --------------------------------------------------------------------------------
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# Review 6: experiments show that clear ice shaped in the form of disk can be used to create fire after are removed from an ice slab it can be melted and by using the heat of hands when the piece is held to the sun the concentration of sunlight on particular spot results in creation of fire
# Original Summary: sos fire can be created using ice eos
# Predicted Summary:  sos new york to get its first ever eos
# ROUGE Scores:
#   ROUGE1 - Precision: 0.2222, Recall: 0.2500, F1 Score: 0.2353
#   ROUGE2 - Precision: 0.0000, Recall: 0.0000, F1 Score: 0.0000
#   ROUGEL - Precision: 0.2222, Recall: 0.2500, F1 Score: 0.2353
#
# --------------------------------------------------------------------------------
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# Review 7: karan johar has said that there is tremendous potential in regional cinema he further said cinema is growing by leaps and taking big we keep dividing it calling it regional cinema we should just call it indian cinema and be proud of it johar added that he wants to showcase the talent and do much more in regional cinema
# Original Summary: sos there tremendous potential in regional cinema karan johar eos
# Predicted Summary:  sos i have been the most powerful actor eos
# ROUGE Scores:
#   ROUGE1 - Precision: 0.2222, Recall: 0.2000, F1 Score: 0.2105
#   ROUGE2 - Precision: 0.0000, Recall: 0.0000, F1 Score: 0.0000
#   ROUGEL - Precision: 0.2222, Recall: 0.2000, F1 Score: 0.2105
#
# --------------------------------------------------------------------------------
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Review 8: the makers of vijay starrer mersal have muted the dialogues mocking gst and digital india from its telugu version this comes after the bharatiya janata party tamil nadu unit objected to the references in the film bjp leader raja state president tamilisai and union minister pon radhakrishnan had earlier demanded that the references should be deleted
# Original Summary: sos makers of mersal mute dialogues on gst in telugu version eos
# Predicted Summary:  sos gst is the most powerful president eos
# ROUGE Scores:
#   ROUGE1 - Precision: 0.3750, Recall: 0.2500, F1 Score: 0.3000
#   ROUGE2 - Precision: 0.0000, Recall: 0.0000, F1 Score: 0.0000
#   ROUGEL - Precision: 0.3750, Recall: 0.2500, F1 Score: 0.3000
#
# --------------------------------------------------------------------------------
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Review 9: a jet airways air hostess was arrested with 480 200 around ã¢ââ¹3 crore onboard delhi hong kong flight on monday officials said the initial investigation suggested she was part of an elaborate scheme to bring gold into india in exchange for black money meanwhile jet airways released statement saying it would take further action against the employee following the investigation
# Original Summary: sos jet airways air hostess arrested with ã¢ââ¹3 crore in us eos
# Predicted Summary:  sos air india flight gets air air air air force flight eos
# ROUGE Scores:
#   ROUGE1 - Precision: 0.2500, Recall: 0.2500, F1 Score: 0.2500
#   ROUGE2 - Precision: 0.0000, Recall: 0.0000, F1 Score: 0.0000
#   ROUGEL - Precision: 0.2500, Recall: 0.2500, F1 Score: 0.2500
#
# --------------------------------------------------------------------------------
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Review 10: new pictures of actor hrithik roshan from the sets of his upcoming film super 30 have surfaced online the pictures are reportedly from the streets of jaipur the actor will be seen portraying mathematician anand kumar who is credited with starting an educational initiative to prepare thirty meritorious but financially challenged students for the iit examination
# Original Summary: sos new pics of hrithik from sets of super 30 surface online eos
# Predicted Summary:  sos new poster of thrones released eos
# ROUGE Scores:
#   ROUGE1 - Precision: 0.5714, Recall: 0.3077, F1 Score: 0.4000
#   ROUGE2 - Precision: 0.1667, Recall: 0.0833, F1 Score: 0.1111
#   ROUGEL - Precision: 0.5714, Recall: 0.3077, F1 Score: 0.4000
#
# --------------------------------------------------------------------------------
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# Review 11: nearly 60 000 children in north korea face potential starvation due to international sanctions against the regime the unicef has said although providing humanitarian assistance is exempted from the sanctions the absence of adequate shipping routes delays the delivery of aid global sanctions have been imposed against north korea over its ballistic and nuclear missile programme
# Original Summary: sos 60 000 north korean kids may due to sanctions unicef eos
# Predicted Summary:  sos us sanctions against korea over korea eos
# ROUGE Scores:
#   ROUGE1 - Precision: 0.3750, Recall: 0.2500, F1 Score: 0.3000
#   ROUGE2 - Precision: 0.0000, Recall: 0.0000, F1 Score: 0.0000
#   ROUGEL - Precision: 0.3750, Recall: 0.2500, F1 Score: 0.3000
#
# --------------------------------------------------------------------------------
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# Review 12: paris mayor anne has called for ban on black feminist festival saying it is prohibited to white people the festival has reserved 80 of its area only for black women while the rest is divided into an area open to black men and women and an area open to all anti racist groups have condemned the festival
# Original Summary: sos paris mayor demands ban on black event eos
# Predicted Summary:  sos uk university bans women from its name eos
# ROUGE Scores:
#   ROUGE1 - Precision: 0.3333, Recall: 0.3333, F1 Score: 0.3333
#   ROUGE2 - Precision: 0.0000, Recall: 0.0000, F1 Score: 0.0000
#   ROUGEL - Precision: 0.3333, Recall: 0.3333, F1 Score: 0.3333
#
# --------------------------------------------------------------------------------
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Review 13: chinese electric vehicle maker market value soared to almost 12 billion after its shares closed up 76 on their second day of trading the shanghai based company which billed itself as an emerging tesla rival raised 1 billion in us offering sells only in china although its technology and design teams are based in the us uk and germany
# Original Summary: sos tesla rival valued at 12 billion in two days of trading eos
# Predicted Summary:  sos china to buy its own own cryptocurrency eos
# ROUGE Scores:
#   ROUGE1 - Precision: 0.2222, Recall: 0.1538, F1 Score: 0.1818
#   ROUGE2 - Precision: 0.0000, Recall: 0.0000, F1 Score: 0.0000
#   ROUGEL - Precision: 0.2222, Recall: 0.1538, F1 Score: 0.1818
#
# --------------------------------------------------------------------------------
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Review 14: human rights watch hrw has accused the un security council of failing to investigate war crimes and rights abuses by anti isis forces in iraq calling un approach as flawed and selective the organisation said it misses the opportunity to investigate crimes committed by all parties of the conflict hrw added that the un deliberately chose not to investigate the abuses
# Original Summary: sos un failed to investigate crimes in iraq human rights watch eos
# Predicted Summary:  sos us to give action against us over rohingya violence eos
# ROUGE Scores:
#   ROUGE1 - Precision: 0.2727, Recall: 0.2500, F1 Score: 0.2609
#   ROUGE2 - Precision: 0.0000, Recall: 0.0000, F1 Score: 0.0000
#   ROUGEL - Precision: 0.2727, Recall: 0.2500, F1 Score: 0.2609
#
# --------------------------------------------------------------------------------
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# Review 15: a 23 year old man has been arrested for sending obscene messages to television actress sonarika bhadoria she revealed that the man used 25 different numbers to contact her and had been calling her since eight months sonarika is known for her portrayal of goddess parvati and adi shakti in the television serial devon ke dev mahadev
# Original Summary: sos man arrested for sending obscene messages to tv actress eos
# Predicted Summary:  sos man arrested for posting video of his son in up eos
# ROUGE Scores:
#   ROUGE1 - Precision: 0.4167, Recall: 0.4545, F1 Score: 0.4348
#   ROUGE2 - Precision: 0.2727, Recall: 0.3000, F1 Score: 0.2857
#   ROUGEL - Precision: 0.4167, Recall: 0.4545, F1 Score: 0.4348
#
# --------------------------------------------------------------------------------
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Review 16: former pakistan pm nawaz sharif son hussain has alleged that his father was deprived of bed in jail and that the bathroom there was extremely dirty sharif was arrested along with his daughter maryam on their return to lahore from london on friday earlier reports stated that the father daughter duo will get facilities like ac and tv in jail
# Original Summary: sos no bed dirty washroom for nawaz sharif in jail alleges son eos
# Predicted Summary:  sos pak pm wife wife to be shot by his wife eos
# ROUGE Scores:
#   ROUGE1 - Precision: 0.1667, Recall: 0.1538, F1 Score: 0.1600
#   ROUGE2 - Precision: 0.0000, Recall: 0.0000, F1 Score: 0.0000
#   ROUGEL - Precision: 0.1667, Recall: 0.1538, F1 Score: 0.1600
#
# --------------------------------------------------------------------------------
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Review 17: the external affairs ministry has announced that the last page of passports which carries the holder address will no longer be printed making the document an invalid address proof this comes after committee recommended that the father name which is also on the last page be omitted however no timeline has been announced for the implementation of the change
# Original Summary: sos new indian passports cannot be used as an address proof eos
# Predicted Summary:  sos india to be part of india in india eos
# ROUGE Scores:
#   ROUGE1 - Precision: 0.3000, Recall: 0.2500, F1 Score: 0.2727
#   ROUGE2 - Precision: 0.0000, Recall: 0.0000, F1 Score: 0.0000
#   ROUGEL - Precision: 0.3000, Recall: 0.2500, F1 Score: 0.2727
#
# --------------------------------------------------------------------------------
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Review 18: the us navy destroyer which recently collided with philippine flagged container ship in japan failed to respond to warning signals or take evasive action before the collision according to the philippine ship captain the accident claimed the lives of seven us navy sailors in the greatest loss of life on us navy vessel since 2000 nn
# Original Summary: sos us destroyer which with ship didn act to warnings eos
# Predicted Summary:  sos us navy to death after being hit by isis eos
# ROUGE Scores:
#   ROUGE1 - Precision: 0.3636, Recall: 0.3636, F1 Score: 0.3636
#   ROUGE2 - Precision: 0.1000, Recall: 0.1000, F1 Score: 0.1000
#   ROUGEL - Precision: 0.3636, Recall: 0.3636, F1 Score: 0.3636
#
# --------------------------------------------------------------------------------
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# Review 19: police have arrested five people including prominent lawyer surendra and delhi man rana jacob in connection with the bhima koregaon riots in maharashtra in january police also searched the house of nagpur university professor with alleged maoist links the violence had been triggered during gathering by dalits for the 200th anniversary celebrations of the bhima koregaon battle
# Original Summary: sos lawyer activists among arrested over bhima koregaon riots eos
# Predicted Summary:  sos police arrests ex cop for refusing to kill him eos
# ROUGE Scores:
#   ROUGE1 - Precision: 0.2727, Recall: 0.3000, F1 Score: 0.2857
#   ROUGE2 - Precision: 0.0000, Recall: 0.0000, F1 Score: 0.0000
#   ROUGEL - Precision: 0.2727, Recall: 0.3000, F1 Score: 0.2857
#
# --------------------------------------------------------------------------------
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# Review 20: south africa registered 6 wicket victory in the second t20i at centurion on wednesday to end india winning streak of five t20i matches and level the three match series 1 1 india had last lost t20i match on november 2017 against new zealand at rajkot the series decider will take place at cape town on saturday
# Original Summary: sos sa end india 5 match winning streak level series 1 1 eos
# Predicted Summary:  sos australia beat sl to win their first odi series in t20i eos
# ROUGE Scores:
#   ROUGE1 - Precision: 0.3077, Recall: 0.3077, F1 Score: 0.3077
#   ROUGE2 - Precision: 0.0000, Recall: 0.0000, F1 Score: 0.0000
#   ROUGEL - Precision: 0.3077, Recall: 0.3077, F1 Score: 0.3077
#
# --------------------------------------------------------------------------------
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# Review 21: users have reported that bug affecting samsung galaxy and galaxy note sent users pictures to their contacts without their permission they claimed that the issue affected samsung messages following mobile network t mobile update for advanced messaging between carriers samsung spokesperson said it is aware of the issue and is looking into the matter
# Original Summary: sos bug makes samsung phones send photos to random contacts eos
# Predicted Summary:  sos google launches feature to let users eos
# ROUGE Scores:
#   ROUGE1 - Precision: 0.3750, Recall: 0.2727, F1 Score: 0.3158
#   ROUGE2 - Precision: 0.0000, Recall: 0.0000, F1 Score: 0.0000
#   ROUGEL - Precision: 0.3750, Recall: 0.2727, F1 Score: 0.3158
#
# --------------------------------------------------------------------------------
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Review 22: around 27 children in india are married before the age of 18 years as compared to the global average of 28 according to united nations fund for population activities report the report also states india maternal mortality rate mmr that is mothers dying per 00 000 live births is 174 against the world average of 216
# Original Summary: sos 27 children in india are married before they turn 18 un eos
# Predicted Summary:  sos indian origin women to be auctioned for years eos
# ROUGE Scores:
#   ROUGE1 - Precision: 0.2000, Recall: 0.1538, F1 Score: 0.1739
#   ROUGE2 - Precision: 0.0000, Recall: 0.0000, F1 Score: 0.0000
#   ROUGEL - Precision: 0.2000, Recall: 0.1538, F1 Score: 0.1739
#
# --------------------------------------------------------------------------------
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Review 23: a uk court has cleared extradition of 50 year old bookie sanjeev chawla key accused in the 2000 match fixing scandal involving late south africa captain hansie cronje to india the accused had moved to the uk in 1996 and obtained british passport in 2005 this comes after the uk high court accepted assurances given by india regarding tihar jail condition
# Original Summary: sos uk court clears extradition of accused in 2000 match fixing scandal eos
# Predicted Summary:  sos pak court dismisses plea against pak over his tweet eos
# ROUGE Scores:
#   ROUGE1 - Precision: 0.2727, Recall: 0.2308, F1 Score: 0.2500
#   ROUGE2 - Precision: 0.0000, Recall: 0.0000, F1 Score: 0.0000
#   ROUGEL - Precision: 0.2727, Recall: 0.2308, F1 Score: 0.2500
#
# --------------------------------------------------------------------------------
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Review 24: actor abhay deol has revealed that only one actress called to support him after he slammed bollywood actors including shah rukh khan deepika padukone and sonam kapoor for endorsing fairness creams received lot of support from people and media from corporates and filmmakers no why would they am calling them out for their practices he added
# Original Summary: sos only actress supported me abhay on fairness cream post eos
# Predicted Summary:  sos i am not my life with me saif on ranbir kapoor eos
# ROUGE Scores:
#   ROUGE1 - Precision: 0.3077, Recall: 0.3636, F1 Score: 0.3333
#   ROUGE2 - Precision: 0.0000, Recall: 0.0000, F1 Score: 0.0000
#   ROUGEL - Precision: 0.3077, Recall: 0.3636, F1 Score: 0.3333
#
# --------------------------------------------------------------------------------
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# Review 25: the 14th dalai lama said that historically the indians and tibetans have had long enduring relationship as teachers gurus and disciples chelas we are not only chelas but quite reliable chelas he added the dalai lama who was on nine day visit to arunachal pradesh has traveled to the indian state on six earlier occasions since 1983
# Original Summary: sos india is the guru tibetans are dalai lama eos
# Predicted Summary:  sos india to be part of india china eos
# ROUGE Scores:
#   ROUGE1 - Precision: 0.3333, Recall: 0.3000, F1 Score: 0.3158
#   ROUGE2 - Precision: 0.1250, Recall: 0.1111, F1 Score: 0.1176
#   ROUGEL - Precision: 0.3333, Recall: 0.3000, F1 Score: 0.3158
#
# --------------------------------------------------------------------------------
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Review 26: bengaluru based vernacular social networking app sharechat has banned 50 000 profiles with problematic content like pornography violence and fake news it asked users to report profiles with problematic content reviewed the complaints and then took appropriate action by iit kanpur alumni sharechat lets users post content in 14 local languages including telugu bhojpuri and odia n
# Original Summary: sos bans 50 000 profiles to tackle porn fake news eos
# Predicted Summary:  sos iit group makes users to let users eos
# ROUGE Scores:
#   ROUGE1 - Precision: 0.3333, Recall: 0.2727, F1 Score: 0.3000
#   ROUGE2 - Precision: 0.0000, Recall: 0.0000, F1 Score: 0.0000
#   ROUGEL - Precision: 0.3333, Recall: 0.2727, F1 Score: 0.3000
#
# --------------------------------------------------------------------------------
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Review 27: the panchayat in bihar village asked man to pay compensation of ã¢ââ¹20 000 to girl whom he kissed twice on the cheek without her consent when she was returning home however the girl refused to take compensation and said he the accused has earned me much disrepute in the society and he will have to marry me
# Original Summary: sos panchayat fines man for kissing girl she wants to marry him eos
# Predicted Summary:  sos man arrested for raping woman in up for months eos
# ROUGE Scores:
#   ROUGE1 - Precision: 0.3636, Recall: 0.3077, F1 Score: 0.3333
#   ROUGE2 - Precision: 0.0000, Recall: 0.0000, F1 Score: 0.0000
#   ROUGEL - Precision: 0.3636, Recall: 0.3077, F1 Score: 0.3333
#
# --------------------------------------------------------------------------------
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Review 28: china has opposed pm narendra modi visit to arunachal pradesh which it claims as part of south tibet adding that it has never recognised the so called arunachal pradesh china said that it would lodge diplomatic protest with india over the visit this was pm modi first visit to the indian state since the india china doklam standoff last year nn
# Original Summary: sos china opposes pm narendra modi visit to arunachal pradesh eos
# Predicted Summary:  sos china to visit india to visit india eos
# ROUGE Scores:
#   ROUGE1 - Precision: 0.5556, Recall: 0.4545, F1 Score: 0.5000
#   ROUGE2 - Precision: 0.1250, Recall: 0.1000, F1 Score: 0.1111
#   ROUGEL - Precision: 0.5556, Recall: 0.4545, F1 Score: 0.5000
#
# --------------------------------------------------------------------------------
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Review 29: the border security force bsf on monday seized pakistani boat loaded with 400 kg fish near sutlej river in punjab border area and an investigation has been launched into the matter last month the pakistan navy apprehended 88 indian fishermen and 15 boats off the gujarat coast in the arabian sea for allegedly straying into its territorial waters
# Original Summary: sos bsf seizes pak boat from river in punjab eos
# Predicted Summary:  sos army kills 11 civilians in air strike over air india eos
# ROUGE Scores:
#   ROUGE1 - Precision: 0.2500, Recall: 0.3000, F1 Score: 0.2727
#   ROUGE2 - Precision: 0.0000, Recall: 0.0000, F1 Score: 0.0000
#   ROUGEL - Precision: 0.2500, Recall: 0.3000, F1 Score: 0.2727
#
# --------------------------------------------------------------------------------
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Review 30: deepika padukone broke down on the sets of 2013 film goliyon ki rasleela ram leela because of some last minute changes in the dialogues revealed the film writer she deepika usually very good with her lines but the change meant completely upsetting her pattern said co writer garima the writers later worked on the lines till deepika was comfortable with them
# Original Summary: sos deepika broke down on ram leela sets due to dialogue change eos
# Predicted Summary:  sos deepika ranveer to star in film reports eos
# ROUGE Scores:
#   ROUGE1 - Precision: 0.4444, Recall: 0.3077, F1 Score: 0.3636
#   ROUGE2 - Precision: 0.1250, Recall: 0.0833, F1 Score: 0.1000
#   ROUGEL - Precision: 0.4444, Recall: 0.3077, F1 Score: 0.3636
#
# --------------------------------------------------------------------------------
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# Review 31: attorney general kk venugopal on saturday said unity among supreme court judges will be restored by monday this comes after four senior most sc judges held press conference voicing concerns over cji dipak misra and the administration of the judiciary ag venugopal further said he hoped that the judges will not let the issue escalate
# Original Summary: sos unity in sc judges will return by monday attorney general eos
# Predicted Summary:  sos sc to hear plea against cji to hear plea eos
# ROUGE Scores:
#   ROUGE1 - Precision: 0.2727, Recall: 0.2500, F1 Score: 0.2609
#   ROUGE2 - Precision: 0.0000, Recall: 0.0000, F1 Score: 0.0000
#   ROUGEL - Precision: 0.2727, Recall: 0.2500, F1 Score: 0.2609
#
# --------------------------------------------------------------------------------
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# Review 32: singer varsha singh alleged that singer kailash kher who she used to consider her guru once sent her message that read want to make love to you she also accused music composer of sexual misconduct when under the influence of alcohol he put his hand on her thigh has denied the allegations
# Original Summary: sos kailash kher saying want to make love to you singer eos
# Predicted Summary:  sos i am not to be called me as actress eos
# ROUGE Scores:
#   ROUGE1 - Precision: 0.2727, Recall: 0.2500, F1 Score: 0.2609
#   ROUGE2 - Precision: 0.0000, Recall: 0.0000, F1 Score: 0.0000
#   ROUGEL - Precision: 0.2727, Recall: 0.2500, F1 Score: 0.2609
#
# --------------------------------------------------------------------------------
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# Review 33: the screening of the film the accidental prime minister was cancelled at kolkata hind cinema due to security concerns amid protests by youth congress activists close to 100 activists protested in front of the theatre west bengal youth congress president shadab khan said the show was reportedly halted after the first ten minutes of the film were screened
# Original Summary: sos the accidental halted in kolkata theatre amid protests eos
# Predicted Summary:  sos bjp leader who killed in encounter in up eos
# ROUGE Scores:
#   ROUGE1 - Precision: 0.3000, Recall: 0.3000, F1 Score: 0.3000
#   ROUGE2 - Precision: 0.0000, Recall: 0.0000, F1 Score: 0.0000
#   ROUGEL - Precision: 0.3000, Recall: 0.3000, F1 Score: 0.3000
#
# --------------------------------------------------------------------------------
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Review 34: org parody of us president donald trump owned hotels website com displays photos of immigrants in temporary detention centres the website which mocks trump zero tolerance immigration policy also features his quotes supporting the same the domain name records reportedly show that the org domain was registered last week through proxy service
# Original Summary: sos parody site of com shows images of immigrants eos
# Predicted Summary:  sos trump asks president to visit us prez eos
# ROUGE Scores:
#   ROUGE1 - Precision: 0.2222, Recall: 0.2000, F1 Score: 0.2105
#   ROUGE2 - Precision: 0.0000, Recall: 0.0000, F1 Score: 0.0000
#   ROUGEL - Precision: 0.2222, Recall: 0.2000, F1 Score: 0.2105
#
# --------------------------------------------------------------------------------
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# Review 35: ken 97 year old war veteran who survived the battle of dunkirk during world war ii attended the premiere of christopher nolan film dunkirk in calgary canada was 20 when that happened but watching the movie could see my old friends again and lot of them died later in the war said ken
# Original Summary: sos war veteran who survived wwii attends premiere eos
# Predicted Summary:  sos i was the world cup after being called eos
# ROUGE Scores:
#   ROUGE1 - Precision: 0.2000, Recall: 0.2222, F1 Score: 0.2105
#   ROUGE2 - Precision: 0.0000, Recall: 0.0000, F1 Score: 0.0000
#   ROUGEL - Precision: 0.2000, Recall: 0.2222, F1 Score: 0.2105
#
# --------------------------------------------------------------------------------
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Review 36: english singer songwriter ed sheeran who performed in mumbai on sunday at his second concert ever in india has said that bollywood is bright and colourful and film with actor shah rukh khan would be quite cool sheeran added had to come back to india last time when performed here loved it people are so welcoming here
# Original Summary: sos a film with shah rukh khan would be quite cool ed sheeran eos
# Predicted Summary:  sos i am the most expensive actress on being demise eos
# ROUGE Scores:
#   ROUGE1 - Precision: 0.2727, Recall: 0.2143, F1 Score: 0.2400
#   ROUGE2 - Precision: 0.0000, Recall: 0.0000, F1 Score: 0.0000
#   ROUGEL - Precision: 0.2727, Recall: 0.2143, F1 Score: 0.2400
#
# --------------------------------------------------------------------------------
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Review 37: posing as policemen two men allegedly raped 20 year old woman and molested her minor niece in outer delhi on sunday night the accused had approached the woman and her niece claiming they were policemen the police said the victims statements were recorded and case was registered but the men are yet to be identified
# Original Summary: sos posing as policemen two men sexually assault woman niece eos
# Predicted Summary:  sos delhi man held for raping woman in delhi eos
# ROUGE Scores:
#   ROUGE1 - Precision: 0.3000, Recall: 0.2727, F1 Score: 0.2857
#   ROUGE2 - Precision: 0.0000, Recall: 0.0000, F1 Score: 0.0000
#   ROUGEL - Precision: 0.3000, Recall: 0.2727, F1 Score: 0.2857
#
# --------------------------------------------------------------------------------
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# Review 38: mukesh ambani led reliance industries is reportedly in talks to acquire mumbai based cable and broadband service provider hathway cable and the talks are aimed at using the company platform to speed up the commercial launch of its jio home broadband services the deal is expected to value hathway at around ã¢ââ¹2 500 crore
# Original Summary: sos reliance in talks to buy broadband firm report eos
# Predicted Summary:  sos flipkart to invest in india in india eos
# ROUGE Scores:
#   ROUGE1 - Precision: 0.4444, Recall: 0.4000, F1 Score: 0.4211
#   ROUGE2 - Precision: 0.0000, Recall: 0.0000, F1 Score: 0.0000
#   ROUGEL - Precision: 0.3333, Recall: 0.3000, F1 Score: 0.3158
#
# --------------------------------------------------------------------------------
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# ...
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Review 88: australian pacer nathan coulter nile became the only bowler to dismiss indian captain virat kohli for duck twice in his career after getting him caught by glenn maxwell in the first india australia odi on sunday earlier this year coulter nile had dismissed kohli for duck in the kkr rcb game in ipl in kolkata
# Original Summary: sos only bowler has dismissed virat kohli for duck twice eos
# Predicted Summary:  sos kohli takes out of most runs in test cricket eos
# ROUGE Scores:
#   ROUGE1 - Precision: 0.2727, Recall: 0.2727, F1 Score: 0.2727
#   ROUGE2 - Precision: 0.0000, Recall: 0.0000, F1 Score: 0.0000
#   ROUGEL - Precision: 0.2727, Recall: 0.2727, F1 Score: 0.2727
#
# --------------------------------------------------------------------------------
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Review 89: brazil based startup robotics in partnership with intel demonstrated an ai powered adapter kit wheelie to move wheelchair with facial expressions and gestures at the consumer electronics show ces 2019 in las vegas the kit learns about the user gestures automatically and takes around seven minutes to install it can be plugged into any motorised wheelchair the startup said
# Original Summary: sos ai kit that can control wheelchair with face shown at ces eos
# Predicted Summary:  sos startup makes ai that can detect users from eos
# ROUGE Scores:
#   ROUGE1 - Precision: 0.5000, Recall: 0.3846, F1 Score: 0.4348
#   ROUGE2 - Precision: 0.1111, Recall: 0.0833, F1 Score: 0.0952
#   ROUGEL - Precision: 0.5000, Recall: 0.3846, F1 Score: 0.4348
#
# --------------------------------------------------------------------------------
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Review 90: a frequent bus rider in the united states was given lifetime bus pass on the occasion of her birthday the woman barbara said it means everything to me look at how much can save who lives independently takes the bus to church around four times week
# Original Summary: sos woman gets lifetime bus pass as birthday gift eos
# Predicted Summary:  sos video shows cop who died in car in mumbai eos
# ROUGE Scores:
#   ROUGE1 - Precision: 0.1818, Recall: 0.2000, F1 Score: 0.1905
#   ROUGE2 - Precision: 0.0000, Recall: 0.0000, F1 Score: 0.0000
#   ROUGEL - Precision: 0.1818, Recall: 0.2000, F1 Score: 0.1905
#
# --------------------------------------------------------------------------------
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# Review 91: the motion poster of the upcoming thriller film aksar which is sequel to the emraan hashmi dino and udita goswami starrer 2006 film aksar has been released the sequel stars actors khan and gautam rode in lead roles it has been directed by ananth narayan mahadevan who also directed the first film
# Original Summary: sos motion poster of aksar released eos
# Predicted Summary:  sos release date of film released eos
# ROUGE Scores:
#   ROUGE1 - Precision: 0.5714, Recall: 0.5714, F1 Score: 0.5714
#   ROUGE2 - Precision: 0.1667, Recall: 0.1667, F1 Score: 0.1667
#   ROUGEL - Precision: 0.5714, Recall: 0.5714, F1 Score: 0.5714
#
# --------------------------------------------------------------------------------
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Review 92: actor nafisa ali who has been diagnosed with stage cancer shared video of her grandchildren cutting her hair asked my grandchildren to cut my hair as then they will not realise that am going through chemo we had fun she captioned the video on instagram recently she also shared picture of her shedding hair
# Original Summary: sos they won know about my gets hair cut by eos
# Predicted Summary:  sos i was my son on my life after being cancer eos
# ROUGE Scores:
#   ROUGE1 - Precision: 0.2500, Recall: 0.2727, F1 Score: 0.2609
#   ROUGE2 - Precision: 0.0000, Recall: 0.0000, F1 Score: 0.0000
#   ROUGEL - Precision: 0.2500, Recall: 0.2727, F1 Score: 0.2609
#
# --------------------------------------------------------------------------------
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Review 93: vaibhav kesarkar 24 year old cricketer from mumbai died after suffering heart attack on the field while playing local cricket match kesarkar continued to bat for his team despite the chest pain and severe discomfort according to reports he died at nearby hospital where he was taken for medical examination
# Original Summary: sos 24 yr old mumbai cricketer suffers heart attack while playing dies eos
# Predicted Summary:  sos video shows player who died in football match eos
# ROUGE Scores:
#   ROUGE1 - Precision: 0.3000, Recall: 0.2308, F1 Score: 0.2609
#   ROUGE2 - Precision: 0.0000, Recall: 0.0000, F1 Score: 0.0000
#   ROUGEL - Precision: 0.3000, Recall: 0.2308, F1 Score: 0.2609
#
# --------------------------------------------------------------------------------
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Review 94: air india on wednesday rendered an apology day after passengers on its delayed pune delhi flight weren allowed to deboard even as they complained that the air conditioners weren working causing them discomfort last minute technical glitch led to the unfortunate delay of the flight in this process faced inconvenience as they couldn be deboarded before clearance the airline tweeted
# Original Summary: sos air india apologises after passengers locked in flight without ac eos
# Predicted Summary:  sos air india flight gets to air india flight eos
# ROUGE Scores:
#   ROUGE1 - Precision: 0.5000, Recall: 0.4167, F1 Score: 0.4545
#   ROUGE2 - Precision: 0.2222, Recall: 0.1818, F1 Score: 0.2000
#   ROUGEL - Precision: 0.5000, Recall: 0.4167, F1 Score: 0.4545
#
# --------------------------------------------------------------------------------
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Review 95: the uttarakhand high court has banned the state government from purchasing luxury items like cars and cellphones over its failure to provide basic amenities in state run schools the court observed that government which cannot provide basic amenities to children has no moral right to spend money on luxuries this comes after an hc order on facilities in government schools
# Original Summary: sos uttarakhand hc bans state govt from buying cars eos
# Predicted Summary:  sos govt approves new rules for not paying for eos
# ROUGE Scores:
#   ROUGE1 - Precision: 0.3000, Recall: 0.3000, F1 Score: 0.3000
#   ROUGE2 - Precision: 0.0000, Recall: 0.0000, F1 Score: 0.0000
#   ROUGEL - Precision: 0.3000, Recall: 0.3000, F1 Score: 0.3000
#
# --------------------------------------------------------------------------------
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Review 96: prime minister narendra modi attended actress priyanka chopra and american singer nick jonas wedding reception held in delhi taj palace hotel on tuesday while priyanka wore white and nude embellished lehenga nick chose velvet tuxedo for the occasion the couple who got married as per christian as well as hindu rituals will reportedly host another reception in mumbai
# Original Summary: sos pm narendra modi attends priyanka nick delhi wedding reception eos
# Predicted Summary:  sos priyanka nick to be held for daughter in mumbai eos
# ROUGE Scores:
#   ROUGE1 - Precision: 0.3636, Recall: 0.3636, F1 Score: 0.3636
#   ROUGE2 - Precision: 0.1000, Recall: 0.1000, F1 Score: 0.1000
#   ROUGEL - Precision: 0.3636, Recall: 0.3636, F1 Score: 0.3636
#
# --------------------------------------------------------------------------------
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Review 97: in order to fight misinformation and rumours facebook owned messenger service whatsapp is limiting the text forwards to five chats at time for users worldwide previously whatsapp user could forward message to 20 individuals or groups the limit was introduced in india in july after the spread of rumours on social media led to killings and lynching attempts
# Original Summary: sos whatsapp limits text to chats at time worldwide eos
# Predicted Summary:  sos facebook ceo resigns after users quit eos
# ROUGE Scores:
#   ROUGE1 - Precision: 0.2500, Recall: 0.2000, F1 Score: 0.2222
#   ROUGE2 - Precision: 0.0000, Recall: 0.0000, F1 Score: 0.0000
#   ROUGEL - Precision: 0.2500, Recall: 0.2000, F1 Score: 0.2222
#
# --------------------------------------------------------------------------------
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Review 98: uk based scientists have claimed that molecules brought to earth by meteorites could potentially be converted into the building blocks of dna supporting theory that life on earth was seeded by material from outer space the team demonstrated molecules from interstellar ice in presence of amino acids could be converted to biologically relevant or the ingredients for life
# Original Summary: sos life ingredients can be made from deep space material study eos
# Predicted Summary:  sos scientists create new new species eos
# ROUGE Scores:
#   ROUGE1 - Precision: 0.2857, Recall: 0.1667, F1 Score: 0.2105
#   ROUGE2 - Precision: 0.0000, Recall: 0.0000, F1 Score: 0.0000
#   ROUGEL - Precision: 0.2857, Recall: 0.1667, F1 Score: 0.2105
#
# --------------------------------------------------------------------------------
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Review 99: india has delayed implementation of higher tariffs on some goods imported from the us to december 17 despite the us removing at least 50 indian products from the list of items eligible for duty free treatment india was to raise tariffs on us goods on november over us move to unilaterally raise import duties on indian steel and aluminium products
# Original Summary: sos india delays of retaliatory tariffs on us goods eos
# Predicted Summary:  sos india to be used by us in india eos
# ROUGE Scores:
#   ROUGE1 - Precision: 0.4000, Recall: 0.4000, F1 Score: 0.4000
#   ROUGE2 - Precision: 0.1111, Recall: 0.1111, F1 Score: 0.1111
#   ROUGEL - Precision: 0.4000, Recall: 0.4000, F1 Score: 0.4000
#
# --------------------------------------------------------------------------------
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# Review 100: actor varun dhawan has said that actors should stop behaving like it only their film while adding that putting all the pressure on the actor is also wrong the actor should also stop behaving like main karta hoon main kar meri picture hai added varun he further said feel we give less credit to our directors
# Original Summary: sos actors should stop behaving like it only their film varun eos
# Predicted Summary:  sos i am not to be part of my film on film eos
# ROUGE Scores:
#   ROUGE1 - Precision: 0.2308, Recall: 0.2500, F1 Score: 0.2400
#   ROUGE2 - Precision: 0.0000, Recall: 0.0000, F1 Score: 0.0000
#   ROUGEL - Precision: 0.2308, Recall: 0.2500, F1 Score: 0.2400
#
# --------------------------------------------------------------------------------

# %%
import pickle

# Save tokenizers
with open("source_tokenizer.pkl", "wb") as f:
    pickle.dump(x_tokenizer, f)  # Assuming x_tokenizer is your source tokenizer

with open("target_tokenizer.pkl", "wb") as f:
    pickle.dump(y_tokenizer, f)  # Assuming y_tokenizer is your target tokenizer

# %%
parameters = {
    "max_text_len": max_text_len,
    "max_summary_len": max_summary_len,
}

with open("parameters.pkl", "wb") as f:
    pickle.dump(parameters, f)
